# %%
import math
import random
import re
from datetime import datetime, timedelta
from itertools import combinations

import numpy as np
import pandas as pd
import spacy
import torch
from pulp import LpMinimize, LpProblem, LpVariable, lpSum
from sklearn.metrics.pairwise import cosine_similarity
from transformers import AutoModel, AutoTokenizer, pipeline

# %% [markdown]
# # 1. Анализ данных и их обработка

# %% [markdown]
# ## 1.1 Список поручений

# %%
df_cases = pd.read_csv("../data/cases.csv", delimiter=";", encoding="utf-8-sig", decimal=",")
df_cases.head(5)
# Out:
#    Номер поручения Заказчик Дата поручения Выполнено Дата выполнения  \
# 0            11000     Анна     1051-08-11        да      1051-08-21
# 1            11001    Мария     1051-07-09        да      1051-09-02
# 2            11002   Эмилио     1053-10-05        да      1053-10-20
# 3            11003   Бьянка     1052-11-24        да      1052-12-02
# 4            11004   Бьянка     1052-02-23        да      1052-03-30
#
#    Затрачено дней  Сумма вознаграждения  \
# 0             4.0                  6000
# 1             2.0                 20000
# 2             7.0                 22500
# 3             5.0                  5500
# 4             8.0                 10500
#
#                                             Описание
# 0  В лесу по дороге от пещеры звери нападают на л...
# 1  В лесу по дороге от пещеры были замечены разбо...
# 2  По дороге из деревни монстры похитили путников...
# 3  Недалеко от города видели монстров. Нужно побе...
# 4  В деревне у меня пропала сумка с документами. ...

# %% [markdown]
# На основе первичного анализа можно выделить несколько ключевых особенностей:
#
# 1. **Повторяющийся характер описаний**
#    В описаниях поручений наблюдаются схожие фразы и структуры, что указывает на их стандартный характер.
#
# 2. **Явная структура текста**
#    Каждое описание состоит из двух или трёх предложений, которые соответствуют следующей логике:
#    - **Описание ситуации:** Указание на проблему или событие, произошедшее в определённой местности (например, нападение монстров или кража).
#    - **Необходимая цель:** Формулировка задачи, которую требуется выполнить (например, победить монстров или вернуть пропавший предмет).
#    - **Совет:** В некоторых случаях добавляется дополнительное указание или пожелание, уточняющее действия или способы выполнения задания.
#
# Такой подход позволяет быстро понять суть поручения и его требования.

# %%
df_cases["Описание"].value_counts()
# Out:
# Описание
# В пещере появвилось огромное каменное чудовище. Нужно убить его.                                                              23
# В пещере появвилось огромное каменное чудовище. Нужно уничтожить его.                                                         22
# В пещере завёлся дракон. Нужно его уничтожить.                                                                                19
# В пещере завёлся дракон. Нужно его убить.                                                                                     18
# В пещере завёлся дракон. Нужно его уничтожить. Это может потребовать времени и усилий, так как дракон очень опасен.           15
#                                                                                                                               ..
# В лесу между городом и деревней заметили зверей. Нужно прогнать их.                                                            1
# В лесу по дороге от пещеры видели монстров. Нужно победить их.                                                                 1
# В лесу около деревни заметили зверей. Нужно убить их.                                                                          1
# Недалеко от города разбойники нападают на людей. Нужно убить их. Будьте осторожны, так как разбойники могут быть опасными.     1
# Недалеко от города у меня пропал рюкзак. Нужно вернуть его как можно скорее.                                                   1
# Name: count, Length: 243, dtype: int64

# %% [markdown]
# На основе выявленных первичных зависимостей разработан метод, который разбивает описание на логические структуры:

# %%
#Разбиение описания на предложения и получение отдельного дата фрейма: номер поручения, описание, цель, совет
def split_description(data):
    ids = []
    description = []
    purpose = []
    advice = []
    for id, text in data:
        text_splitted = text.split(". ")
        ids.append(id)
        if len(text_splitted) == 2:
            description.append(text_splitted[0])
            purpose.append(text_splitted[1])
            advice.append("")
        else:
            description.append(text_splitted[0])
            purpose.append(text_splitted[1])
            advice.append(text_splitted[2])
    return pd.DataFrame({
        "Номер поручения": ids,
        "description": description,
        "advice": advice,
        "purpose": purpose
    })

# %% [markdown]
# После чего полученное "разбитое" описание было добавлено в исходную таблицу поручений:

# %%
#Разбиение описания и расширение таблицы с поручениями
df_cases = pd.merge(
    df_cases,
    split_description(df_cases[["Номер поручения", "Описание"]].values),
    on="Номер поручения",
    how="outer"
    )

# %% [markdown]
# Рассмотрим частоту встречаемости целей

# %%
df_cases["purpose"].value_counts()
# Out:
# purpose
# Нужно найти её как можно скорее.       36
# Нужно вернуть её как можно скорее.     35
# Нужно убить их.                        34
# Нужно прогнать их.                     27
# Нужно спасти их                        23
# Нужно убить его.                       23
# Нужно вернуть его как можно скорее.    23
# Нужно уничтожить его.                  22
# Нужно освободить их                    21
# Нужно найти его как можно скорее.      21
# Нужно вернуть её как можно скорее      20
# Нужно его уничтожить.                  19
# Нужно уничтожить их.                   19
# Нужно победить их.                     18
# Нужно его убить.                       18
# Нужно прогнать их                      16
# Нужно его уничтожить                   15
# Нужно убить их                         14
# Нужно проучить их.                     14
# Нужно найти её как можно скорее        13
# Нужно освободить их.                   13
# Нужно уничтожить их                    10
# Нужно спасти их.                       10
# Нужно его убить                         8
# Нужно победить их                       7
# Нужно проучить их                       5
# Нужно уничтожить его                    4
# Нужно найти его как можно скорее        4
# Нужно убить его                         4
# Нужно вернуть его как можно скорее      4
# Name: count, dtype: int64

# %% [markdown]
# На основе предоставленных данных можно сделать следующие выводы:
#
# 1. **Схожесть целей задач**
#    Большинство задач имеют повторяющиеся или схожие формулировки целей, что позволяет выделить их в общие кластеры.
#
# 2. **Явные кластеры задач**
#    Цели можно разделить на несколько основных категорий:
#    - **Поиск:** Например, "Нужно найти её как можно скорее" и "Нужно найти его как можно скорее".
#    - **Возврат:** Например, "Нужно вернуть её как можно скорее" и "Нужно вернуть его как можно скорее".
#    - **Уничтожение:** Например, "Нужно убить их", "Нужно уничтожить его" и "Нужно победить их".
#    - **Освобождение:** Например, "Нужно освободить их" и "Нужно спасти их".
#    - **Прогон:** Например, "Нужно прогнать их" и "Нужно проучить их".
#
# 3. **Разные формулировки одной цели**
#    Некоторые цели написаны разными словами, но представляют собой одно и то же действие. Например:
#    - "Нужно уничтожить их" и "Нужно их уничтожить".
#    - "Нужно убить его" и "Нужно его убить".
#
# Такое дублирование можно оптимизировать, унифицировав формулировки задач для удобства анализа и обработки.

# %% [markdown]
# Для унификации описаний целей задач применены методы нормализации и лемматизации текста. Эти подходы позволяют эффективно обработать текстовые данные, устранив избыточность и разнообразие формулировок.
#
# ## Что такое нормализация и лемматизация?
#
# 1. **Нормализация**
#    Нормализация текста включает удаление избыточных элементов, таких как:
#    - **Стоп-слова** (например, предлоги, союзы), которые не несут ключевой информации.
#    - **Знаки пунктуации**, которые не влияют на смысл текста.
#    Это позволяет сосредоточиться исключительно на значимых словах и фразах.
#
# 2. **Лемматизация**
#    Лемматизация приводит слова к их базовой форме (лемме). Например:
#    - "убить", "убийца" → "убить".
#    - "найти", "нашёл" → "найти".
#    Таким образом, все варианты написания и склонения одного слова сводятся к его основному виду, что упрощает дальнейшую обработку текста.
#
# ## Как это реализовано?
#
# Для выполнения нормализации и лемматизации был разработан специальный класс на Python. Он использует библиотеку SpaCy, которая предоставляет инструменты для анализа текста на естественном языке. Основной метод класса, `normalize_and_lemmatize`, выполняет следующие шаги:
#
# 1. Загружает предобученную модель для русского языка `ru_core_news_sm`.
# 2. Обрабатывает текст, выделяя леммы слов.
# 3. Исключает из текста стоп-слова и знаки пунктуации.
# 4. Возвращает нормализованный текст в единой унифицированной форме.

# %%
class TextCasePreprocessing():
    def __init__(self) -> None:
        self.nlp_model = spacy.load("ru_core_news_sm")

    def normalize_and_lemmatize(self, text):
        doc = self.nlp_model(text)
        normalized_text = " ".join([token.lemma_ for token in doc if not token.is_stop and not token.is_punct])
        return normalized_text

# %% [markdown]
# Преобразуем цели поручений на основе выше описанных методов:

# %%
text_preprocessor = TextCasePreprocessing()

# %%
df_cases["purpose_prep"] = df_cases["purpose"].apply(lambda x: text_preprocessor.normalize_and_lemmatize(x))
df_cases["description_prep"] = df_cases["description"].apply(lambda x: text_preprocessor.normalize_and_lemmatize(x))

# %% [markdown]
# На основе нормализованных данных целей задач можно выделить основные кластеры, представленные в таблице ниже:
# ## Первичный анализ
#
# 1. **Явные кластеры**
#    Каждый кластер представляет определённую цель задачи, например, уничтожение врагов, поиск предметов или спасение людей. Без учёта синонимов данные показывают разнообразие формулировок, которые уже нормализованы.
#
# 2. **Потенциальные объединения**
#    При детальном анализе можно заметить, что некоторые кластеры представляют схожие или даже идентичные задачи:
#    - **"Убить" и "Уничтожить":** Оба действия указывают на необходимость устранения угрозы.
#    - **"Освободить" и "Спасти":** В обоих случаях цель состоит в помощи или освобождении жертв.
#    - **"Найти" и "Вернуть":** Задачи могут подразумевать поиск и возвращение одного и того же объекта.
#
# 3. **Рекомендации по объединению**
#    Для оптимизации анализа и дальнейшей обработки данных можно объединить некоторые кластеры:
#    - Кластер **устранения угроз:** "Убить", "Уничтожить", "Победить".
#    - Кластер **помощи:** "Спасти", "Освободить".
#    - Кластер **поиска и возврата:** "Найти", "Вернуть".
#
# ## Вывод
#
# Объединение схожих кластеров позволит более точно классифицировать задачи и выявить основные направления работы. Такой подход значительно упростит дальнейшую работу с данными, обеспечив их структурированность и уменьшив избыточность.

# %%
df_cases["purpose_prep"].value_counts()
# Out:
# purpose_prep
# убить         101
# уничтожить     89
# вернуть        82
# найти          74
# прогнать       43
# освободить     34
# спасти         33
# победить       25
# проучить       19
# Name: count, dtype: int64

# %% [markdown]
# Рассмотрим предлагаемые кластеры отдельно и проведём их визуальную оценку на предмет близости формулировок и целей. Такой подход поможет понять, насколько предложенные объединения логически оправданы и соответствуют смыслу задач.
#
# ## Предлагаемые кластеры
#
# 1. **Кластер устранения угроз**
#    Включает цели:
#    - "Убить"
#    - "Уничтожить"
#    - "Победить"
#    Все формулировки объединяет одна цель — устранение противника или угрозы. Однако стоит проверить, не содержат ли данные описания специфических нюансов, которые могут повлиять на точность объединения.
#
# 2. **Кластер помощи**
#    Включает цели:
#    - "Спасти"
#    - "Освободить"
#    Оба термина подразумевают помощь или защиту. Визуальная оценка позволит определить, есть ли различия в контексте задач (например, "освободить из плена" и "спасти от монстров").
#
# 3. **Кластер поиска и возврата**
#    Включает цели:
#    - "Найти"
#    - "Вернуть"
#    Здесь объединение кажется очевидным, так как поиск часто является частью задачи по возврату. Однако нужно проверить, встречаются ли исключительные случаи, где контекст существенно отличается.
#
# 4. **Дополнительные кластеры**
#    Такие цели, как "Прогнать" и "Проучить", формируют менее крупные, но всё же значимые группы. Следует оценить их контекст на предмет возможного объединения или уточнения.
#
# ## Подход к оценке
#
# Для каждой пары целей внутри кластера:
# - Проведём визуальное сравнение описаний задач, чтобы определить степень их сходства.
# - Проверим, не содержат ли задачи контекстуальные различия, которые могут затруднить объединение.
# - Убедимся, что объединение не приведёт к потере важной информации.
#
# **Цель:** Обеспечить, чтобы предложенные кластеры были максимально точными и отражали истинные смыслы формулировок, заложенных в задачах.

# %%
#Метод отображения описаний поручений на основе их целей
def show_cases_by_purposes(purpose_list):
    return df_cases[df_cases["purpose_prep"].isin(purpose_list)][["description_prep", "purpose_prep"]]

# %% [markdown]
# ## Убить-Уничтожить-Победить"
#
# На основании анализа таблицы можно сделать вывод, что задачи, связанные с уничтожением угроз, имеют общую цель, несмотря на разнообразие формулировок. Рассмотрим ключевые особенности этого кластера.
#
# ## Общее между задачами
# 1. **Единая цель:**
#    Задачи из этого кластера сводятся к устранению угроз, будь то монстры, разбойники или звери. Например:
#    - "Пещера завелся дракон" требует действия "убить" или "уничтожить".
#    - "Лес, город, деревня, монстры нападают на человека" может подразумевать как "уничтожить", так и "победить".
#
# 2. **Контекст угрозы:**
#    Независимо от используемой формулировки, описание задачи указывает на необходимость противодействия активной опасности (нападение монстров, разбойников или животных).
#
# 3. **Вариативность формулировок:**
#    - "Уничтожить" чаще используется для описания задач, связанных с монстрами или крупными существами ("каменное чудовище", "дракон").
#    - "Убить" встречается в задачах, связанных с людьми (разбойники) или мелкими угрозами (звери).
#    - "Победить" используется для обозначения более обобщённого результата, подразумевая победу над угрозой без уточнения её формы.
#
# ## Почему кластер работает
#
# - **Контекстная близость:**
#   Независимо от точной формулировки ("убить", "уничтожить", "победить"), цель остаётся общей — устранение угрозы. Например:
#   - "Лес, город, заметить монстра" может предполагать любое из трёх действий, в зависимости от предпочтений автора задачи.
#
# - **Универсальность объединения:**
#   Объединение этих задач в один кластер позволяет эффективно анализировать их без потери значимого контекста.
#
# ## Вывод
# Кластер "Убить-Уничтожить-Победить" обладает высокой степенью логической связанности. Формулировки "убить", "уничтожить" и "победить" могут быть использованы как взаимозаменяемые для описания одной и той же цели — ликвидации угрозы. Такое объединение оправдано и не вызывает потери важной информации.

# %%
show_cases_by_purposes(["убить", "победить", "уничтожить"]).value_counts()
# Out:
# description_prep                              purpose_prep
# пещера завестись дракон                       уничтожить      34
# пещера появвилось огромный каменный чудовище  убить           27
#                                               уничтожить      26
# пещера завестись дракон                       убить           26
# лес город заметить разбойник                  убить            5
# лес город деревня видеть монстр               победить         4
# лес дорога пещера заметить монстр             победить         4
# лес дорога пещера видеть монстр               уничтожить       4
# лес деревня видеть монстр                     уничтожить       4
# лес город деревня монстр нападать человек     уничтожить       4
# город разбойник нападать человек              убить            3
# лес город видеть монстр                       уничтожить       3
# город встречаться звери                       убить            3
# лес город деревня заметить разбойник          убить            3
# лес деревня встречаться звери                 убить            3
# лес город заметить зверь                      убить            3
# лес дорога пещера заметить разбойник          убить            3
# лес дорога пещера заметить зверь              убить            3
# лес дорога пещера монстр нападать человек     победить         3
# город заметить монстр                         уничтожить       3
# город заметить зверь                          убить            3
# лес дорога пещера зверь нападать человек      убить            2
# город зверь нападать человек                  убить            2
# лес деревня монстр нападать человек           уничтожить       2
# лес дорога пещера монстр нападать человек     уничтожить       2
# лес город монстр нападать человек             победить         2
# лес город зверь нападать человек              убить            2
# лес город заметить монстр                     победить         2
# город видеть монстр                           победить         2
# дорога деревня заметить разбойник             убить            2
# дорога деревня зверь нападать человек         убить            2
# дорога деревня монстр нападать человек        уничтожить       2
# лес город встречаться звери                   убить            2
# лес город деревня разбойник нападать человек  убить            1
# лес город заметить монстр                     уничтожить       1
# город заметить монстр                         победить         1
# дорога деревня монстр нападать человек        победить         1
# лес город видеть монстр                       победить         1
# город заметить разбойник                      убить            1
# дорога деревня встречаться звери              убить            1
# лес город деревня видеть монстр               уничтожить       1
# лес дорога пещера видеть монстр               победить         1
# лес город деревня встречаться звери           убить            1
# лес деревня заметить разбойник                убить            1
# лес деревня заметить монстр                   победить         1
# лес деревня заметить зверь                    убить            1
# лес город деревня заметить зверь              убить            1
# город монстр нападать человек                 уничтожить       1
# лес деревня видеть монстр                     победить         1
# лес город деревня заметить монстр             уничтожить       1
# лес город деревня монстр нападать человек     победить         1
# дорога деревня заметить монстр                уничтожить       1
#                                               победить         1
# Name: count, dtype: int64

# %% [markdown]
# # "Спасти-Освободить"
#
# Кластер "Спасти-Освободить" объединяет задачи, связанные с оказанием помощи жертвам, которых похитили монстры. Несмотря на различия в формулировках, задачи имеют общий смысл и цель. Рассмотрим ключевые особенности этого кластера.
#
# ## Общее между задачами
#
# 1. **Единая цель:**
#    Задачи из кластера сводятся к освобождению похищенных путников из плена монстров. Например:
#    - "Город, монстр похитил путников" подразумевает либо "спасти", либо "освободить" жертв.
#    - "Дорога, деревня, монстр похитил путников" также требует действий, направленных на их возвращение.
#
# 2. **Контекст ситуации:**
#    Независимо от используемой формулировки, задачи описывают однотипный сценарий:
#    - Монстры похищают путников.
#    - Основная цель — вернуть жертв обратно.
#
# 3. **Вариативность формулировок:**
#    - "Спасти" используется чаще для эмоционально окрашенных описаний, подчеркивающих опасность для жертв.
#    - "Освободить" акцентирует внимание на физическом устранении преград или пленения, что часто встречается в описаниях вроде "освободить путников из деревни".
#
# ## Почему кластер работает
#
# - **Контекстная близость:**
#   Обе формулировки ("спасти" и "освободить") подразумевают действия по устранению угрозы и возвращению похищенных. Например:
#   - "Город, монстр похитил путников" может подразумевать как "спасти", так и "освободить", в зависимости от акцента на эмоциональной или практической стороне задачи.
#
# - **Взаимозаменяемость формулировок:**
#   Задачи с этими формулировками можно объединить в один кластер без потери смысла, так как обе цели представляют одну и ту же конечную задачу — помощь жертвам.
#
# ## Вывод
#
# Кластер "Спасти-Освободить" логически обоснован. Независимо от использования слов "спасти" или "освободить", задача остаётся одной и той же: устранить угрозу и помочь похищенным путникам. Объединение этих задач в общий кластер позволяет упорядочить данные и избежать дублирования.

# %%
show_cases_by_purposes(["спасти", "освободить"]).value_counts()
# Out:
# description_prep                       purpose_prep
# город монстр похитить путник           спасти          15
# дорога деревня монстр похитить путник  освободить      13
# город монстр похитить путник           освободить      12
# деревня монстр похитить путник         спасти          10
#                                        освободить       9
# дорога деревня монстр похитить путник  спасти           8
# Name: count, dtype: int64

# %% [markdown]
# # "Найти-Вернуть"
#
# Кластер "Найти-Вернуть" объединяет задачи, связанные с поиском и возвратом утерянных или украденных вещей. Несмотря на различия в формулировках, все задачи имеют схожую конечную цель: обнаружить пропавший предмет и вернуть его владельцу. Рассмотрим ключевые особенности этого кластера.
#
# ## Общее между задачами
#
# 1. **Единая цель:**
#    Все задачи направлены на поиск или возврат пропавших вещей, таких как:
#    - "Сумка с документами"
#    - "Рюкзак"
#    - "Драгоценность"
#
# 2. **Контекст ситуации:**
#    Сценарии, описанные в задачах, варьируются, но их суть остаётся неизменной:
#    - **Пропажа:** Предмет был потерян или забыт.
#    - **Кража:** Предмет был похищен, и его необходимо вернуть.
#
# 3. **Вариативность формулировок:**
#    - "Найти" чаще используется, когда акцент делается на сам процесс обнаружения предмета.
#    - "Вернуть" подразумевает конечный результат, связанный с передачей предмета обратно владельцу.
#
# ## Почему кластер работает
#
# - **Контекстная близость:**
#   Описание задач, как правило, указывает на одну и ту же последовательность действий:
#   - Поиск предмета (найти).
#   - Возврат владельцу (вернуть).
#   Например, "город, пропала сумка с документами" может предполагать как "найти", так и "вернуть", в зависимости от фокусировки на этапе задачи.
#
# - **Логическая взаимосвязь:**
#   Задачи с формулировками "найти" и "вернуть" практически всегда связаны друг с другом, так как возврат предполагает предварительный поиск.
#
# ## Вывод
#
# Кластер "Найти-Вернуть" является логически оправданным объединением. Несмотря на различия в акцентах (поиск или результат), обе формулировки представляют собой этапы одной задачи: обнаружить пропавшую вещь и вернуть её владельцу. Объединение этих задач упрощает их анализ и устранение дублирования.

# %%
show_cases_by_purposes(["найти", "вернуть"]).value_counts()
# Out:
# description_prep                          purpose_prep
# город пропасть драгоценность              вернуть         11
# город пропасть рюкзак                     вернуть          7
# деревня украсть сумка документ            вернуть          6
# город потеряться сумка документ           вернуть          6
#                                           найти            6
# город пропасть рюкзак                     найти            6
# город пропасть сумка документ             вернуть          6
# город украсть драгоценность               найти            6
# город украсть рюкзак                      вернуть          6
#                                           найти            5
# город потеряться рюкзак                   найти            5
# город потеряться драгоценность            найти            5
# город украсть сумка документ              найти            5
# деревня украсть рюкзак                    вернуть          4
# город украсть сумка документ              вернуть          4
# город потеряться драгоценность            вернуть          4
# город украсть драгоценность               вернуть          4
# город пропасть драгоценность              найти            4
# город потеряться рюкзак                   вернуть          4
# дорога деревня украсть драгоценность      найти            3
#                                           вернуть          3
# дорога деревня пропасть драгоценность     вернуть          3
# деревня пропасть рюкзак                   вернуть          3
# дорога деревня потеряться драгоценность   найти            3
# деревня украсть рюкзак                    найти            3
# дорога деревня украсть рюкзак             вернуть          2
# дорога деревня пропасть сумка документ    найти            2
# дорога деревня пропасть рюкзак            найти            2
# дорога деревня пропасть драгоценность     найти            2
# дорога деревня потеряться драгоценность   вернуть          2
# деревня пропасть драгоценность            найти            2
# деревня украсть драгоценность             найти            2
# деревня пропасть рюкзак                   найти            2
# деревня пропасть сумка документ           найти            2
# деревня потеряться сумка документ         найти            2
#                                           вернуть          2
# дорога деревня потеряться сумка документ  найти            1
# деревня пропасть драгоценность            вернуть          1
# деревня пропасть сумка документ           вернуть          1
# деревня украсть сумка документ            найти            1
# дорога деревня пропасть сумка документ    вернуть          1
# деревня потеряться рюкзак                 найти            1
#                                           вернуть          1
# деревня потеряться драгоценность          найти            1
# город пропасть сумка документ             найти            1
# дорога деревня украсть рюкзак             найти            1
# дорога деревня украсть сумка документ     вернуть          1
#                                           найти            1
# Name: count, dtype: int64

# %% [markdown]
# # "Прогнать-Проучить"
#
# Кластер "Прогнать-Проучить" объединяет задачи, связанные с устранением угрозы, будь то разбойники или звери. Несмотря на различие в формулировках, все задачи подразумевают необходимость избавления от источника проблемы. Рассмотрим основные особенности этого кластера.
#
# ## Общее между задачами
#
# 1. **Единая цель:**
#    Все задачи сводятся к устранению присутствия или влияния нежелательных элементов:
#    - Разбойники, замеченные в лесу, деревне или на дороге.
#    - Звери, нападающие на людей или встречающиеся на пути.
#
# 2. **Контекст ситуации:**
#    Формулировки описывают разные степени воздействия:
#    - **Прогнать:** Указание на удаление угрозы без акцента на суровости действия.
#    - **Проучить:** Подразумевает наказание или применение силы с целью предупреждения повторных действий.
#
# 3. **Вариативность формулировок:**
#    - "Прогнать" чаще используется для описания задачи, где требуется лишь устранить проблему.
#    - "Проучить" акцентирует внимание на наказании или преподнесении урока, особенно в отношении разбойников.
#
# ## Почему кластер работает
#
# - **Контекстная близость:**
#   Независимо от выбранного термина, обе формулировки относятся к задачам устранения угрозы. Например:
#   - "Лес, город, заметить разбойников" может подразумевать как "прогнать" (удалить угрозу), так и "проучить" (наказать).
#
# - **Логическая взаимосвязь:**
#   В большинстве случаев проучивание автоматически включает удаление угрозы. Поэтому объединение задач "прогнать" и "проучить" обосновано.
#
# ## Вывод
#
# Кластер "Прогнать-Проучить" логически оправдан, так как обе формулировки описывают действия, направленные на устранение угрозы. Различия между "прогнать" и "проучить" в основном связаны с уровнем воздействия, но конечная цель остаётся одной и той же. Объединение этих задач в общий кластер помогает упростить анализ и повысить точность обработки данных.

# %%
show_cases_by_purposes(["прогнать", "проучить"]).value_counts()
# Out:
# description_prep                              purpose_prep
# лес город деревня заметить разбойник          прогнать        5
# лес город заметить разбойник                  проучить        4
# лес дорога пещера зверь нападать человек      прогнать        3
# город заметить разбойник                      прогнать        3
# лес дорога пещера заметить зверь              прогнать        3
# лес дорога пещера встречаться звери           прогнать        3
# лес деревня разбойник нападать человек        прогнать        2
# лес город заметить разбойник                  прогнать        2
# лес деревня заметить зверь                    прогнать        2
# лес деревня заметить разбойник                проучить        2
# лес город деревня заметить разбойник          проучить        2
# лес деревня разбойник нападать человек        проучить        2
# дорога деревня разбойник нападать человек     прогнать        2
# дорога деревня заметить разбойник             проучить        2
# дорога деревня встречаться звери              прогнать        2
# лес дорога пещера заметить разбойник          проучить        2
# лес деревня встречаться звери                 прогнать        1
# лес деревня зверь нападать человек            прогнать        1
# лес дорога пещера заметить разбойник          прогнать        1
# лес деревня заметить разбойник                прогнать        1
# лес дорога пещера разбойник нападать человек  прогнать        1
# город заметить зверь                          прогнать        1
# лес город деревня разбойник нападать человек  проучить        1
# лес город разбойник нападать человек          проучить        1
# лес город заметить зверь                      прогнать        1
# лес город деревня разбойник нападать человек  прогнать        1
# лес город деревня звери нападать человек      прогнать        1
# лес город деревня заметить зверь              прогнать        1
# лес город деревня встречаться звери           прогнать        1
# дорога деревня разбойник нападать человек     проучить        1
# дорога деревня зверь нападать человек         прогнать        1
# дорога деревня заметить разбойник             прогнать        1
# дорога деревня заметить зверь                 прогнать        1
# город разбойник нападать человек              прогнать        1
# город зверь нападать человек                  прогнать        1
# город заметить разбойник                      проучить        1
# лес дорога пещера разбойник нападать человек  проучить        1
# Name: count, dtype: int64

# %% [markdown]
# ### Формирование основных кластеров поручений
#
# На основе анализа задач удалось выделить 4 основных кластера целей:
#
# 1. **Убить-Победить-Уничтожить**
# 2. **Спасти-Освободить**
# 3. **Вернуть-Найти**
# 4. **Прогнать-Проучить**
#
# Эти кластеры объединили схожие задачи, выраженные разными словами, в логически связанные группы.
#
# Для работы с этими кластерами используется структура `synonym_cliques`:
#
# ```python
# synonym_cliques = [
#     "убить-победить-уничтожить",
#     "спасти-освободить",
#     "вернуть-найти",
#     "прогнать-проучить"
# ]
#
# На основе этих кластеров был разработан метод `get_synonym_dict`, который автоматически формирует словарь синонимов. Этот словарь устанавливает правила замены, позволяя нормализовать цели задач.

# %%
def get_synonym_dict(synonym_cliques):
    synonym_dict = {}

    for clique in synonym_cliques:
        for word in clique.split("-"):
            synonym_dict[word] = clique
    return synonym_dict

# %%
synonym_cliques = [
    "убить-победить-уничтожить",
    "спасти-освободить",
    "вернуть-найти",
    "прогнать-проучить"
]

# %%
synonym_dict = get_synonym_dict(synonym_cliques)
synonym_dict
# Out:
# {'убить': 'убить-победить-уничтожить',
#  'победить': 'убить-победить-уничтожить',
#  'уничтожить': 'убить-победить-уничтожить',
#  'спасти': 'спасти-освободить',
#  'освободить': 'спасти-освободить',
#  'вернуть': 'вернуть-найти',
#  'найти': 'вернуть-найти',
#  'прогнать': 'прогнать-проучить',
#  'проучить': 'прогнать-проучить'}

# %% [markdown]
# Замена названия цели на соотвествующий кластер

# %%
df_cases["common_purpose"] = df_cases["purpose_prep"].map(synonym_dict)

# %%
df_cases.head(4)
# Out:
#    Номер поручения Заказчик Дата поручения Выполнено Дата выполнения  \
# 0            11000     Анна     1051-08-11        да      1051-08-21
# 1            11001    Мария     1051-07-09        да      1051-09-02
# 2            11002   Эмилио     1053-10-05        да      1053-10-20
# 3            11003   Бьянка     1052-11-24        да      1052-12-02
#
#    Затрачено дней  Сумма вознаграждения  \
# 0             4.0                  6000
# 1             2.0                 20000
# 2             7.0                 22500
# 3             5.0                  5500
#
#                                             Описание  \
# 0  В лесу по дороге от пещеры звери нападают на л...
# 1  В лесу по дороге от пещеры были замечены разбо...
# 2  По дороге из деревни монстры похитили путников...
# 3  Недалеко от города видели монстров. Нужно побе...
#
#                                          description  \
# 0  В лесу по дороге от пещеры звери нападают на л...
# 1  В лесу по дороге от пещеры были замечены разбо...
# 2     По дороге из деревни монстры похитили путников
# 3                 Недалеко от города видели монстров
#
#                                               advice              purpose  \
# 0  Осмотрите все возможные укрытия, чтобы найти з...       Нужно убить их
# 1  Будьте осторожны, так как разбойники могут быт...       Нужно убить их
# 2  Осмотрите все возможные укрытия, чтобы найти п...  Нужно освободить их
# 3  Будьте осторожны, так как монстры могут быть о...    Нужно победить их
#
#   purpose_prep                          description_prep  \
# 0        убить  лес дорога пещера зверь нападать человек
# 1        убить      лес дорога пещера заметить разбойник
# 2   освободить     дорога деревня монстр похитить путник
# 3     победить                       город видеть монстр
#
#               common_purpose
# 0  убить-победить-уничтожить
# 1  убить-победить-уничтожить
# 2          спасти-освободить
# 3  убить-победить-уничтожить

# %% [markdown]
# Анализ данных показывает, что задачи можно разделить на 4 основных кластера целей. Их частота встречаемости подтверждает ключевые направления поручений:
#
# #### 1. **Убить-Победить-Уничтожить**
# Это наиболее распространённый кластер поручений. Он включает задачи, связанные с устранением угроз в виде монстров, разбойников или зверей.
# Такие поручения составляют 36% от общего числа, что подчеркивает важность борьбы с опасностью в окружающем мире.
#
# #### 2. **Вернуть-Найти**
# Второй по популярности кластер. Задачи этой группы связаны с поиском и возвратом пропавших или украденных вещей.
# Доля этого кластера составляет 26%, что делает его важным направлением поручений.
#
# #### 3. **Спасти-Освободить**
# Кластер охватывает задачи, направленные на спасение или освобождение похищенных путников.
# Частота встречаемости этих поручений составляет 11%, что отражает их значимость, хотя и меньшую, чем у первых двух кластеров.
#
# #### 4. **Прогнать-Проучить**
# Наименее частый кластер, который включает задачи по устранению угрозы в виде разбойников или зверей, без полного их уничтожения.
# Его доля составляет 10% от общего числа поручений.
#
# ### Вывод
# Частота встречаемости показывает, что наибольшее внимание уделяется устранению угроз и поиску пропавших вещей. Задачи спасения и проучивания встречаются реже, но их важность остаётся значительной. Это распределение подчёркивает ключевые направления поручений, которые могут служить основой для дальнейшей унификации и анализа.

# %%
df_cases["common_purpose"].value_counts()
# Out:
# common_purpose
# убить-победить-уничтожить    215
# вернуть-найти                156
# спасти-освободить             67
# прогнать-проучить             62
# Name: count, dtype: int64

# %% [markdown]
# ### Определение кластеров и необходимость детализации
#
# Мы выявили явные кластеры-цели поручений, которые отражают основные направления задач. Однако, для полного анализа необходимо дополнительно определить **объект**, над которым или от которого нужно выполнить указанную цель.
#
# #### Зачем это нужно?
# Цели, такие как "убить", "вернуть" или "спасти", сами по себе не дают полной картины без уточнения:
# - Кто или что является объектом? (например, "монстр", "рюкзак", "путник").
# - Где находится этот объект? (например, "в лесу", "в городе", "на дороге").
#
# #### Следующий шаг
# Определение объекта и его характеристик позволит:
# - Уточнить описание поручений.
# - Упростить их классификацию.
# - Выявить дополнительные закономерности в данных.
#
# Таким образом, вместе с целями важно учитывать и объекты, чтобы построить более точную и детализированную модель анализа.

# %% [markdown]
# ### Извлечение объекта из описания
#
# Для определения объекта, над которым или от которого нужно выполнить цель, был использовали метод автоматического извлечения информации с помощью трансформера. Эта задача решается с использованием библиотеки **Hugging Face Transformers** и предобученной модели **ruselkomp/deep-pavlov-full**, настроенной на задачу "вопрос-ответ".
#
# #### Как это работает?
#
# 1. **Что такое модель "вопрос-ответ"?**
#    Это алгоритм, который принимает текст (описание задачи) и вопрос, а затем возвращает наиболее вероятный ответ, найденный в тексте. Например:
#    - Текст: "Лес, город, дракон похитил путников."
#    - Вопрос: "Кто является объектом задачи?"
#    - Ответ: "дракон".
#
# 2. **Используемая модель**
#    Модель **ruselkomp/deep-pavlov-full** обучена на русском языке для задачи "вопрос-ответ". Она анализирует текст, выделяет ключевые фрагменты и предоставляет ответ на заданный вопрос.
#
# 3. **Как применяется в задаче?**
#    Задаётся вопрос, который помогает извлечь объект из текста описания. Например:
#    - Вопрос: "Какой объект упоминается в задаче?"
#    Для каждого текста модель возвращает ключевой объект, связанный с целью поручения.

# %%
#Инициализация модели
description_answering_pipline = pipeline(task="question-answering", model="ruselkomp/deep-pavlov-full")

# %% [markdown]
# ### Формирование вопросов на основе кластеров
#
# Для каждого поручения на вход подаётся его описание. В зависимости от принадлежности цели задачи к определённому кластеру, формируется соответствующий вопрос, который помогает извлечь из текста ключевой объект. Этот подход позволяет задать более точный и релевантный контекст для модели "вопрос-ответ".
#
# #### Логика формирования вопросов
#
# 1. **Кластер "Спасти-Освободить"**
#    Если цель задачи относится к кластеру "спасти-освободить", задаётся вопрос:
#    **"Кто напал на тех, кого надо освободить или спасти?"**
#    Этот вопрос помогает выявить нападающих (например, монстров или разбойников), чтобы уточнить, от кого необходимо защитить жертв.
#
# 2. **Кластер "Вернуть-Найти"**
#    Для задач из этого кластера формируется вопрос:
#    **"Что нужно вернуть или найти?"**
#    Такой подход позволяет определить, какой именно объект требуется обнаружить (например, драгоценности, рюкзак или документы).
#
# 3. **Другие кластеры**
#    Если цель задачи не относится к первым двум кластерам (например, "убить-победить-уничтожить" или "прогнать-проучить"), задаётся вопрос:
#    **"Кто опасен и кто нападает?"**
#    Это позволяет определить угрозу или объект, от которого нужно избавиться (например, монстра, зверя или разбойников).
#
# #### Пример работы
# Каждое описание поручения анализируется индивидуально, а соответствующий вопрос помогает модели точно определить ключевой объект. Это делает процесс более гибким и универсальным, адаптированным под каждый тип задачи.

# %%
def get_object_description(model, description, purpose):
    if purpose == "спасти-освободить":
        question_ = "Кто напал на тех, кого надо освободить-спасти?"
    elif purpose == "вернуть-найти":
        question_ = "Что нужно вернуть-найти?"
    else: question_ = "Кто опасен и кто нападает?"

    return model(
        question=question_,
        context=description
    )["answer"]

# %%
description_objects = [get_object_description(
        description_answering_pipline,
        descp,
        purp
    )
    for descp, purp in df_cases[["description", "common_purpose"]].values]

# %% [markdown]
# После того как были получены **объекты**, необходимо их также нормализовать и лемматизировать:

# %%
df_cases["description_object"] = description_objects
df_cases["description_object"] = df_cases["description_object"].apply(text_preprocessor.normalize_and_lemmatize)

# %% [markdown]
# ### Структурирование поручений на основе целей и объектов
#
# В результате анализа удалось выделить основные кластеры поручений, сгруппированные по их целям и объектам. Этот подход позволил систематизировать задачи и придать данным чёткую структуру:
#
# 1. **Кластеры целей:**
#    Задачи разделены на группы по их целям, такие как "убить-победить-уничтожить", "спасти-освободить", "вернуть-найти", "прогнать-проучить".
#
# 2. **Определение объектов:**
#    Для каждой цели извлечены ключевые объекты, такие как "монстр", "рюкзак", "дракон". Это помогло уточнить контекст поручений и их специфику.
#
# #### Обработка выбросов
#
# В процессе анализа был выявлен выброс: описание "звери нападают на человека". Этот случай не соответствует стандартным кластерам и был обработан вручную для корректного включения в данные.
#
# #### Автоматизация нормализации
#
# После извлечения объектов выполнена нормализация данных для унификации текста. Этот шаг обеспечил единообразие описаний и упростил дальнейшую обработку.

# %%
df_cases[["common_purpose"	,"description_object"]].value_counts()
# Out:
# common_purpose             description_object
# спасти-освободить          монстр                        67
# убить-победить-уничтожить  дракон                        60
# вернуть-найти              драгоценность                 56
# убить-победить-уничтожить  монстр                        54
#                            огромный каменный чудовище    53
# вернуть-найти              рюкзак                        52
#                            сумка документ                48
# прогнать-проучить          разбойник                     39
# убить-победить-уничтожить  зверь                         29
# прогнать-проучить          зверь                         23
# убить-победить-уничтожить  разбойник                     19
# Name: count, dtype: int64

# %% [markdown]
# Замена выброса:

# %%
df_cases["description_object"] = df_cases["description_object"].replace("звери нападать человек", "зверь")

# %% [markdown]
# ### Анализ ценообразования
#
# На основе предоставленных данных проведён анализ ценообразования для различных комбинаций кластеров целей и объектов. Основное внимание уделено тому, как средние значения (mean) и медианы (median) варьируются в зависимости от целей и объектов.
#
# ---
#
# #### Варьирование средних значений
#
# - **Максимальная средняя стоимость** наблюдается для задач:
#   - Убить монстра: **18,259**.
#   - Прогнать разбойников: **18,065**.
# - **Минимальная средняя стоимость**:
#   - Убить разбойников: **14,394**.
#
# Разница между самой дорогой и самой дешёвой средней стоимостью составляет около **3,865**, что указывает на умеренную вариацию.
#
# #### Варьирование медиан
#
# - Медианы имеют меньшее разброс:
#   - Максимальная медиана: убить монстра (18,500).
#   - Минимальная медиана: убить разбойников (13,000).
# - Разница между максимальной и минимальной медианой составляет **5,500**, что указывает на сильное влияние объекта на восприятие ценности задачи.
#
# ---
#
# ### Обнаруженные зависимости
#
# 1. **Цели "убить-победить-уничтожить"**
#    - Стоимость задач зависит от объекта:
#      - Убийство разбойников стоит существенно меньше (mean: 14,394), чем убийство монстров (mean: 18,259).
#      - Убийство дракона и зверя имеют схожую стоимость (около 16,400).
#
# 2. **Цели "вернуть-найти"**
#    - Ценности задач на поиск вещей зависят от объекта:
#      - Драгоценности имеют максимальную среднюю стоимость (18,040).
#      - Рюкзак и сумка с документами оцениваются дешевле, но их стоимость близка (mean около 15,800–17,400).
#
# 3. **Цели "прогнать-проучить"**
#    - Разбойники имеют более высокую стоимость (mean: 18,065) по сравнению со зверями (mean: 16,022).
#
# 4. **Цели "спасти-освободить"**
#    - Монстры оцениваются относительно высоко (mean: 16,782), что сравнимо со стоимостью убийства более опасных объектов.
#
# ---
#
# ### Выводы
#
# - **Сильная зависимость от объекта:** Стоимость задачи варьируется значительно в зависимости от её цели и объекта. Например, убийство монстра стоит значительно дороже, чем убийство разбойников, а возврат драгоценностей ценится выше, чем возврат рюкзаков.
# - **Медианы стабилизируют распределение:** Несмотря на различия в средних значениях, медианы указывают на меньшее варьирование внутри групп задач.
# - **Цели "убить" и "прогнать" наиболее подвержены изменению стоимости в зависимости от сложности объекта.**
#
# Общая структура ценообразования относительно стабильна, однако объекты оказывают значительное влияние на итоговую оценку задачи.
#
# ### Зависимость от заказчика
#
# Поскольку медианы не сильно разбросаны, можно сделать вывод, что влияние заказчика на цену задачи незначительно. Цены преимущественно зависят от цели и объекта задачи, а не от того, кто сделал заказ.

# %%
cluster_stats = df_cases[df_cases["Выполнено"]=="да"].groupby(["common_purpose", "description_object"])['Сумма вознаграждения'].agg(['mean', 'median']).reset_index()
cluster_stats
# Out:
#                common_purpose          description_object          mean  \
# 0               вернуть-найти               драгоценность  18040.000000
# 1               вернуть-найти                      рюкзак  17400.000000
# 2               вернуть-найти              сумка документ  15885.416667
# 3           прогнать-проучить                       зверь  16022.727273
# 4           прогнать-проучить                   разбойник  18065.789474
# 5           спасти-освободить                      монстр  16782.258065
# 6   убить-победить-уничтожить                      дракон  16635.593220
# 7   убить-победить-уничтожить                       зверь  16428.571429
# 8   убить-победить-уничтожить                      монстр  18259.259259
# 9   убить-победить-уничтожить  огромный каменный чудовище  16186.274510
# 10  убить-победить-уничтожить                   разбойник  14394.736842
#
#      median
# 0   15750.0
# 1   16500.0
# 2   15750.0
# 3   16250.0
# 4   20750.0
# 5   15500.0
# 6   16500.0
# 7   17500.0
# 8   18500.0
# 9   15500.0
# 10  13000.0

# %% [markdown]
# ## 1.2 Дневники + оценки потребителей

# %%
df_diaries = pd.read_csv("../data/diaries.csv", delimiter=";", encoding='utf-8-sig', decimal=",")

# %%
df_diaries.head(4)
# Out:
#    Номер поручения    Герой Запись в дневнике  Затрачено часов      Роль
# 0            11000   Мартин    разжечь костёр              1.0  рейнджер
# 1            11000   Мартин    выследить цель              6.0  следопыт
# 2            11001  Альфред    разжечь костёр              1.0  рейнджер
# 3            11001  Альфред     залечить раны             18.0    лекарь

# %% [markdown]
# #### Структурированность и ответственность героев
#
# На основании анализа дневниковых записей можно сделать вывод, что герои подходят к документированию своих задач крайне ответственно. Все записи выполняются без использования синонимов, в строго унифицированной форме. Например, действие "разжечь костёр" фиксируется одинаково, независимо от героя или контекста. Это позволяет легко интерпретировать и классифицировать их задачи.
#
#
#
# #### Оценка задач по ролям героев
#
# Для анализа задач было использовано агрегирование по героям, их ролям и записям в дневнике. Этот подход позволил оценить, какие действия могут выполнять представители каждой роли.
#
# #### Выводы
#
# 1. **Унифицированные записи**
#    Все действия фиксируются героически четко и без вариаций в формулировках. Это упрощает анализ их работы и позволяет исключить двусмысленности.
#
# 2. **Распределение задач по ролям**
#    Каждая роль выполняет специфические задачи:
#    - **Рейнджеры, Лучники, Боевые маги, Мечники:** Выполняют задания, связанные с поддержанием выживания, такие как "разжечь костёр".
#    - **Следопыты:** Занимаются поисковыми задачами, такими как "выследить цель", "найти пропажу", "отыскать заказ".
#    - **Лекари:** Сосредотачиваются на помощи команде, например, "залечить раны".
#
# 3. **Агрегация данных**
#    Сгруппированные данные позволяют понять вклад каждого героя и его роли в выполнении поручений, а также оценить затраты времени на разные действия.

# %%
df_roles_tasks = df_diaries.groupby(["Герой", "Роль"])["Запись в дневнике"].apply(set).reset_index()
df_roles_tasks["Запись в дневнике"] = df_roles_tasks["Запись в дневнике"].map(sorted).map(tuple)

df_roles_skills = df_roles_tasks.groupby('Роль')['Запись в дневнике'].unique().reset_index()
df_roles_skills["Уникальное число способностей"] = df_roles_skills["Запись в дневнике"].apply(len)

# %%
df_roles_skills["Запись в дневнике"] = df_roles_skills["Запись в дневнике"].map(lambda x: list(x[0]))

# %%
df_roles_skills
# Out:
#          Роль                                  Запись в дневнике  \
# 0  боевой маг                                   [разжечь костёр]
# 1      лекарь                                    [залечить раны]
# 2      лучник                                   [разжечь костёр]
# 3      мечник                                   [разжечь костёр]
# 4    рейнджер                                   [разжечь костёр]
# 5    следопыт  [выследить цель, найти пропажу, отыскать заказ...
#
#    Уникальное число способностей
# 0                              1
# 1                              1
# 2                              1
# 3                              1
# 4                              1
# 5                              1

# %% [markdown]
# Рассмотрим оценки героев

# %%
df_marks = pd.read_csv("../data/marks.csv", delimiter=";", encoding='utf-8-sig', decimal=",")

# %%
df_marks.head()
# Out:
#    Номер поручения    Герой  Оценка за качество  Оценка по срокам  \
# 0            11000   Мартин                   4                 3
# 1            11001  Альфред                   5                 5
# 2            11002   Мартин                   5                 4
# 3            11003   Бендер                   2                 4
# 4            11004     Юлия                   4                 4
#
#    Оценка за вежливость
# 0                     4
# 1                     4
# 2                     4
# 3                     3
# 4                     5

# %% [markdown]
# ### Анализ оценок героев
#
# При анализе средних оценок героев без учёта их ролей и кластеров можно заметить, что значения для большинства показателей находятся в узком диапазоне. Это приводит к минимальным различиям между героями, что затрудняет выделение их уникальных характеристик.
#
# ---
#
# #### Наблюдения
#
# 1. **Близость средних оценок**
#    Все оценки за качество, сроки и вежливость находятся в диапазоне **3.67–4.00**, что свидетельствует о схожем уровне выполнения задач среди героев. Например:
#    - **Оценка за качество** варьируется от **3.78** (Бенедикт) до **4.00** (Пастушок).
#    - **Оценка по срокам** колеблется от **3.67** (Юлия) до **4.00** (Фредерик).
#    - **Оценка за вежливость** имеет небольшой разброс от **3.83** (Соня) до **4.00** (Глюкоза, Пастушок).
#
# 2. **Отсутствие значимой дифференциации**
#    Из-за близости значений средних оценок становится сложно определить сильные и слабые стороны каждого героя. Это снижает ценность анализа, если не учитывать дополнительные факторы.
#
# ---
#
# #### Учёт ролей и кластеров
#
# Чтобы сделать анализ более значимым, необходимо учитывать:
# - **Роли героев:** Разные роли предполагают выполнение различных типов задач, что может влиять на их оценки. Например, от рейнджеров могут ожидать более высоких оценок по срокам, а от лекарей — по вежливости.
# - **Кластеры задач:** Учитывая специфику поручений, можно оценивать героев не только в общем, но и по средним показателям в их ключевых задачах.
#
# ---
#
# #### Преимущества кластеризации
#
# - **Повышение точности анализа:** Учитывая роли и кластеры, можно выявить сильные стороны героев в их специализированных задачах.
# - **Выявление слабых мест:** Анализ по ролям помогает понять, в каких аспектах конкретные герои нуждаются в улучшении.
# - **Целевая обратная связь:** Средние оценки по ролям дают более точную информацию для развития каждого героя.
#
# Таким образом, без учёта ролей и кластеров средние оценки теряют аналитическую ценность, что делает кластеризацию необходимым этапом анализа.

# %%
df_mean_scores_heroes = df_marks.groupby(["Герой"]).agg(
    {
        "Оценка за качество": "mean",
        "Оценка по срокам": "mean",
        "Оценка за вежливость": "mean"
    }
).reset_index()

# %%
df_mean_scores_heroes
# Out:
#          Герой  Оценка за качество  Оценка по срокам  Оценка за вежливость
# 0        Агата            3.939394          3.727273              4.000000
# 1      Альфред            3.871795          3.692308              3.897436
# 2       Бендер            3.928571          3.928571              3.928571
# 3     Бенедикт            3.785714          3.880952              3.928571
# 4      Глюкоза            3.863636          3.931818              4.000000
# 5     Леопольд            3.893617          3.808511              3.872340
# 6       Мартин            3.967742          3.935484              3.935484
# 7     Пастушок            4.000000          3.836735              4.000000
# 8   Синеглазый            3.878049          3.756098              3.878049
# 9         Соня            3.888889          3.972222              3.833333
# 10    Фредерик            3.878049          4.000000              3.878049
# 11        Юлия            3.818182          3.672727              3.945455

# %% [markdown]
# ### Агрегация данных по ролям
#
# Для более глубокого анализа был проведён процесс агрегации данных, позволяющий определить, какие роли выполнял каждый герой в различных поручениях. Этот подход помогает связать действия героев с их ролями и оценить их вклад в выполнение задач.
#
# ---
#
# #### Задачи агрегации
#
# 1. **Выявление ролей героев**
#    Сгруппированы данные, чтобы увидеть, как герои распределяли свои усилия между разными ролями. Например:
#    - Один герой мог выступать как рейнджер в одном поручении и как лекарь в другом.
#    - Выявлены специфические задачи, наиболее часто выполняемые каждой ролью.
#
# 2. **Связь ролей с поручениями**
#    Для каждого поручения определено, какие роли были задействованы. Это позволяет понять, какие именно действия выполнялись в зависимости от задачи.
#
# #### Выводы
#
# 1. **Разнообразие ролей**
#    Герои часто выполняют несколько ролей в рамках одного или разных поручений.
#
# 2. **Оптимизация ресурсов**
#    Агрегация помогает выявить, какие роли требуются для выполнения различных задач, что способствует более эффективному распределению усилий.
#
# 3. **База для дальнейшего анализа**
#    Эта структура данных позволяет изучить:
#    - Средние показатели героев в каждой роли.
#    - Зависимость успеха поручения от распределения ролей.
#
# Агрегация данных по ролям оказалась полезным инструментом для понимания вклада героев в выполнение поручений и дальнейшей оптимизации их работы.

# %%
df_diaries_heroes_agg = df_diaries.groupby(['Номер поручения', 'Герой']).agg({'Роль': lambda x: list(x)}).reset_index()
df_diaries_heroes_agg["solo"] = df_diaries_heroes_agg["Роль"].apply(lambda x: 1 if len(x) == 1 else 0)

# %%
df_diaries_heroes_agg
# Out:
#      Номер поручения       Герой                          Роль  solo
# 0              11000      Мартин  [рейнджер, следопыт, лучник]     0
# 1              11001     Альфред    [рейнджер, лекарь, мечник]     0
# 2              11002      Мартин                    [следопыт]     1
# 3              11003      Бендер                      [мечник]     1
# 4              11004        Юлия          [следопыт, следопыт]     0
# ..               ...         ...                           ...   ...
# 476            11495  Синеглазый    [рейнджер, лекарь, мечник]     0
# 477            11496        Юлия    [рейнджер, лекарь, мечник]     0
# 478            11497    Пастушок            [рейнджер, мечник]     0
# 479            11498      Мартин            [рейнджер, лучник]     0
# 480            11499     Глюкоза        [рейнджер, боевой маг]     0
#
# [481 rows x 4 columns]

# %% [markdown]
# ### Обогащение данных для дальнейшего анализа
#
# После агрегации данных по ролям к полученной таблице были добавлены дополнительные данные, включая оценки и кластеры (цель и объект), к которым относится каждое поручение. Это позволило значительно расширить возможности анализа и выявить новые закономерности.
#
# ---
#
# #### Было добавлено:
#
# 1. **Оценки выполнения задач:**
#    Для каждой записи добавлены средние оценки героев:
#    - **Оценка за качество.**
#    - **Оценка по срокам.**
#    - **Оценка за вежливость.**
#    Эти данные позволяют оценить эффективность выполнения поручений в разрезе ролей и кластеров.
#
# 2. **Кластеризация поручений:**
#    Каждое поручение было отнесено к одному из кластеров, определённых ранее:
#    - Цель задачи (например, "убить-победить-уничтожить", "вернуть-найти").
#    - Объект задачи (например, "монстр", "рюкзак", "дракон").
#    Это добавление позволяет более точно анализировать, как различные роли справляются с разными типами задач.
#
#
# #### Преимущества добавления данных
#
# 1. **Анализ производительности по ролям и задачам:**
#    Теперь можно определить, как конкретные роли справляются с определёнными целями и объектами задач. Например, рейнджеры могут иметь более высокие оценки за выполнение задач, связанных с разведкой, чем с боевыми действиями.
#
# 2. **Выявление сильных и слабых сторон:**
#    Дополнительные данные помогают анализировать, какие роли и герои лучше всего подходят для выполнения конкретных типов поручений.
#
# 3. **Обоснованное распределение ролей:**
#    С учётом оценок и кластеров становится возможным предсказать, какие роли и герои будут наиболее эффективны в будущих поручениях.
#
#
#
# Добавление оценок и кластеров сделало таблицу более информативной и позволило подготовить данные для дальнейшего анализа и оптимизации распределения задач между героями.

# %%
df_heroes_w_marks = pd.merge(
    pd.merge(df_diaries_heroes_agg, 
         df_cases[df_cases["Выполнено"]=="да"][["Номер поручения", "common_purpose", "description_object"]],
         on="Номер поручения",
         how = "outer"),
    df_marks,
    on="Номер поручения",
    how="outer"
)

# %%
df_heroes_w_marks.head(5)
# Out:
#    Номер поручения  Герой_x                          Роль  solo  \
# 0            11000   Мартин  [рейнджер, следопыт, лучник]   0.0
# 1            11001  Альфред    [рейнджер, лекарь, мечник]   0.0
# 2            11002   Мартин                    [следопыт]   1.0
# 3            11003   Бендер                      [мечник]   1.0
# 4            11004     Юлия          [следопыт, следопыт]   0.0
#
#               common_purpose description_object  Герой_y  Оценка за качество  \
# 0  убить-победить-уничтожить              зверь   Мартин                   4
# 1  убить-победить-уничтожить          разбойник  Альфред                   5
# 2          спасти-освободить             монстр   Мартин                   5
# 3  убить-победить-уничтожить             монстр   Бендер                   2
# 4              вернуть-найти     сумка документ     Юлия                   4
#
#    Оценка по срокам  Оценка за вежливость
# 0                 3                     4
# 1                 5                     4
# 2                 4                     4
# 3                 4                     3
# 4                 4                     5

# %% [markdown]
# ### Учет сложности оценки ролей при многозадачности
#
# Анализ показал, что **3/4 поручений (316 из 434)** выполнялись героями, которые одновременно занимали несколько ролей. Это создает трудности при точной оценке каждой роли отдельно, так как оценки за поручение распределяются на несколько ролей.
#
# ---
#
# ### Агрегация данных по ролям, кластерам и оценкам
#
# Чтобы корректно оценить вклад героев в выполнение задач, были выполнены следующие шаги:
# 1. **Агрегация данных**
#    Для каждого героя были рассчитаны средние оценки по:
#    - Его ролям.
#    - Кластерам (цель-объект).
#    - Поручениям.
#
# 2. **Обработка поручений с несколькими ролями**
#    Если герой выполнял поручение в нескольких ролях, то для каждой роли отдельно учитывались оценки из этих поручений.
#
# 3. **Результат: таблица `df_roles`**
#    Итогом стала таблица, которая содержит информацию о каждом герое, его ролях, связанных кластерах, и средних оценках.
#
# ---
#
# ### Отбор лучших героев
#
# Для дальнейшего анализа из таблицы `df_roles` были отобраны только лучшие герои, у которых одновременно:
# - **Средние оценки по срокам больше 2.**
# - **Средние оценки по качеству больше 3.**
#
# Этот фильтр гарантирует, что выбранные герои способны эффективно выполнять задачи.
#
# ---
#
# ### Создание профилей героев
#
# На основе данных из `df_roles` была создана таблица **`hero_profiles`**, которая содержит следующую информацию:
# - **Герой:** Имя героя.
# - **Роль:** Роль героя в поручении.
# - **Кластер:** К какому кластеру (цель-объект) относятся выполненные задачи.
# - **Средние оценки:** Средние значения по качеству, срокам и вежливости.
# - **Действия из дневника:** Список задач, выполненных героем в данной роли.
# - **Общее время:** Сумма затраченных часов на выполнение задач.
#
#
# ---
#
# ### Итог
#
# Сформированные данные позволяют:
# - Точно оценить эффективность героев в их ролях.
# - Провести детализированный анализ задач, связанных с конкретными кластерами.
# - Упростить планирование задач и распределение ролей в будущем.

# %%
#1 - если герой выступал в качестве одной роли
df_heroes_w_marks["solo"].value_counts()
# Out:
# solo
# 0.0    347
# 1.0    134
# Name: count, dtype: int64

# %%
df_heroes_w_marks['Роль'] = df_heroes_w_marks['Роль'].apply(lambda x: x if isinstance(x, list) else [x])
df_single_role = df_heroes_w_marks[df_heroes_w_marks['Роль'].apply(len) == 1].explode('Роль', ignore_index=True)
df_multi_role = df_heroes_w_marks[df_heroes_w_marks["Роль"].isin(df_single_role["Роль"]) == False].explode('Роль', ignore_index=True)
df_expanded = pd.concat([df_single_role, df_multi_role])



df_roles = df_expanded.groupby(["Герой_x", "Роль", "common_purpose",	"description_object"], as_index=False).agg(
    {
        "Оценка за качество": "mean",
        "Оценка по срокам": "mean",
        "Оценка за вежливость": "mean"
    }
).reset_index()

# %%
df_roles = df_roles[(
    df_roles["Оценка за качество"] >3) & (df_roles["Оценка по срокам"] > 2)]
df_roles = df_roles.rename(columns={'Герой_x': 'Герой'})

# %%
df_roles.head(5)
# Out:
#    index  Герой    Роль             common_purpose description_object  \
# 0      0  Агата  лучник          прогнать-проучить              зверь
# 1      1  Агата  лучник          прогнать-проучить          разбойник
# 2      2  Агата  лучник  убить-победить-уничтожить             дракон
# 3      3  Агата  лучник  убить-победить-уничтожить              зверь
# 4      4  Агата  лучник  убить-победить-уничтожить             монстр
#
#    Оценка за качество  Оценка по срокам  Оценка за вежливость
# 0                 4.0          3.000000              4.000000
# 1                 4.0          3.333333              4.666667
# 2                 4.2          4.200000              4.000000
# 3                 4.0          3.333333              5.000000
# 4                 3.5          3.500000              4.000000

# %%
hero_profiles = pd.merge(
    df_roles,
    pd.merge(
        df_diaries,
        df_cases[["Номер поручения", "common_purpose", "description_object"]],
        on="Номер поручения",
        how="left"
    ).groupby(
        ["Герой", "Запись в дневнике", "Роль", "common_purpose", "description_object"]
        )["Затрачено часов"].mean().reset_index(),
    on=["Герой", "Роль", "common_purpose", "description_object"],
    how="left"        
).drop(columns="index")

# %%
hero_profiles.head(5)
# Out:
#    Герой    Роль             common_purpose description_object  \
# 0  Агата  лучник          прогнать-проучить              зверь
# 1  Агата  лучник          прогнать-проучить          разбойник
# 2  Агата  лучник  убить-победить-уничтожить             дракон
# 3  Агата  лучник  убить-победить-уничтожить              зверь
# 4  Агата  лучник  убить-победить-уничтожить             монстр
#
#    Оценка за качество  Оценка по срокам  Оценка за вежливость  \
# 0                 4.0          3.000000              4.000000
# 1                 4.0          3.333333              4.666667
# 2                 4.2          4.200000              4.000000
# 3                 4.0          3.333333              5.000000
# 4                 3.5          3.500000              4.000000
#
#   Запись в дневнике  Затрачено часов
# 0    разжечь костёр         0.666667
# 1    разжечь костёр         0.666667
# 2    разжечь костёр         0.666667
# 3    разжечь костёр         0.666667
# 4    разжечь костёр         0.666667

# %% [markdown]
# После чего для дальнешего упрощения работы колонки кластеров **цель** и **объект** были объединены в один с помощью метода ``connect_clusters``

# %%
def connect_clusters(row):
    return " ".join(row[["common_purpose", "description_object"]])

# %%
hero_profiles["cluster"] = hero_profiles.apply(connect_clusters, axis=1, result_type="expand")

# %%
hero_profiles.head(5)
# Out:
#    Герой    Роль             common_purpose description_object  \
# 0  Агата  лучник          прогнать-проучить              зверь
# 1  Агата  лучник          прогнать-проучить          разбойник
# 2  Агата  лучник  убить-победить-уничтожить             дракон
# 3  Агата  лучник  убить-победить-уничтожить              зверь
# 4  Агата  лучник  убить-победить-уничтожить             монстр
#
#    Оценка за качество  Оценка по срокам  Оценка за вежливость  \
# 0                 4.0          3.000000              4.000000
# 1                 4.0          3.333333              4.666667
# 2                 4.2          4.200000              4.000000
# 3                 4.0          3.333333              5.000000
# 4                 3.5          3.500000              4.000000
#
#   Запись в дневнике  Затрачено часов                           cluster
# 0    разжечь костёр         0.666667           прогнать-проучить зверь
# 1    разжечь костёр         0.666667       прогнать-проучить разбойник
# 2    разжечь костёр         0.666667  убить-победить-уничтожить дракон
# 3    разжечь костёр         0.666667   убить-победить-уничтожить зверь
# 4    разжечь костёр         0.666667  убить-победить-уничтожить монстр

# %%
#Профили героев
hero_profiles.to_csv("result_heroes_profiles_clusters.csv")

# %% [markdown]
# ### Полученные в результате анализа таблицы позволяют перейти к следующему этапу

# %% [markdown]
# # 2. Подготовка к модели

# %% [markdown]
# ## 2.1 Таблица поручений

# %% [markdown]
# Объединение колонок кластеров **цель** и **объект**  в один с помощью метода ``connect_clusters``

# %%
df_cases["cluster"] = df_cases.apply(connect_clusters, axis=1, result_type="expand")

# %% [markdown]
# ### Учет временного фактора для рекомендательной системы
#
# Для построения качественной рекомендательной системы важно учитывать **временной фактор** выполнения поручений, чтобы анализировать доступность героев в разные промежутки времени. Это позволяет оптимально распределять задачи и предсказывать участие героев в будущем.
#
# ---
#
# #### Преобразование дат для анализа
#
# 1. **Метод `convert_date`**
#    Для работы с временными данными был разработан метод `convert_date`, который преобразует даты в числовой формат, удобный для дальнейшего анализа.
#
# 2. **Определение диапазона работы гильдии**
#    На основе списка поручений были вычислены:
#    - **Минимальная дата (`min_date`)**: начало работы гильдии.
#    - **Максимальная дата (`max_date`)**: крайняя дата выполнения или появления поручений.
#
# 3. **Замена дат на числовые значения**
#    Каждая дата в таблице была заменена на соответствующее число, где:
#    - **Дата поручения_t**: дни с начала горизонта планирования (от `1` до `n`).
#    - **Дата выполнения_t**: дни с начала горизонта планирования (от `1` до `n`).
#
# #### Горизонт планирования
#
# Полученный список дней от 1 до `n` называется **горизонтом планирования**, где:
# - `n = max_date - min_date` (в днях).
# - Это последовательность, используемая для анализа временной доступности героев.
#
#
#
# #### Зачем это нужно?
#
# 1. **Анализ доступности героев**
#    Числовой формат позволяет легко определить, кто из героев был занят в определённый промежуток времени.
#
# 2. **Горизонт планирования**
#    Универсальная шкала времени упрощает прогнозирование и планирование задач в будущем.
#
# 3. **Интеграция в рекомендательную систему**
#    Использование временного фактора в сочетании с ролями, кластерами и оценками позволяет повысить точность рекомендаций.
#
# ---
#
# ### Итог
#
# Преобразование данных в числовой формат с использованием метода `convert_date` и формирование горизонта планирования создали основу для учета временного фактора в рекомендательной системе. Это улучшает качество анализа и планирования задач в рамках работы гильдии.

# %%
def convert_date(date):
    if pd.notna(date):
        try:
            return datetime.strptime(date, "%Y-%m-%d")
        except ValueError:
            return date
    return date

# %%
#Преобразование строковых дат в объект datetime
df_cases["time_in"] = df_cases["Дата поручения"].apply(convert_date)
df_cases["time_finish"] = df_cases["Дата выполнения"].apply(convert_date)

# %%
#Поиск минимальной и максимальной даты среди дат поступления поручений и их конца выполнения
min_date = min(df_cases["time_in"].min(),df_cases["time_finish"].dropna().min())
max_date = max(df_cases["time_in"].max(),df_cases["time_finish"].dropna().max())

# %%
#Создание словаря замены даты в кванты времени и наоборот
t_date_list = []
date_t_list = []
current_date = min_date
i = 0
while current_date <= max_date:
    t_date_list.append([i:= i +1 ,current_date])
    date_t_list.append([current_date, i])
    current_date += timedelta(days=1)

t_date_dict = dict(t_date_list)
date_t_dict = dict(date_t_list)

# %%
#Перевод дат в кванты времени (у невыполненных поручений Nan заменен на -1, чтобы код отработал)
df_cases["Дата поручения_t"] = df_cases["time_in"].map(date_t_dict)
df_cases["Дата выполнения_t"] = df_cases["time_finish"].map(date_t_dict).fillna(-1).astype(int)

# %%
#Горизонт планирования
t = np.array(range(1, date_t_list[-1][-1]))

# %% [markdown]
# ### Создание обучающей выборки на основе исторических данных
#
# Для разработки качественной модели рекомендательной системы была создана обучающая выборка, основанная на исторических данных о выполненных поручениях.
#
# ---
#
# #### Источник данных
#
# 1. **Таблица выполненных поручений**
#    В выборку были включены только те поручения, которые помечены как успешно выполненные.
#
# 2. **Объединение данных**
#    Выполненные поручения были объединены с:
#    - **Записями из дневника:** Описания задач, которые герой выполнял для выполнения поручения.
#    - **Оценками по срокам:** Показатель, отражающий удовлетворённость заказчика скоростью выполнения задачи.
#
# ---
#
# #### Подход к оценке времени выполнения
#
# Для анализа временного фактора было сделано допущение:
# **Оценка по срокам пропорциональна количеству времени, затраченного героем на выполнение задачи.**
#
# - **Интерпретация оценки:**
#   Например, если оценка по срокам равна `3`, это указывает на то, что заказчик ожидал более быстрого выполнения задачи.
#
# - **Формула подсчета идеального времени выполнения:**
#   На основе этой идеи была выведена формула:
#
#   * **Идеальное время выполнения = ceil(Фактическое время выполнения * Оценка по срокам / 5)**
#
#   Где:
#   - **Фактическое время выполнения** — количество дней, которое герой реально затратил.
#   - **Оценка по срокам** — оценка заказчика по шкале от 1 до 5.
#   - **Округление вверх** ``ceil`` связано с тем, что задачи оцениваются в целых днях.
#
# Оценка идеального времени для задачи реализована с помощью метода ``ideal_time``
#
# ---
#
# #### Зачем это нужно?
#
# 1. **Формирование эталона времени выполнения**
#    Идеальное время выполнения позволяет установить ориентир для оценки, за сколько фактических дней команда выполняет те или иные задачи.
#
# 2. **Анализ производительности**
#    Сравнение фактического времени с идеальным помогает выявить слабые места и улучшить планирование.
#
# 3. **Улучшение рекомендательной системы**
#    Использование идеального времени в качестве целевой метрики делает модель более адаптированной к ожиданиям заказчиков.
#
# ---
#
# ### Итог
#
# На основе исторических данных о выполненных задачах и оценок по срокам была создана обучающая выборка. Формула подсчета идеального времени выполнения позволяет использовать временной фактор для оптимизации выполнения задач и повышения удовлетворённости заказчиков.

# %%
def ideal_time(row):
    return int(np.ceil(row["Оценка по срокам"] * row["Затрачено дней"] / 5))

# %%
df_train_cases = pd.merge(
    df_cases[df_cases["Выполнено"]=="да"],
    pd.merge(
        df_diaries.groupby(["Номер поручения", "Герой"])["Запись в дневнике"].apply(list).reset_index(),
        df_marks[["Номер поручения", "Оценка по срокам"]],
        on=["Номер поручения"]
    ),
    on="Номер поручения"
)

# %%
df_train_cases.head(5)
# Out:
#    Номер поручения Заказчик Дата поручения Выполнено Дата выполнения  \
# 0            11000     Анна     1051-08-11        да      1051-08-21
# 1            11001    Мария     1051-07-09        да      1051-09-02
# 2            11002   Эмилио     1053-10-05        да      1053-10-20
# 3            11003   Бьянка     1052-11-24        да      1052-12-02
# 4            11004   Бьянка     1052-02-23        да      1052-03-30
#
#    Затрачено дней  Сумма вознаграждения  \
# 0             4.0                  6000
# 1             2.0                 20000
# 2             7.0                 22500
# 3             5.0                  5500
# 4             8.0                 10500
#
#                                             Описание  \
# 0  В лесу по дороге от пещеры звери нападают на л...
# 1  В лесу по дороге от пещеры были замечены разбо...
# 2  По дороге из деревни монстры похитили путников...
# 3  Недалеко от города видели монстров. Нужно побе...
# 4  В деревне у меня пропала сумка с документами. ...
#
#                                          description  \
# 0  В лесу по дороге от пещеры звери нападают на л...
# 1  В лесу по дороге от пещеры были замечены разбо...
# 2     По дороге из деревни монстры похитили путников
# 3                 Недалеко от города видели монстров
# 4       В деревне у меня пропала сумка с документами
#
#                                               advice  ...  \
# 0  Осмотрите все возможные укрытия, чтобы найти з...  ...
# 1  Будьте осторожны, так как разбойники могут быт...  ...
# 2  Осмотрите все возможные укрытия, чтобы найти п...  ...
# 3  Будьте осторожны, так как монстры могут быть о...  ...
# 4                                                     ...
#
#               common_purpose description_object  \
# 0  убить-победить-уничтожить              зверь
# 1  убить-победить-уничтожить          разбойник
# 2          спасти-освободить             монстр
# 3  убить-победить-уничтожить             монстр
# 4              вернуть-найти     сумка документ
#
#                                cluster              time_in  \
# 0      убить-победить-уничтожить зверь  1051-08-11 00:00:00
# 1  убить-победить-уничтожить разбойник  1051-07-09 00:00:00
# 2             спасти-освободить монстр  1053-10-05 00:00:00
# 3     убить-победить-уничтожить монстр  1052-11-24 00:00:00
# 4         вернуть-найти сумка документ  1052-02-23 00:00:00
#
#            time_finish Дата поручения_t Дата выполнения_t    Герой  \
# 0  1051-08-21 00:00:00              221               231   Мартин
# 1  1051-09-02 00:00:00              188               243  Альфред
# 2  1053-10-20 00:00:00             1007              1022   Мартин
# 3  1052-12-02 00:00:00              692               700   Бендер
# 4  1052-03-30 00:00:00              417               453     Юлия
#
#                                   Запись в дневнике  Оценка по срокам
# 0  [разжечь костёр, выследить цель, разжечь костёр]                 3
# 1   [разжечь костёр, залечить раны, разжечь костёр]                 5
# 2                                  [выследить цель]                 4
# 3                                  [разжечь костёр]                 4
# 4               [найти пропажу, отыскать заказчика]                 4
#
# [5 rows x 23 columns]

# %%
df_train_cases["Идеальное время"] = df_train_cases.apply(ideal_time, axis=1, result_type="expand")
df_train_cases["Затрачено дней"] = df_train_cases["Затрачено дней"].astype(int)

# %% [markdown]
# Удаление лишних неинформативных далее колонок

# %%
df_train_cases = df_train_cases[["Номер поручения", "Заказчик", "Дата поручения", 
                "Дата выполнения", "Затрачено дней", "Сумма вознаграждения",
                "description", "cluster", "time_in", "time_finish", "Дата поручения_t",
                "Дата выполнения_t", "Герой", "Запись в дневнике", "Идеальное время"
                ]]

# %% [markdown]
# ### Расчет квантов времени для задач и героев
#
# Для анализа временной доступности задач и героев был разработан подход, основанный на расчёте **квантов времени**, которые определяют:
#
# 1. **Доступность задачи для выполнения**
#    Каждый кванты времени для задачи определяется как промежуток между:
#    - **Датой появления поручения в гильдии** (дата начала).
#    - **Максимальной доступной датой** (граничный кванты времени для планирования).
#
# 2. **Доступность героев**
#    Для каждого героя учитываются его занятость и пересечения между:
#    - **Выполненными поручениями**.
#    - **Поручениями, которые находятся в процессе выполнения.**
#
# Эти данные позволяют учитывать, что некоторые задачи могут накладываться на невыполненные или параллельно выполняемые поручения.
#
# ---
#
# #### Построение квантов времени
#
# Для построения квантов времени была использована функция **`create_date_range`**, которая создаёт последовательность дат, представляющих доступность:
#
# 1. **Для задач:**
#    Кванты времени создаются между датой появления задачи в гильдии и максимальной доступной датой (горизонт планирования).
#
# 2. **Для героев:**
#    Кванты времени формируются на основе:
#    - Даты завершения последнего поручения героя.
#    - Возможных пересечений с другими задачами.

# %%
def create_date_range(row):
    return [row["Дата выполнения_t"] - i for i in range(0, row["Дата выполнения_t"] - row["Идеальное время"])]

# %%
df_train_cases['диапазон дат'] = df_train_cases.apply(create_date_range, axis=1)

# %%
grouped_df = df_train_cases[["Герой", "диапазон дат"]].groupby('Герой')['диапазон дат'].sum().reset_index()
grouped_df['диапазон дат'] = grouped_df['диапазон дат'].apply(lambda x: sorted(set(x)))
grouped_df["feasible_date"] = grouped_df["диапазон дат"].apply(lambda x: list(np.setdiff1d(t, np.array(x))))

heroes_availibility = dict(grouped_df[["Герой", "feasible_date"]].values)

# %%
heroes_availibility
# Out:
# {'Агата': [1,
#   1055,
#   1056,
#   1057,
#   1058,
#   1059,
#   1060,
#   1061,
#   1062,
#   1063,
#   1064,
#   1065,
#   1066,
#   1067,
#   1068,
#   1069,
#   1070,
#   1071,
#   1072,
#   1073,
#   1074,
#   1075,
#   1076,
#   1077,
#   1078,
#   1079,
#   1080,
#   1081,
#   1082,
#   1083,
#   1084,
#   1085,
#   1086,
#   1087,
#   1088,
#   1089,
#   1090,
#   1091,
#   1092,
#   1093,
#   1094,
#   1095,
#   1096,
#   1097,
#   1098,
#   1099,
#   1100,
#   1101,
#   1102,
#   1103,
#   1104,
#   1105,
#   1106],
#  'Альфред': [1,
#   1044,
#   1045,
#   1046,
#   1047,
#   1048,
#   1049,
#   1050,
#   1051,
#   1052,
#   1053,
#   1054,
#   1055,
#   1056,
#   1057,
#   1058,
#   1059,
#   1060,
#   1061,
#   1062,
#   1063,
#   1064,
#   1065,
#   1066,
#   1067,
#   1068,
#   1069,
#   1070,
#   1071,
#   1072,
#   1073,
#   1074,
#   1075,
#   1076,
#   1077,
#   1078,
#   1079,
#   1080,
#   1081,
#   1082,
#   1083,
#   1084,
#   1085,
#   1086,
#   1087,
#   1088,
#   1089,
#   1090,
#   1091,
#   1092,
#   1093,
#   1094,
#   1095,
#   1096,
#   1097,
#   1098,
#   1099,
#   1100,
#   1101,
#   1102,
#   1103,
#   1104,
#   1105,
#   1106],
#  'Бендер': [1,
#   1036,
#   1037,
#   1038,
#   1039,
#   1040,
#   1041,
#   1042,
#   1043,
#   1044,
#   1045,
#   1046,
#   1047,
#   1048,
#   1049,
#   1050,
#   1051,
#   1052,
#   1053,
#   1054,
#   1055,
#   1056,
#   1057,
#   1058,
#   1059,
#   1060,
#   1061,
#   1062,
#   1063,
#   1064,
#   1065,
#   1066,
#   1067,
#   1068,
#   1069,
#   1070,
#   1071,
#   1072,
#   1073,
#   1074,
#   1075,
#   1076,
#   1077,
#   1078,
#   1079,
#   1080,
#   1081,
#   1082,
#   1083,
#   1084,
#   1085,
#   1086,
#   1087,
#   1088,
#   1089,
#   1090,
#   1091,
#   1092,
#   1093,
#   1094,
#   1095,
#   1096,
#   1097,
#   1098,
#   1099,
#   1100,
#   1101,
#   1102,
#   1103,
#   1104,
#   1105,
#   1106],
#  'Бенедикт': [1,
#   1022,
#   1023,
#   1024,
#   1025,
#   1026,
#   1027,
#   1028,
#   1029,
#   1030,
#   1031,
#   1032,
#   1033,
#   1034,
#   1035,
#   1036,
#   1037,
#   1038,
#   1039,
#   1040,
#   1041,
#   1042,
#   1043,
#   1044,
#   1045,
#   1046,
#   1047,
#   1048,
#   1049,
#   1050,
#   1051,
#   1052,
#   1053,
#   1054,
#   1055,
#   1056,
#   1057,
#   1058,
#   1059,
#   1060,
#   1061,
#   1062,
#   1063,
#   1064,
#   1065,
#   1066,
#   1067,
#   1068,
#   1069,
#   1070,
#   1071,
#   1072,
#   1073,
#   1074,
#   1075,
#   1076,
#   1077,
#   1078,
#   1079,
#   1080,
#   1081,
#   1082,
#   1083,
#   1084,
#   1085,
#   1086,
#   1087,
#   1088,
#   1089,
#   1090,
#   1091,
#   1092,
#   1093,
#   1094,
#   1095,
#   1096,
#   1097,
#   1098,
#   1099,
#   1100,
#   1101,
#   1102,
#   1103,
#   1104,
#   1105,
#   1106],
#  'Глюкоза': [1],
#  'Леопольд': [1,
#   1046,
#   1047,
#   1048,
#   1049,
#   1050,
#   1051,
#   1052,
#   1053,
#   1054,
#   1055,
#   1056,
#   1057,
#   1058,
#   1059,
#   1060,
#   1061,
#   1062,
#   1063,
#   1064,
#   1065,
#   1066,
#   1067,
#   1068,
#   1069,
#   1070,
#   1071,
#   1072,
#   1073,
#   1074,
#   1075,
#   1076,
#   1077,
#   1078,
#   1079,
#   1080,
#   1081,
#   1082,
#   1083,
#   1084,
#   1085,
#   1086,
#   1087,
#   1088,
#   1089,
#   1090,
#   1091,
#   1092,
#   1093,
#   1094,
#   1095,
#   1096,
#   1097,
#   1098,
#   1099,
#   1100,
#   1101,
#   1102,
#   1103,
#   1104,
#   1105,
#   1106],
#  'Мартин': [1,
#   1023,
#   1024,
#   1025,
#   1026,
#   1027,
#   1028,
#   1029,
#   1030,
#   1031,
#   1032,
#   1033,
#   1034,
#   1035,
#   1036,
#   1037,
#   1038,
#   1039,
#   1040,
#   1041,
#   1042,
#   1043,
#   1044,
#   1045,
#   1046,
#   1047,
#   1048,
#   1049,
#   1050,
#   1051,
#   1052,
#   1053,
#   1054,
#   1055,
#   1056,
#   1057,
#   1058,
#   1059,
#   1060,
#   1061,
#   1062,
#   1063,
#   1064,
#   1065,
#   1066,
#   1067,
#   1068,
#   1069,
#   1070,
#   1071,
#   1072,
#   1073,
#   1074,
#   1075,
#   1076,
#   1077,
#   1078,
#   1079,
#   1080,
#   1081,
#   1082,
#   1083,
#   1084,
#   1085,
#   1086,
#   1087,
#   1088,
#   1089,
#   1090,
#   1091,
#   1092,
#   1093,
#   1094,
#   1095,
#   1096,
#   1097,
#   1098,
#   1099,
#   1100,
#   1101,
#   1102,
#   1103,
#   1104,
#   1105,
#   1106],
#  'Пастушок': [1,
#   1083,
#   1084,
#   1085,
#   1086,
#   1087,
#   1088,
#   1089,
#   1090,
#   1091,
#   1092,
#   1093,
#   1094,
#   1095,
#   1096,
#   1097,
#   1098,
#   1099,
#   1100,
#   1101,
#   1102,
#   1103,
#   1104,
#   1105,
#   1106],
#  'Синеглазый': [1,
#   1070,
#   1071,
#   1072,
#   1073,
#   1074,
#   1075,
#   1076,
#   1077,
#   1078,
#   1079,
#   1080,
#   1081,
#   1082,
#   1083,
#   1084,
#   1085,
#   1086,
#   1087,
#   1088,
#   1089,
#   1090,
#   1091,
#   1092,
#   1093,
#   1094,
#   1095,
#   1096,
#   1097,
#   1098,
#   1099,
#   1100,
#   1101,
#   1102,
#   1103,
#   1104,
#   1105,
#   1106],
#  'Соня': [1,
#   1088,
#   1089,
#   1090,
#   1091,
#   1092,
#   1093,
#   1094,
#   1095,
#   1096,
#   1097,
#   1098,
#   1099,
#   1100,
#   1101,
#   1102,
#   1103,
#   1104,
#   1105,
#   1106],
#  'Фредерик': [1,
#   1079,
#   1080,
#   1081,
#   1082,
#   1083,
#   1084,
#   1085,
#   1086,
#   1087,
#   1088,
#   1089,
#   1090,
#   1091,
#   1092,
#   1093,
#   1094,
#   1095,
#   1096,
#   1097,
#   1098,
#   1099,
#   1100,
#   1101,
#   1102,
#   1103,
#   1104,
#   1105,
#   1106],
#  'Юлия': [1,
#   1050,
#   1051,
#   1052,
#   1053,
#   1054,
#   1055,
#   1056,
#   1057,
#   1058,
#   1059,
#   1060,
#   1061,
#   1062,
#   1063,
#   1064,
#   1065,
#   1066,
#   1067,
#   1068,
#   1069,
#   1070,
#   1071,
#   1072,
#   1073,
#   1074,
#   1075,
#   1076,
#   1077,
#   1078,
#   1079,
#   1080,
#   1081,
#   1082,
#   1083,
#   1084,
#   1085,
#   1086,
#   1087,
#   1088,
#   1089,
#   1090,
#   1091,
#   1092,
#   1093,
#   1094,
#   1095,
#   1096,
#   1097,
#   1098,
#   1099,
#   1100,
#   1101,
#   1102,
#   1103,
#   1104,
#   1105,
#   1106]}

# %%
df_train_cases.head()
# Out:
#    Номер поручения Заказчик Дата поручения Дата выполнения  Затрачено дней  \
# 0            11000     Анна     1051-08-11      1051-08-21               4
# 1            11001    Мария     1051-07-09      1051-09-02               2
# 2            11002   Эмилио     1053-10-05      1053-10-20               7
# 3            11003   Бьянка     1052-11-24      1052-12-02               5
# 4            11004   Бьянка     1052-02-23      1052-03-30               8
#
#    Сумма вознаграждения                                        description  \
# 0                  6000  В лесу по дороге от пещеры звери нападают на л...
# 1                 20000  В лесу по дороге от пещеры были замечены разбо...
# 2                 22500     По дороге из деревни монстры похитили путников
# 3                  5500                 Недалеко от города видели монстров
# 4                 10500       В деревне у меня пропала сумка с документами
#
#                                cluster              time_in  \
# 0      убить-победить-уничтожить зверь  1051-08-11 00:00:00
# 1  убить-победить-уничтожить разбойник  1051-07-09 00:00:00
# 2             спасти-освободить монстр  1053-10-05 00:00:00
# 3     убить-победить-уничтожить монстр  1052-11-24 00:00:00
# 4         вернуть-найти сумка документ  1052-02-23 00:00:00
#
#            time_finish  Дата поручения_t  Дата выполнения_t    Герой  \
# 0  1051-08-21 00:00:00               221                231   Мартин
# 1  1051-09-02 00:00:00               188                243  Альфред
# 2  1053-10-20 00:00:00              1007               1022   Мартин
# 3  1052-12-02 00:00:00               692                700   Бендер
# 4  1052-03-30 00:00:00               417                453     Юлия
#
#                                   Запись в дневнике  Идеальное время  \
# 0  [разжечь костёр, выследить цель, разжечь костёр]                3
# 1   [разжечь костёр, залечить раны, разжечь костёр]                2
# 2                                  [выследить цель]                6
# 3                                  [разжечь костёр]                4
# 4               [найти пропажу, отыскать заказчика]                7
#
#                                         диапазон дат
# 0  [231, 230, 229, 228, 227, 226, 225, 224, 223, ...
# 1  [243, 242, 241, 240, 239, 238, 237, 236, 235, ...
# 2  [1022, 1021, 1020, 1019, 1018, 1017, 1016, 101...
# 3  [700, 699, 698, 697, 696, 695, 694, 693, 692, ...
# 4  [453, 452, 451, 450, 449, 448, 447, 446, 445, ...

# %% [markdown]
# ## 2.2 Поиск ближайших поручений

# %% [markdown]
# ### Генерация допустимых команд для выполнения задач
#
# Для эффективного распределения задач между героями был создан алгоритм представленный в виде класса ``TaskManager``, который формирует **допустимые команды** на основе доступности героев, их оценок и требований к задачам.
#
# ---
#
# #### Основные критерии формирования команд
#
# 1. **Доступность команды в квантах времени**
#    Для каждой задачи алгоритм проверяет доступность героев в интервале времени, начиная с момента поступления задачи (start_quant). Например:
#    - Для каждой сгенерированной команды оценивается её способность выполнить задачу в ожидаемое время **time_task**, основанное на средней оценке по срокам героев.
#    - Если задача поступила в `start_quant = 4` и её **task_time = 5**, то герои в команде должны быть доступны в интервале от `t` до `t + task_time` (включительно), для какого-либо `t` >= `start_quant`
#
# 2. **Список задач внутри задачи**
#    Для каждой задачи формируются команды, которые могут выполнить весь набор подзадач, входящих в поручение. Один герой может выполнять несколько задач внутри одного поручения, при этом в команде он будет учитываться несколько раз.
#
# 3. **Фиксированная длина команды**
#    Все команды имеют равное количество слотов, но один герой может занимать несколько слотов, если он выполняет несколько задач. Например:
#    - Если герой выполняет две задачи, он считается дважды в составе команды.
#    Фактически установлено ограничение на максимально кол-во уникального героя команды = 1. Но поскольку может быть один и тот же герой в разных ролях и действиях, то команды будут размером также от 1 до 4
# ---
#
# #### Оценка производительности команды
#
# После формирования команды рассчитываются её характеристики:
#
# 1. **Средние оценки команды:**
#    - Средняя оценка по качеству.
#    - Средняя оценка по срокам.
#    - Максимальная оценка по вежливости среди членов команды, так как будем считать, что вежливость команды может представлять один герой.
#
# 2. **Средневзвешенная оценка команды**
#    Для определения общей эффективности команды рассчитывается **средневзвешенная оценка**:
#
#    * **Оценка команды = 0.5 * Качество + 0.4 * Сроки + 0.1 * Вежливость **
#
#
# ---
#
# #### Зачем это нужно?
#
# 1. **Учёт доступности героев**
#    Команды формируются с учётом времени, когда герои свободны для выполнения задачи, что минимизирует пересечения и простаивание.
#
# 2. **Оптимизация команд**
#    Генерация фиксированных команд позволяет оценить их эффективность на основе оценок и временных факторов.
#
# 3. **Повышение точности планирования**
#    Использование средневзвешенной оценки позволяет выбирать команды, которые обеспечат наилучшее выполнение задачи.
#
# ---
#
# ### Итог
#
# Алгоритм генерации допустимых команд обеспечивает эффективное распределение задач, учитывая доступность героев, их оценки и временные ограничения. Это создаёт основу для построения более точной и качественной рекомендательной системы.

# %%
class TaskManager:
    def __init__(self, heroes_table, hero_availability):
        self.heroes_table = heroes_table
        self.hero_availability = hero_availability

    def find_heroes_for_task(self, tasks):
        """
        Создает список задач и героев, которые могут их выполнять.
        :param tasks: Список задач
        :return: Список задач с возможными героями и ролями
        """
        
        task_list = []
        for task in tasks:
            possible_roles = []
            for hero in self.heroes_table:
                if hero['Запись в дневнике'] == task:
                    possible_roles.append((hero['Герой'], hero['Роль']))
            task_list.append((task, possible_roles))
        return task_list

    def calculate_team_scores(self, team, t0):
        """
        Рассчитать средние оценки команды и время выполнения задачи.
        :param team: Список героев и их ролей
        :param t0: Ожидаемое время выполнения задачи
        :return: Средние оценки и время выполнения
        """
        qualities = []
        deadlines = []
        politeness = []

        for hero, role in team:
            for record in self.heroes_table:
                if record['Герой'] == hero and record['Роль'] == role:
                    qualities.append(record['Оценка за качество'])
                    deadlines.append(record['Оценка по срокам'])
                    politeness.append(record['Оценка за вежливость'])

        avg_quality = sum(qualities) / len(qualities) if qualities else 0
        avg_deadline = sum(deadlines) / len(deadlines) if deadlines else 0
        max_politeness = max(politeness) if politeness else 0

        
        task_time = math.ceil(t0 * 5 / avg_deadline) if avg_deadline > 0 else float('inf')

        
        weighted_score = (
            0.5 * avg_quality +
            0.4 * avg_deadline +
            0.1 * max_politeness
        )

        return avg_quality, avg_deadline, max_politeness, task_time, weighted_score

    def check_team_availability(self, team, start_quant, task_duration):
        """
        Проверяет, есть ли пересечение доступности команды в нужном интервале времени.
        :param team: Список героев и их ролей
        :param start_quant: Квант времени начала задачи
        :param task_duration: Длительность задачи
        :return: Tuple[bool, Set[int]]: True, если команда доступна, и множество пересечений
        """
        team_availability = []

        for hero, _ in team:
            hero_availability = self.hero_availability.get(hero, [])
            team_availability.append(set(hero_availability))

        common_availability = set.intersection(*team_availability) if team_availability else set()

        for start in common_availability:
            required_time = list(range(start, start + task_duration))
            if all(quant in common_availability for quant in required_time):
                if required_time[0] >= start_quant:
                    return True, common_availability

        return False, common_availability

    def generate_teams(self, task_list, start_quant, t0, max_team_size=4):
        """
        Генерация всех возможных команд для выполнения задач.
        :param task_list: Список задач с возможными героями
        :param start_quant: Квант времени начала задачи
        :param t0: Ожидаемое время выполнения задачи
        :param max_team_size: Максимальный размер команды
        :return: Список возможных команд
        """
        teams = []

        def backtrack(current_team, task_index, used_roles):
            if task_index == len(task_list):
                if 1 <= len(current_team) <= max_team_size:
                    avg_quality, avg_deadline, max_politeness, task_duration, weighted_score = self.calculate_team_scores(current_team, t0)

                    is_available, common_availability = self.check_team_availability(current_team, start_quant, task_duration)
                    if is_available:
                        teams.append({
                            'team': list(current_team),
                            'avg_quality': avg_quality,
                            'avg_deadline': avg_deadline,
                            'max_politeness': max_politeness,
                            'task_time': task_duration,
                            'weighted_score': weighted_score,
                            'common_availability': common_availability,
                        })
                return

            task, candidates = task_list[task_index]
            for hero, role in candidates:
                if (hero, role) not in used_roles:
                    current_team.append((hero, role))
                    used_roles.add((hero, role))
                    backtrack(current_team, task_index + 1, used_roles)
                    used_roles.remove((hero, role))
                    current_team.pop()

        backtrack([], 0, set())
        return teams

# %% [markdown]
# ### Пример работы алгоритм по созданию команд

# %%
# Пример входных данных
heroes_table = [
    {'Герой': 'Агата', 'Роль': 'лучник', 'Оценка за качество': 4, 'Оценка по срокам': 4, 'Оценка за вежливость': 4, 'Запись в дневнике': 'разжечь костёр'},
    {'Герой': 'Агата', 'Роль': 'рейнджер', 'Оценка за качество': 4, 'Оценка по срокам': 4, 'Оценка за вежливость': 4, 'Запись в дневнике': 'разжечь костёр'},
    {'Герой': 'Борис', 'Роль': 'целитель', 'Оценка за качество': 5, 'Оценка по срокам': 5, 'Оценка за вежливость': 5, 'Запись в дневнике': 'залечить раны'},
]

heroes_table = hero_profiles[hero_profiles["cluster"]=="прогнать-проучить разбойник"].T.to_dict().values()
tasks = ['разжечь костёр', 'разжечь костёр', 'залечить раны']

# Начальные параметры задачи
start_quant = 1100
t0 = 3


# Создание и использование TaskManager
manager = TaskManager(heroes_table, heroes_availibility)
task_mapping = manager.find_heroes_for_task(tasks)
teams = manager.generate_teams(task_mapping, start_quant, t0)
sorted_teams = sorted(teams, key=lambda team: team['weighted_score'], reverse=True)

for team_info in teams:
    print("Команда:", team_info['team'])
    print("Средняя оценка за качество:", team_info['avg_quality'])
    print("Средняя оценка по срокам:", team_info['avg_deadline'])
    print("Максимальная оценка за вежливость:", team_info['max_politeness'])
    print("Время выполнения задачи:", team_info['task_time'])
    print("---")
# Out:
# Все возможные команды и их оценки:
# Команда: [('Агата', 'лучник'), ('Агата', 'рейнджер'), ('Альфред', 'лекарь')]
# Средняя оценка за качество: 4.0
# Средняя оценка по срокам: 3.777777777777778
# Максимальная оценка за вежливость: 4.666666666666667
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'лучник'), ('Агата', 'рейнджер'), ('Мартин', 'лекарь')]
# Средняя оценка за качество: 4.0
# Средняя оценка по срокам: 3.777777777777778
# Максимальная оценка за вежливость: 4.666666666666667
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'лучник'), ('Агата', 'рейнджер'), ('Соня', 'лекарь')]
# Средняя оценка за качество: 3.8333333333333335
# Средняя оценка по срокам: 3.9444444444444446
# Максимальная оценка за вежливость: 4.666666666666667
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'лучник'), ('Агата', 'рейнджер'), ('Фредерик', 'лекарь')]
# Средняя оценка за качество: 4.0
# Средняя оценка по срокам: 3.777777777777778
# Максимальная оценка за вежливость: 4.666666666666667
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'лучник'), ('Альфред', 'мечник'), ('Альфред', 'лекарь')]
# Средняя оценка за качество: 4.166666666666667
# Средняя оценка по срокам: 3.611111111111111
# Максимальная оценка за вежливость: 4.666666666666667
# Время выполнения задачи: 5
# ---
# Команда: [('Агата', 'лучник'), ('Альфред', 'мечник'), ('Мартин', 'лекарь')]
# Средняя оценка за качество: 4.166666666666667
# Средняя оценка по срокам: 3.611111111111111
# Максимальная оценка за вежливость: 4.666666666666667
# Время выполнения задачи: 5
# ---
# Команда: [('Агата', 'лучник'), ('Альфред', 'мечник'), ('Соня', 'лекарь')]
# Средняя оценка за качество: 4.0
# Средняя оценка по срокам: 3.777777777777778
# Максимальная оценка за вежливость: 4.666666666666667
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'лучник'), ('Альфред', 'мечник'), ('Фредерик', 'лекарь')]
# Средняя оценка за качество: 4.166666666666667
# Средняя оценка по срокам: 3.611111111111111
# Максимальная оценка за вежливость: 4.666666666666667
# Время выполнения задачи: 5
# ---
# Команда: [('Агата', 'лучник'), ('Альфред', 'рейнджер'), ('Альфред', 'лекарь')]
# Средняя оценка за качество: 4.333333333333333
# Средняя оценка по срокам: 3.4444444444444446
# Максимальная оценка за вежливость: 5.0
# Время выполнения задачи: 5
# ---
# Команда: [('Агата', 'лучник'), ('Альфред', 'рейнджер'), ('Мартин', 'лекарь')]
# Средняя оценка за качество: 4.333333333333333
# Средняя оценка по срокам: 3.4444444444444446
# Максимальная оценка за вежливость: 5.0
# Время выполнения задачи: 5
# ---
# Команда: [('Агата', 'лучник'), ('Альфред', 'рейнджер'), ('Соня', 'лекарь')]
# Средняя оценка за качество: 4.166666666666667
# Средняя оценка по срокам: 3.611111111111111
# Максимальная оценка за вежливость: 5.0
# Время выполнения задачи: 5
# ---
# Команда: [('Агата', 'лучник'), ('Альфред', 'рейнджер'), ('Фредерик', 'лекарь')]
# Средняя оценка за качество: 4.333333333333333
# Средняя оценка по срокам: 3.4444444444444446
# Максимальная оценка за вежливость: 5.0
# Время выполнения задачи: 5
# ---
# Команда: [('Агата', 'лучник'), ('Бендер', 'мечник'), ('Альфред', 'лекарь')]
# Средняя оценка за качество: 4.0
# Средняя оценка по срокам: 3.4444444444444446
# Максимальная оценка за вежливость: 4.666666666666667
# Время выполнения задачи: 5
# ---
# Команда: [('Агата', 'лучник'), ('Бендер', 'мечник'), ('Мартин', 'лекарь')]
# Средняя оценка за качество: 4.0
# Средняя оценка по срокам: 3.4444444444444446
# Максимальная оценка за вежливость: 4.666666666666667
# Время выполнения задачи: 5
# ---
# Команда: [('Агата', 'лучник'), ('Бендер', 'мечник'), ('Соня', 'лекарь')]
# Средняя оценка за качество: 3.8333333333333335
# Средняя оценка по срокам: 3.611111111111111
# Максимальная оценка за вежливость: 4.666666666666667
# Время выполнения задачи: 5
# ---
# Команда: [('Агата', 'лучник'), ('Бендер', 'мечник'), ('Фредерик', 'лекарь')]
# Средняя оценка за качество: 4.0
# Средняя оценка по срокам: 3.4444444444444446
# Максимальная оценка за вежливость: 4.666666666666667
# Время выполнения задачи: 5
# ---
# Команда: [('Агата', 'лучник'), ('Бендер', 'рейнджер'), ('Альфред', 'лекарь')]
# Средняя оценка за качество: 4.333333333333333
# Средняя оценка по срокам: 3.777777777777778
# Максимальная оценка за вежливость: 4.666666666666667
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'лучник'), ('Бендер', 'рейнджер'), ('Мартин', 'лекарь')]
# Средняя оценка за качество: 4.333333333333333
# Средняя оценка по срокам: 3.777777777777778
# Максимальная оценка за вежливость: 4.666666666666667
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'лучник'), ('Бендер', 'рейнджер'), ('Соня', 'лекарь')]
# Средняя оценка за качество: 4.166666666666667
# Средняя оценка по срокам: 3.9444444444444446
# Максимальная оценка за вежливость: 4.666666666666667
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'лучник'), ('Бендер', 'рейнджер'), ('Фредерик', 'лекарь')]
# Средняя оценка за качество: 4.333333333333333
# Средняя оценка по срокам: 3.777777777777778
# Максимальная оценка за вежливость: 4.666666666666667
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'лучник'), ('Бенедикт', 'мечник'), ('Альфред', 'лекарь')]
# Средняя оценка за качество: 4.0
# Средняя оценка по срокам: 3.6944444444444446
# Максимальная оценка за вежливость: 4.666666666666667
# Время выполнения задачи: 5
# ---
# Команда: [('Агата', 'лучник'), ('Бенедикт', 'мечник'), ('Мартин', 'лекарь')]
# Средняя оценка за качество: 4.0
# Средняя оценка по срокам: 3.6944444444444446
# Максимальная оценка за вежливость: 4.666666666666667
# Время выполнения задачи: 5
# ---
# Команда: [('Агата', 'лучник'), ('Бенедикт', 'мечник'), ('Соня', 'лекарь')]
# Средняя оценка за качество: 3.8333333333333335
# Средняя оценка по срокам: 3.861111111111111
# Максимальная оценка за вежливость: 4.666666666666667
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'лучник'), ('Бенедикт', 'мечник'), ('Фредерик', 'лекарь')]
# Средняя оценка за качество: 4.0
# Средняя оценка по срокам: 3.6944444444444446
# Максимальная оценка за вежливость: 4.666666666666667
# Время выполнения задачи: 5
# ---
# Команда: [('Агата', 'лучник'), ('Бенедикт', 'рейнджер'), ('Альфред', 'лекарь')]
# Средняя оценка за качество: 4.0
# Средняя оценка по срокам: 3.6944444444444446
# Максимальная оценка за вежливость: 4.666666666666667
# Время выполнения задачи: 5
# ---
# Команда: [('Агата', 'лучник'), ('Бенедикт', 'рейнджер'), ('Мартин', 'лекарь')]
# Средняя оценка за качество: 4.0
# Средняя оценка по срокам: 3.6944444444444446
# Максимальная оценка за вежливость: 4.666666666666667
# Время выполнения задачи: 5
# ---
# Команда: [('Агата', 'лучник'), ('Бенедикт', 'рейнджер'), ('Соня', 'лекарь')]
# Средняя оценка за качество: 3.8333333333333335
# Средняя оценка по срокам: 3.861111111111111
# Максимальная оценка за вежливость: 4.666666666666667
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'лучник'), ('Бенедикт', 'рейнджер'), ('Фредерик', 'лекарь')]
# Средняя оценка за качество: 4.0
# Средняя оценка по срокам: 3.6944444444444446
# Максимальная оценка за вежливость: 4.666666666666667
# Время выполнения задачи: 5
# ---
# Команда: [('Агата', 'лучник'), ('Леопольд', 'мечник'), ('Альфред', 'лекарь')]
# Средняя оценка за качество: 4.333333333333333
# Средняя оценка по срокам: 3.4444444444444446
# Максимальная оценка за вежливость: 5.0
# Время выполнения задачи: 5
# ---
# Команда: [('Агата', 'лучник'), ('Леопольд', 'мечник'), ('Мартин', 'лекарь')]
# Средняя оценка за качество: 4.333333333333333
# Средняя оценка по срокам: 3.4444444444444446
# Максимальная оценка за вежливость: 5.0
# Время выполнения задачи: 5
# ---
# Команда: [('Агата', 'лучник'), ('Леопольд', 'мечник'), ('Соня', 'лекарь')]
# Средняя оценка за качество: 4.166666666666667
# Средняя оценка по срокам: 3.611111111111111
# Максимальная оценка за вежливость: 5.0
# Время выполнения задачи: 5
# ---
# Команда: [('Агата', 'лучник'), ('Леопольд', 'мечник'), ('Фредерик', 'лекарь')]
# Средняя оценка за качество: 4.333333333333333
# Средняя оценка по срокам: 3.4444444444444446
# Максимальная оценка за вежливость: 5.0
# Время выполнения задачи: 5
# ---
# Команда: [('Агата', 'лучник'), ('Мартин', 'лучник'), ('Альфред', 'лекарь')]
# Средняя оценка за качество: 3.888888888888889
# Средняя оценка по срокам: 3.7222222222222228
# Максимальная оценка за вежливость: 4.666666666666667
# Время выполнения задачи: 5
# ---
# Команда: [('Агата', 'лучник'), ('Мартин', 'лучник'), ('Мартин', 'лекарь')]
# Средняя оценка за качество: 3.888888888888889
# Средняя оценка по срокам: 3.7222222222222228
# Максимальная оценка за вежливость: 4.666666666666667
# Время выполнения задачи: 5
# ---
# Команда: [('Агата', 'лучник'), ('Мартин', 'лучник'), ('Соня', 'лекарь')]
# Средняя оценка за качество: 3.722222222222222
# Средняя оценка по срокам: 3.8888888888888893
# Максимальная оценка за вежливость: 4.666666666666667
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'лучник'), ('Мартин', 'лучник'), ('Фредерик', 'лекарь')]
# Средняя оценка за качество: 3.888888888888889
# Средняя оценка по срокам: 3.7222222222222228
# Максимальная оценка за вежливость: 4.666666666666667
# Время выполнения задачи: 5
# ---
# Команда: [('Агата', 'лучник'), ('Мартин', 'рейнджер'), ('Альфред', 'лекарь')]
# Средняя оценка за качество: 3.8333333333333335
# Средняя оценка по срокам: 3.861111111111111
# Максимальная оценка за вежливость: 4.666666666666667
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'лучник'), ('Мартин', 'рейнджер'), ('Мартин', 'лекарь')]
# Средняя оценка за качество: 3.8333333333333335
# Средняя оценка по срокам: 3.861111111111111
# Максимальная оценка за вежливость: 4.666666666666667
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'лучник'), ('Мартин', 'рейнджер'), ('Соня', 'лекарь')]
# Средняя оценка за качество: 3.6666666666666665
# Средняя оценка по срокам: 4.027777777777778
# Максимальная оценка за вежливость: 4.666666666666667
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'лучник'), ('Мартин', 'рейнджер'), ('Фредерик', 'лекарь')]
# Средняя оценка за качество: 3.8333333333333335
# Средняя оценка по срокам: 3.861111111111111
# Максимальная оценка за вежливость: 4.666666666666667
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'лучник'), ('Пастушок', 'мечник'), ('Альфред', 'лекарь')]
# Средняя оценка за качество: 4.0
# Средняя оценка по срокам: 4.111111111111112
# Максимальная оценка за вежливость: 5.0
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'лучник'), ('Пастушок', 'мечник'), ('Мартин', 'лекарь')]
# Средняя оценка за качество: 4.0
# Средняя оценка по срокам: 4.111111111111112
# Максимальная оценка за вежливость: 5.0
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'лучник'), ('Пастушок', 'мечник'), ('Соня', 'лекарь')]
# Средняя оценка за качество: 3.8333333333333335
# Средняя оценка по срокам: 4.277777777777778
# Максимальная оценка за вежливость: 5.0
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'лучник'), ('Пастушок', 'мечник'), ('Фредерик', 'лекарь')]
# Средняя оценка за качество: 4.0
# Средняя оценка по срокам: 4.111111111111112
# Максимальная оценка за вежливость: 5.0
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'лучник'), ('Пастушок', 'рейнджер'), ('Альфред', 'лекарь')]
# Средняя оценка за качество: 4.0
# Средняя оценка по срокам: 4.111111111111112
# Максимальная оценка за вежливость: 5.0
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'лучник'), ('Пастушок', 'рейнджер'), ('Мартин', 'лекарь')]
# Средняя оценка за качество: 4.0
# Средняя оценка по срокам: 4.111111111111112
# Максимальная оценка за вежливость: 5.0
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'лучник'), ('Пастушок', 'рейнджер'), ('Соня', 'лекарь')]
# Средняя оценка за качество: 3.8333333333333335
# Средняя оценка по срокам: 4.277777777777778
# Максимальная оценка за вежливость: 5.0
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'лучник'), ('Пастушок', 'рейнджер'), ('Фредерик', 'лекарь')]
# Средняя оценка за качество: 4.0
# Средняя оценка по срокам: 4.111111111111112
# Максимальная оценка за вежливость: 5.0
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'лучник'), ('Синеглазый', 'мечник'), ('Альфред', 'лекарь')]
# Средняя оценка за качество: 4.0
# Средняя оценка по срокам: 3.777777777777778
# Максимальная оценка за вежливость: 4.666666666666667
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'лучник'), ('Синеглазый', 'мечник'), ('Мартин', 'лекарь')]
# Средняя оценка за качество: 4.0
# Средняя оценка по срокам: 3.777777777777778
# Максимальная оценка за вежливость: 4.666666666666667
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'лучник'), ('Синеглазый', 'мечник'), ('Соня', 'лекарь')]
# Средняя оценка за качество: 3.8333333333333335
# Средняя оценка по срокам: 3.9444444444444446
# Максимальная оценка за вежливость: 4.666666666666667
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'лучник'), ('Синеглазый', 'мечник'), ('Фредерик', 'лекарь')]
# Средняя оценка за качество: 4.0
# Средняя оценка по срокам: 3.777777777777778
# Максимальная оценка за вежливость: 4.666666666666667
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'лучник'), ('Синеглазый', 'рейнджер'), ('Альфред', 'лекарь')]
# Средняя оценка за качество: 4.0
# Средняя оценка по срокам: 3.777777777777778
# Максимальная оценка за вежливость: 4.666666666666667
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'лучник'), ('Синеглазый', 'рейнджер'), ('Мартин', 'лекарь')]
# Средняя оценка за качество: 4.0
# Средняя оценка по срокам: 3.777777777777778
# Максимальная оценка за вежливость: 4.666666666666667
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'лучник'), ('Синеглазый', 'рейнджер'), ('Соня', 'лекарь')]
# Средняя оценка за качество: 3.8333333333333335
# Средняя оценка по срокам: 3.9444444444444446
# Максимальная оценка за вежливость: 4.666666666666667
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'лучник'), ('Синеглазый', 'рейнджер'), ('Фредерик', 'лекарь')]
# Средняя оценка за качество: 4.0
# Средняя оценка по срокам: 3.777777777777778
# Максимальная оценка за вежливость: 4.666666666666667
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'лучник'), ('Соня', 'боевой маг'), ('Альфред', 'лекарь')]
# Средняя оценка за качество: 3.9333333333333336
# Средняя оценка по срокам: 3.777777777777778
# Максимальная оценка за вежливость: 4.666666666666667
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'лучник'), ('Соня', 'боевой маг'), ('Мартин', 'лекарь')]
# Средняя оценка за качество: 3.9333333333333336
# Средняя оценка по срокам: 3.777777777777778
# Максимальная оценка за вежливость: 4.666666666666667
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'лучник'), ('Соня', 'боевой маг'), ('Соня', 'лекарь')]
# Средняя оценка за качество: 3.766666666666667
# Средняя оценка по срокам: 3.9444444444444446
# Максимальная оценка за вежливость: 4.666666666666667
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'лучник'), ('Соня', 'боевой маг'), ('Фредерик', 'лекарь')]
# Средняя оценка за качество: 3.9333333333333336
# Средняя оценка по срокам: 3.777777777777778
# Максимальная оценка за вежливость: 4.666666666666667
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'лучник'), ('Соня', 'рейнджер'), ('Альфред', 'лекарь')]
# Средняя оценка за качество: 4.083333333333333
# Средняя оценка по срокам: 3.6944444444444446
# Максимальная оценка за вежливость: 4.666666666666667
# Время выполнения задачи: 5
# ---
# Команда: [('Агата', 'лучник'), ('Соня', 'рейнджер'), ('Мартин', 'лекарь')]
# Средняя оценка за качество: 4.083333333333333
# Средняя оценка по срокам: 3.6944444444444446
# Максимальная оценка за вежливость: 4.666666666666667
# Время выполнения задачи: 5
# ---
# Команда: [('Агата', 'лучник'), ('Соня', 'рейнджер'), ('Соня', 'лекарь')]
# Средняя оценка за качество: 3.9166666666666665
# Средняя оценка по срокам: 3.861111111111111
# Максимальная оценка за вежливость: 4.666666666666667
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'лучник'), ('Соня', 'рейнджер'), ('Фредерик', 'лекарь')]
# Средняя оценка за качество: 4.083333333333333
# Средняя оценка по срокам: 3.6944444444444446
# Максимальная оценка за вежливость: 4.666666666666667
# Время выполнения задачи: 5
# ---
# Команда: [('Агата', 'лучник'), ('Фредерик', 'лучник'), ('Альфред', 'лекарь')]
# Средняя оценка за качество: 4.0
# Средняя оценка по срокам: 3.777777777777778
# Максимальная оценка за вежливость: 4.666666666666667
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'лучник'), ('Фредерик', 'лучник'), ('Мартин', 'лекарь')]
# Средняя оценка за качество: 4.0
# Средняя оценка по срокам: 3.777777777777778
# Максимальная оценка за вежливость: 4.666666666666667
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'лучник'), ('Фредерик', 'лучник'), ('Соня', 'лекарь')]
# Средняя оценка за качество: 3.8333333333333335
# Средняя оценка по срокам: 3.9444444444444446
# Максимальная оценка за вежливость: 4.666666666666667
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'лучник'), ('Фредерик', 'лучник'), ('Фредерик', 'лекарь')]
# Средняя оценка за качество: 4.0
# Средняя оценка по срокам: 3.777777777777778
# Максимальная оценка за вежливость: 4.666666666666667
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'лучник'), ('Фредерик', 'рейнджер'), ('Альфред', 'лекарь')]
# Средняя оценка за качество: 4.0
# Средняя оценка по срокам: 3.777777777777778
# Максимальная оценка за вежливость: 5.0
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'лучник'), ('Фредерик', 'рейнджер'), ('Мартин', 'лекарь')]
# Средняя оценка за качество: 4.0
# Средняя оценка по срокам: 3.777777777777778
# Максимальная оценка за вежливость: 5.0
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'лучник'), ('Фредерик', 'рейнджер'), ('Соня', 'лекарь')]
# Средняя оценка за качество: 3.8333333333333335
# Средняя оценка по срокам: 3.9444444444444446
# Максимальная оценка за вежливость: 5.0
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'лучник'), ('Фредерик', 'рейнджер'), ('Фредерик', 'лекарь')]
# Средняя оценка за качество: 4.0
# Средняя оценка по срокам: 3.777777777777778
# Максимальная оценка за вежливость: 5.0
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'лучник'), ('Юлия', 'мечник'), ('Альфред', 'лекарь')]
# Средняя оценка за качество: 4.0476190476190474
# Средняя оценка по срокам: 3.5396825396825395
# Максимальная оценка за вежливость: 4.666666666666667
# Время выполнения задачи: 5
# ---
# Команда: [('Агата', 'лучник'), ('Юлия', 'мечник'), ('Мартин', 'лекарь')]
# Средняя оценка за качество: 4.0476190476190474
# Средняя оценка по срокам: 3.5396825396825395
# Максимальная оценка за вежливость: 4.666666666666667
# Время выполнения задачи: 5
# ---
# Команда: [('Агата', 'лучник'), ('Юлия', 'мечник'), ('Соня', 'лекарь')]
# Средняя оценка за качество: 3.880952380952381
# Средняя оценка по срокам: 3.706349206349206
# Максимальная оценка за вежливость: 4.666666666666667
# Время выполнения задачи: 5
# ---
# Команда: [('Агата', 'лучник'), ('Юлия', 'мечник'), ('Фредерик', 'лекарь')]
# Средняя оценка за качество: 4.0476190476190474
# Средняя оценка по срокам: 3.5396825396825395
# Максимальная оценка за вежливость: 4.666666666666667
# Время выполнения задачи: 5
# ---
# Команда: [('Агата', 'лучник'), ('Юлия', 'рейнджер'), ('Альфред', 'лекарь')]
# Средняя оценка за качество: 4.066666666666666
# Средняя оценка по срокам: 3.711111111111111
# Максимальная оценка за вежливость: 4.666666666666667
# Время выполнения задачи: 5
# ---
# Команда: [('Агата', 'лучник'), ('Юлия', 'рейнджер'), ('Мартин', 'лекарь')]
# Средняя оценка за качество: 4.066666666666666
# Средняя оценка по срокам: 3.711111111111111
# Максимальная оценка за вежливость: 4.666666666666667
# Время выполнения задачи: 5
# ---
# Команда: [('Агата', 'лучник'), ('Юлия', 'рейнджер'), ('Соня', 'лекарь')]
# Средняя оценка за качество: 3.9
# Средняя оценка по срокам: 3.8777777777777778
# Максимальная оценка за вежливость: 4.666666666666667
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'лучник'), ('Юлия', 'рейнджер'), ('Фредерик', 'лекарь')]
# Средняя оценка за качество: 4.066666666666666
# Средняя оценка по срокам: 3.711111111111111
# Максимальная оценка за вежливость: 4.666666666666667
# Время выполнения задачи: 5
# ---
# Команда: [('Агата', 'рейнджер'), ('Агата', 'лучник'), ('Альфред', 'лекарь')]
# Средняя оценка за качество: 4.0
# Средняя оценка по срокам: 3.777777777777778
# Максимальная оценка за вежливость: 4.666666666666667
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'рейнджер'), ('Агата', 'лучник'), ('Мартин', 'лекарь')]
# Средняя оценка за качество: 4.0
# Средняя оценка по срокам: 3.777777777777778
# Максимальная оценка за вежливость: 4.666666666666667
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'рейнджер'), ('Агата', 'лучник'), ('Соня', 'лекарь')]
# Средняя оценка за качество: 3.8333333333333335
# Средняя оценка по срокам: 3.9444444444444446
# Максимальная оценка за вежливость: 4.666666666666667
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'рейнджер'), ('Агата', 'лучник'), ('Фредерик', 'лекарь')]
# Средняя оценка за качество: 4.0
# Средняя оценка по срокам: 3.777777777777778
# Максимальная оценка за вежливость: 4.666666666666667
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'рейнджер'), ('Альфред', 'мечник'), ('Альфред', 'лекарь')]
# Средняя оценка за качество: 4.166666666666667
# Средняя оценка по срокам: 3.8333333333333335
# Максимальная оценка за вежливость: 4.0
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'рейнджер'), ('Альфред', 'мечник'), ('Мартин', 'лекарь')]
# Средняя оценка за качество: 4.166666666666667
# Средняя оценка по срокам: 3.8333333333333335
# Максимальная оценка за вежливость: 4.0
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'рейнджер'), ('Альфред', 'мечник'), ('Соня', 'лекарь')]
# Средняя оценка за качество: 4.0
# Средняя оценка по срокам: 4.0
# Максимальная оценка за вежливость: 4.0
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'рейнджер'), ('Альфред', 'мечник'), ('Фредерик', 'лекарь')]
# Средняя оценка за качество: 4.166666666666667
# Средняя оценка по срокам: 3.8333333333333335
# Максимальная оценка за вежливость: 4.0
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'рейнджер'), ('Альфред', 'рейнджер'), ('Альфред', 'лекарь')]
# Средняя оценка за качество: 4.333333333333333
# Средняя оценка по срокам: 3.6666666666666665
# Максимальная оценка за вежливость: 5.0
# Время выполнения задачи: 5
# ---
# Команда: [('Агата', 'рейнджер'), ('Альфред', 'рейнджер'), ('Мартин', 'лекарь')]
# Средняя оценка за качество: 4.333333333333333
# Средняя оценка по срокам: 3.6666666666666665
# Максимальная оценка за вежливость: 5.0
# Время выполнения задачи: 5
# ---
# Команда: [('Агата', 'рейнджер'), ('Альфред', 'рейнджер'), ('Соня', 'лекарь')]
# Средняя оценка за качество: 4.166666666666667
# Средняя оценка по срокам: 3.8333333333333335
# Максимальная оценка за вежливость: 5.0
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'рейнджер'), ('Альфред', 'рейнджер'), ('Фредерик', 'лекарь')]
# Средняя оценка за качество: 4.333333333333333
# Средняя оценка по срокам: 3.6666666666666665
# Максимальная оценка за вежливость: 5.0
# Время выполнения задачи: 5
# ---
# Команда: [('Агата', 'рейнджер'), ('Бендер', 'мечник'), ('Альфред', 'лекарь')]
# Средняя оценка за качество: 4.0
# Средняя оценка по срокам: 3.6666666666666665
# Максимальная оценка за вежливость: 4.5
# Время выполнения задачи: 5
# ---
# Команда: [('Агата', 'рейнджер'), ('Бендер', 'мечник'), ('Мартин', 'лекарь')]
# Средняя оценка за качество: 4.0
# Средняя оценка по срокам: 3.6666666666666665
# Максимальная оценка за вежливость: 4.5
# Время выполнения задачи: 5
# ---
# Команда: [('Агата', 'рейнджер'), ('Бендер', 'мечник'), ('Соня', 'лекарь')]
# Средняя оценка за качество: 3.8333333333333335
# Средняя оценка по срокам: 3.8333333333333335
# Максимальная оценка за вежливость: 4.5
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'рейнджер'), ('Бендер', 'мечник'), ('Фредерик', 'лекарь')]
# Средняя оценка за качество: 4.0
# Средняя оценка по срокам: 3.6666666666666665
# Максимальная оценка за вежливость: 4.5
# Время выполнения задачи: 5
# ---
# Команда: [('Агата', 'рейнджер'), ('Бендер', 'рейнджер'), ('Альфред', 'лекарь')]
# Средняя оценка за качество: 4.333333333333333
# Средняя оценка по срокам: 4.0
# Максимальная оценка за вежливость: 4.5
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'рейнджер'), ('Бендер', 'рейнджер'), ('Мартин', 'лекарь')]
# Средняя оценка за качество: 4.333333333333333
# Средняя оценка по срокам: 4.0
# Максимальная оценка за вежливость: 4.5
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'рейнджер'), ('Бендер', 'рейнджер'), ('Соня', 'лекарь')]
# Средняя оценка за качество: 4.166666666666667
# Средняя оценка по срокам: 4.166666666666667
# Максимальная оценка за вежливость: 4.5
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'рейнджер'), ('Бендер', 'рейнджер'), ('Фредерик', 'лекарь')]
# Средняя оценка за качество: 4.333333333333333
# Средняя оценка по срокам: 4.0
# Максимальная оценка за вежливость: 4.5
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'рейнджер'), ('Бенедикт', 'мечник'), ('Альфред', 'лекарь')]
# Средняя оценка за качество: 4.0
# Средняя оценка по срокам: 3.9166666666666665
# Максимальная оценка за вежливость: 4.5
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'рейнджер'), ('Бенедикт', 'мечник'), ('Мартин', 'лекарь')]
# Средняя оценка за качество: 4.0
# Средняя оценка по срокам: 3.9166666666666665
# Максимальная оценка за вежливость: 4.5
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'рейнджер'), ('Бенедикт', 'мечник'), ('Соня', 'лекарь')]
# Средняя оценка за качество: 3.8333333333333335
# Средняя оценка по срокам: 4.083333333333333
# Максимальная оценка за вежливость: 4.5
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'рейнджер'), ('Бенедикт', 'мечник'), ('Фредерик', 'лекарь')]
# Средняя оценка за качество: 4.0
# Средняя оценка по срокам: 3.9166666666666665
# Максимальная оценка за вежливость: 4.5
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'рейнджер'), ('Бенедикт', 'рейнджер'), ('Альфред', 'лекарь')]
# Средняя оценка за качество: 4.0
# Средняя оценка по срокам: 3.9166666666666665
# Максимальная оценка за вежливость: 4.5
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'рейнджер'), ('Бенедикт', 'рейнджер'), ('Мартин', 'лекарь')]
# Средняя оценка за качество: 4.0
# Средняя оценка по срокам: 3.9166666666666665
# Максимальная оценка за вежливость: 4.5
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'рейнджер'), ('Бенедикт', 'рейнджер'), ('Соня', 'лекарь')]
# Средняя оценка за качество: 3.8333333333333335
# Средняя оценка по срокам: 4.083333333333333
# Максимальная оценка за вежливость: 4.5
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'рейнджер'), ('Бенедикт', 'рейнджер'), ('Фредерик', 'лекарь')]
# Средняя оценка за качество: 4.0
# Средняя оценка по срокам: 3.9166666666666665
# Максимальная оценка за вежливость: 4.5
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'рейнджер'), ('Леопольд', 'мечник'), ('Альфред', 'лекарь')]
# Средняя оценка за качество: 4.333333333333333
# Средняя оценка по срокам: 3.6666666666666665
# Максимальная оценка за вежливость: 5.0
# Время выполнения задачи: 5
# ---
# Команда: [('Агата', 'рейнджер'), ('Леопольд', 'мечник'), ('Мартин', 'лекарь')]
# Средняя оценка за качество: 4.333333333333333
# Средняя оценка по срокам: 3.6666666666666665
# Максимальная оценка за вежливость: 5.0
# Время выполнения задачи: 5
# ---
# Команда: [('Агата', 'рейнджер'), ('Леопольд', 'мечник'), ('Соня', 'лекарь')]
# Средняя оценка за качество: 4.166666666666667
# Средняя оценка по срокам: 3.8333333333333335
# Максимальная оценка за вежливость: 5.0
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'рейнджер'), ('Леопольд', 'мечник'), ('Фредерик', 'лекарь')]
# Средняя оценка за качество: 4.333333333333333
# Средняя оценка по срокам: 3.6666666666666665
# Максимальная оценка за вежливость: 5.0
# Время выполнения задачи: 5
# ---
# Команда: [('Агата', 'рейнджер'), ('Мартин', 'лучник'), ('Альфред', 'лекарь')]
# Средняя оценка за качество: 3.888888888888889
# Средняя оценка по срокам: 3.9444444444444446
# Максимальная оценка за вежливость: 4.0
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'рейнджер'), ('Мартин', 'лучник'), ('Мартин', 'лекарь')]
# Средняя оценка за качество: 3.888888888888889
# Средняя оценка по срокам: 3.9444444444444446
# Максимальная оценка за вежливость: 4.0
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'рейнджер'), ('Мартин', 'лучник'), ('Соня', 'лекарь')]
# Средняя оценка за качество: 3.722222222222222
# Средняя оценка по срокам: 4.111111111111112
# Максимальная оценка за вежливость: 4.0
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'рейнджер'), ('Мартин', 'лучник'), ('Фредерик', 'лекарь')]
# Средняя оценка за качество: 3.888888888888889
# Средняя оценка по срокам: 3.9444444444444446
# Максимальная оценка за вежливость: 4.0
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'рейнджер'), ('Мартин', 'рейнджер'), ('Альфред', 'лекарь')]
# Средняя оценка за качество: 3.8333333333333335
# Средняя оценка по срокам: 4.083333333333333
# Максимальная оценка за вежливость: 4.0
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'рейнджер'), ('Мартин', 'рейнджер'), ('Мартин', 'лекарь')]
# Средняя оценка за качество: 3.8333333333333335
# Средняя оценка по срокам: 4.083333333333333
# Максимальная оценка за вежливость: 4.0
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'рейнджер'), ('Мартин', 'рейнджер'), ('Соня', 'лекарь')]
# Средняя оценка за качество: 3.6666666666666665
# Средняя оценка по срокам: 4.25
# Максимальная оценка за вежливость: 4.0
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'рейнджер'), ('Мартин', 'рейнджер'), ('Фредерик', 'лекарь')]
# Средняя оценка за качество: 3.8333333333333335
# Средняя оценка по срокам: 4.083333333333333
# Максимальная оценка за вежливость: 4.0
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'рейнджер'), ('Пастушок', 'мечник'), ('Альфред', 'лекарь')]
# Средняя оценка за качество: 4.0
# Средняя оценка по срокам: 4.333333333333333
# Максимальная оценка за вежливость: 5.0
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'рейнджер'), ('Пастушок', 'мечник'), ('Мартин', 'лекарь')]
# Средняя оценка за качество: 4.0
# Средняя оценка по срокам: 4.333333333333333
# Максимальная оценка за вежливость: 5.0
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'рейнджер'), ('Пастушок', 'мечник'), ('Соня', 'лекарь')]
# Средняя оценка за качество: 3.8333333333333335
# Средняя оценка по срокам: 4.5
# Максимальная оценка за вежливость: 5.0
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'рейнджер'), ('Пастушок', 'мечник'), ('Фредерик', 'лекарь')]
# Средняя оценка за качество: 4.0
# Средняя оценка по срокам: 4.333333333333333
# Максимальная оценка за вежливость: 5.0
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'рейнджер'), ('Пастушок', 'рейнджер'), ('Альфред', 'лекарь')]
# Средняя оценка за качество: 4.0
# Средняя оценка по срокам: 4.333333333333333
# Максимальная оценка за вежливость: 5.0
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'рейнджер'), ('Пастушок', 'рейнджер'), ('Мартин', 'лекарь')]
# Средняя оценка за качество: 4.0
# Средняя оценка по срокам: 4.333333333333333
# Максимальная оценка за вежливость: 5.0
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'рейнджер'), ('Пастушок', 'рейнджер'), ('Соня', 'лекарь')]
# Средняя оценка за качество: 3.8333333333333335
# Средняя оценка по срокам: 4.5
# Максимальная оценка за вежливость: 5.0
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'рейнджер'), ('Пастушок', 'рейнджер'), ('Фредерик', 'лекарь')]
# Средняя оценка за качество: 4.0
# Средняя оценка по срокам: 4.333333333333333
# Максимальная оценка за вежливость: 5.0
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'рейнджер'), ('Синеглазый', 'мечник'), ('Альфред', 'лекарь')]
# Средняя оценка за качество: 4.0
# Средняя оценка по срокам: 4.0
# Максимальная оценка за вежливость: 4.0
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'рейнджер'), ('Синеглазый', 'мечник'), ('Мартин', 'лекарь')]
# Средняя оценка за качество: 4.0
# Средняя оценка по срокам: 4.0
# Максимальная оценка за вежливость: 4.0
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'рейнджер'), ('Синеглазый', 'мечник'), ('Соня', 'лекарь')]
# Средняя оценка за качество: 3.8333333333333335
# Средняя оценка по срокам: 4.166666666666667
# Максимальная оценка за вежливость: 4.0
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'рейнджер'), ('Синеглазый', 'мечник'), ('Фредерик', 'лекарь')]
# Средняя оценка за качество: 4.0
# Средняя оценка по срокам: 4.0
# Максимальная оценка за вежливость: 4.0
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'рейнджер'), ('Синеглазый', 'рейнджер'), ('Альфред', 'лекарь')]
# Средняя оценка за качество: 4.0
# Средняя оценка по срокам: 4.0
# Максимальная оценка за вежливость: 4.0
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'рейнджер'), ('Синеглазый', 'рейнджер'), ('Мартин', 'лекарь')]
# Средняя оценка за качество: 4.0
# Средняя оценка по срокам: 4.0
# Максимальная оценка за вежливость: 4.0
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'рейнджер'), ('Синеглазый', 'рейнджер'), ('Соня', 'лекарь')]
# Средняя оценка за качество: 3.8333333333333335
# Средняя оценка по срокам: 4.166666666666667
# Максимальная оценка за вежливость: 4.0
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'рейнджер'), ('Синеглазый', 'рейнджер'), ('Фредерик', 'лекарь')]
# Средняя оценка за качество: 4.0
# Средняя оценка по срокам: 4.0
# Максимальная оценка за вежливость: 4.0
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'рейнджер'), ('Соня', 'боевой маг'), ('Альфред', 'лекарь')]
# Средняя оценка за качество: 3.9333333333333336
# Средняя оценка по срокам: 4.0
# Максимальная оценка за вежливость: 4.0
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'рейнджер'), ('Соня', 'боевой маг'), ('Мартин', 'лекарь')]
# Средняя оценка за качество: 3.9333333333333336
# Средняя оценка по срокам: 4.0
# Максимальная оценка за вежливость: 4.0
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'рейнджер'), ('Соня', 'боевой маг'), ('Соня', 'лекарь')]
# Средняя оценка за качество: 3.766666666666667
# Средняя оценка по срокам: 4.166666666666667
# Максимальная оценка за вежливость: 4.0
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'рейнджер'), ('Соня', 'боевой маг'), ('Фредерик', 'лекарь')]
# Средняя оценка за качество: 3.9333333333333336
# Средняя оценка по срокам: 4.0
# Максимальная оценка за вежливость: 4.0
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'рейнджер'), ('Соня', 'рейнджер'), ('Альфред', 'лекарь')]
# Средняя оценка за качество: 4.083333333333333
# Средняя оценка по срокам: 3.9166666666666665
# Максимальная оценка за вежливость: 4.0
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'рейнджер'), ('Соня', 'рейнджер'), ('Мартин', 'лекарь')]
# Средняя оценка за качество: 4.083333333333333
# Средняя оценка по срокам: 3.9166666666666665
# Максимальная оценка за вежливость: 4.0
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'рейнджер'), ('Соня', 'рейнджер'), ('Соня', 'лекарь')]
# Средняя оценка за качество: 3.9166666666666665
# Средняя оценка по срокам: 4.083333333333333
# Максимальная оценка за вежливость: 4.0
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'рейнджер'), ('Соня', 'рейнджер'), ('Фредерик', 'лекарь')]
# Средняя оценка за качество: 4.083333333333333
# Средняя оценка по срокам: 3.9166666666666665
# Максимальная оценка за вежливость: 4.0
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'рейнджер'), ('Фредерик', 'лучник'), ('Альфред', 'лекарь')]
# Средняя оценка за качество: 4.0
# Средняя оценка по срокам: 4.0
# Максимальная оценка за вежливость: 4.333333333333333
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'рейнджер'), ('Фредерик', 'лучник'), ('Мартин', 'лекарь')]
# Средняя оценка за качество: 4.0
# Средняя оценка по срокам: 4.0
# Максимальная оценка за вежливость: 4.333333333333333
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'рейнджер'), ('Фредерик', 'лучник'), ('Соня', 'лекарь')]
# Средняя оценка за качество: 3.8333333333333335
# Средняя оценка по срокам: 4.166666666666667
# Максимальная оценка за вежливость: 4.333333333333333
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'рейнджер'), ('Фредерик', 'лучник'), ('Фредерик', 'лекарь')]
# Средняя оценка за качество: 4.0
# Средняя оценка по срокам: 4.0
# Максимальная оценка за вежливость: 4.333333333333333
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'рейнджер'), ('Фредерик', 'рейнджер'), ('Альфред', 'лекарь')]
# Средняя оценка за качество: 4.0
# Средняя оценка по срокам: 4.0
# Максимальная оценка за вежливость: 5.0
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'рейнджер'), ('Фредерик', 'рейнджер'), ('Мартин', 'лекарь')]
# Средняя оценка за качество: 4.0
# Средняя оценка по срокам: 4.0
# Максимальная оценка за вежливость: 5.0
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'рейнджер'), ('Фредерик', 'рейнджер'), ('Соня', 'лекарь')]
# Средняя оценка за качество: 3.8333333333333335
# Средняя оценка по срокам: 4.166666666666667
# Максимальная оценка за вежливость: 5.0
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'рейнджер'), ('Фредерик', 'рейнджер'), ('Фредерик', 'лекарь')]
# Средняя оценка за качество: 4.0
# Средняя оценка по срокам: 4.0
# Максимальная оценка за вежливость: 5.0
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'рейнджер'), ('Юлия', 'мечник'), ('Альфред', 'лекарь')]
# Средняя оценка за качество: 4.0476190476190474
# Средняя оценка по срокам: 3.7619047619047614
# Максимальная оценка за вежливость: 4.0
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'рейнджер'), ('Юлия', 'мечник'), ('Мартин', 'лекарь')]
# Средняя оценка за качество: 4.0476190476190474
# Средняя оценка по срокам: 3.7619047619047614
# Максимальная оценка за вежливость: 4.0
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'рейнджер'), ('Юлия', 'мечник'), ('Соня', 'лекарь')]
# Средняя оценка за качество: 3.880952380952381
# Средняя оценка по срокам: 3.9285714285714284
# Максимальная оценка за вежливость: 4.0
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'рейнджер'), ('Юлия', 'мечник'), ('Фредерик', 'лекарь')]
# Средняя оценка за качество: 4.0476190476190474
# Средняя оценка по срокам: 3.7619047619047614
# Максимальная оценка за вежливость: 4.0
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'рейнджер'), ('Юлия', 'рейнджер'), ('Альфред', 'лекарь')]
# Средняя оценка за качество: 4.066666666666666
# Средняя оценка по срокам: 3.9333333333333336
# Максимальная оценка за вежливость: 4.0
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'рейнджер'), ('Юлия', 'рейнджер'), ('Мартин', 'лекарь')]
# Средняя оценка за качество: 4.066666666666666
# Средняя оценка по срокам: 3.9333333333333336
# Максимальная оценка за вежливость: 4.0
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'рейнджер'), ('Юлия', 'рейнджер'), ('Соня', 'лекарь')]
# Средняя оценка за качество: 3.9
# Средняя оценка по срокам: 4.1000000000000005
# Максимальная оценка за вежливость: 4.0
# Время выполнения задачи: 4
# ---
# Команда: [('Агата', 'рейнджер'), ('Юлия', 'рейнджер'), ('Фредерик', 'лекарь')]
# Средняя оценка за качество: 4.066666666666666
# Средняя оценка по срокам: 3.9333333333333336
# Максимальная оценка за вежливость: 4.0
# Время выполнения задачи: 4
# ---
# Команда: [('Альфред', 'мечник'), ('Агата', 'лучник'), ('Альфред', 'лекарь')]
# Средняя оценка за качество: 4.166666666666667
# Средняя оценка по срокам: 3.611111111111111
# Максимальная оценка за вежливость: 4.666666666666667
# Время выполнения задачи: 5
# ---
# Команда: [('Альфред', 'мечник'), ('Агата', 'лучник'), ('Мартин', 'лекарь')]
# Средняя оценка за качество: 4.166666666666667
# Средняя оценка по срокам: 3.611111111111111
# Максимальная оценка за вежливость: 4.666666666666667
# Время выполнения задачи: 5
# ---
# Команда: [('Альфред', 'мечник'), ('Агата', 'лучник'), ('Соня', 'лекарь')]
# Средняя оценка за качество: 4.0
# Средняя оценка по срокам: 3.777777777777778
# Максимальная оценка за вежливость: 4.666666666666667
# Время выполнения задачи: 4
# ---
# Команда: [('Альфред', 'мечник'), ('Агата', 'лучник'), ('Фредерик', 'лекарь')]
# Средняя оценка за качество: 4.166666666666667
# Средняя оценка по срокам: 3.611111111111111
# Максимальная оценка за вежливость: 4.666666666666667
# Время выполнения задачи: 5
# ---
# Команда: [('Альфред', 'мечник'), ('Агата', 'рейнджер'), ('Альфред', 'лекарь')]
# Средняя оценка за качество: 4.166666666666667
# Средняя оценка по срокам: 3.8333333333333335
# Максимальная оценка за вежливость: 4.0
# Время выполнения задачи: 4
# ---
# Команда: [('Альфред', 'мечник'), ('Агата', 'рейнджер'), ('Мартин', 'лекарь')]
# Средняя оценка за качество: 4.166666666666667
# Средняя оценка по срокам: 3.8333333333333335
# Максимальная оценка за вежливость: 4.0
# Время выполнения задачи: 4
# ---
# Команда: [('Альфред', 'мечник'), ('Агата', 'рейнджер'), ('Соня', 'лекарь')]
# Средняя оценка за качество: 4.0
# Средняя оценка по срокам: 4.0
# Максимальная оценка за вежливость: 4.0
# Время выполнения задачи: 4
# ---
# Команда: [('Альфред', 'мечник'), ('Агата', 'рейнджер'), ('Фредерик', 'лекарь')]
# Средняя оценка за качество: 4.166666666666667
# Средняя оценка по срокам: 3.8333333333333335
# Максимальная оценка за вежливость: 4.0
# Время выполнения задачи: 4
# ---
# Команда: [('Альфред', 'мечник'), ('Альфред', 'рейнджер'), ('Альфред', 'лекарь')]
# Средняя оценка за качество: 4.5
# Средняя оценка по срокам: 3.5
# Максимальная оценка за вежливость: 5.0
# Время выполнения задачи: 5
# ---
# Команда: [('Альфред', 'мечник'), ('Альфред', 'рейнджер'), ('Мартин', 'лекарь')]
# Средняя оценка за качество: 4.5
# Средняя оценка по срокам: 3.5
# Максимальная оценка за вежливость: 5.0
# Время выполнения задачи: 5
# ---
# Команда: [('Альфред', 'мечник'), ('Альфред', 'рейнджер'), ('Соня', 'лекарь')]
# Средняя оценка за качество: 4.333333333333333
# Средняя оценка по срокам: 3.6666666666666665
# Максимальная оценка за вежливость: 5.0
# Время выполнения задачи: 5
# ---
# Команда: [('Альфред', 'мечник'), ('Альфред', 'рейнджер'), ('Фредерик', 'лекарь')]
# Средняя оценка за качество: 4.5
# Средняя оценка по срокам: 3.5
# Максимальная оценка за вежливость: 5.0
# Время выполнения задачи: 5
# ---
# Команда: [('Альфред', 'мечник'), ('Бендер', 'мечник'), ('Альфред', 'лекарь')]
# Средняя оценка за качество: 4.166666666666667
# Средняя оценка по срокам: 3.5
# Максимальная оценка за вежливость: 4.5
# Время выполнения задачи: 5
# ---
# Команда: [('Альфред', 'мечник'), ('Бендер', 'мечник'), ('Мартин', 'лекарь')]
# Средняя оценка за качество: 4.166666666666667
# Средняя оценка по срокам: 3.5
# Максимальная оценка за вежливость: 4.5
# Время выполнения задачи: 5
# ---
# Команда: [('Альфред', 'мечник'), ('Бендер', 'мечник'), ('Соня', 'лекарь')]
# Средняя оценка за качество: 4.0
# Средняя оценка по срокам: 3.6666666666666665
# Максимальная оценка за вежливость: 4.5
# Время выполнения задачи: 5
# ---
# Команда: [('Альфред', 'мечник'), ('Бендер', 'мечник'), ('Фредерик', 'лекарь')]
# Средняя оценка за качество: 4.166666666666667
# Средняя оценка по срокам: 3.5
# Максимальная оценка за вежливость: 4.5
# Время выполнения задачи: 5
# ---
# Команда: [('Альфред', 'мечник'), ('Бендер', 'рейнджер'), ('Альфред', 'лекарь')]
# Средняя оценка за качество: 4.5
# Средняя оценка по срокам: 3.8333333333333335
# Максимальная оценка за вежливость: 4.5
# Время выполнения задачи: 4
# ---
# Команда: [('Альфред', 'мечник'), ('Бендер', 'рейнджер'), ('Мартин', 'лекарь')]
# Средняя оценка за качество: 4.5
# Средняя оценка по срокам: 3.8333333333333335
# Максимальная оценка за вежливость: 4.5
# Время выполнения задачи: 4
# ---
# Команда: [('Альфред', 'мечник'), ('Бендер', 'рейнджер'), ('Соня', 'лекарь')]
# Средняя оценка за качество: 4.333333333333333
# Средняя оценка по срокам: 4.0
# Максимальная оценка за вежливость: 4.5
# Время выполнения задачи: 4
# ---
# Команда: [('Альфред', 'мечник'), ('Бендер', 'рейнджер'), ('Фредерик', 'лекарь')]
# Средняя оценка за качество: 4.5
# Средняя оценка по срокам: 3.8333333333333335
# Максимальная оценка за вежливость: 4.5
# Время выполнения задачи: 4
# ---
# Команда: [('Альфред', 'мечник'), ('Бенедикт', 'мечник'), ('Альфред', 'лекарь')]
# Средняя оценка за качество: 4.166666666666667
# Средняя оценка по срокам: 3.75
# Максимальная оценка за вежливость: 4.5
# Время выполнения задачи: 4
# ---
# Команда: [('Альфред', 'мечник'), ('Бенедикт', 'мечник'), ('Мартин', 'лекарь')]
# Средняя оценка за качество: 4.166666666666667
# Средняя оценка по срокам: 3.75
# Максимальная оценка за вежливость: 4.5
# Время выполнения задачи: 4
# ---
# Команда: [('Альфред', 'мечник'), ('Бенедикт', 'мечник'), ('Соня', 'лекарь')]
# Средняя оценка за качество: 4.0
# Средняя оценка по срокам: 3.9166666666666665
# Максимальная оценка за вежливость: 4.5
# Время выполнения задачи: 4
# ---
# Команда: [('Альфред', 'мечник'), ('Бенедикт', 'мечник'), ('Фредерик', 'лекарь')]
# Средняя оценка за качество: 4.166666666666667
# Средняя оценка по срокам: 3.75
# Максимальная оценка за вежливость: 4.5
# Время выполнения задачи: 4
# ---
# Команда: [('Альфред', 'мечник'), ('Бенедикт', 'рейнджер'), ('Альфред', 'лекарь')]
# Средняя оценка за качество: 4.166666666666667
# Средняя оценка по срокам: 3.75
# Максимальная оценка за вежливость: 4.5
# Время выполнения задачи: 4
# ---
# Команда: [('Альфред', 'мечник'), ('Бенедикт', 'рейнджер'), ('Мартин', 'лекарь')]
# Средняя оценка за качество: 4.166666666666667
# Средняя оценка по срокам: 3.75
# Максимальная оценка за вежливость: 4.5
# Время выполнения задачи: 4
# ---
# Команда: [('Альфред', 'мечник'), ('Бенедикт', 'рейнджер'), ('Соня', 'лекарь')]
# Средняя оценка за качество: 4.0
# Средняя оценка по срокам: 3.9166666666666665
# Максимальная оценка за вежливость: 4.5
# Время выполнения задачи: 4
# ---
# Команда: [('Альфред', 'мечник'), ('Бенедикт', 'рейнджер'), ('Фредерик', 'лекарь')]
# Средняя оценка за качество: 4.166666666666667
# Средняя оценка по срокам: 3.75
# Максимальная оценка за вежливость: 4.5
# Время выполнения задачи: 4
# ---
# Команда: [('Альфред', 'мечник'), ('Леопольд', 'мечник'), ('Альфред', 'лекарь')]
# Средняя оценка за качество: 4.5
# Средняя оценка по срокам: 3.5
# Максимальная оценка за вежливость: 5.0
# Время выполнения задачи: 5
# ---
# Команда: [('Альфред', 'мечник'), ('Леопольд', 'мечник'), ('Мартин', 'лекарь')]
# Средняя оценка за качество: 4.5
# Средняя оценка по срокам: 3.5
# Максимальная оценка за вежливость: 5.0
# Время выполнения задачи: 5
# ---
# Команда: [('Альфред', 'мечник'), ('Леопольд', 'мечник'), ('Соня', 'лекарь')]
# Средняя оценка за качество: 4.333333333333333
# Средняя оценка по срокам: 3.6666666666666665
# Максимальная оценка за вежливость: 5.0
# Время выполнения задачи: 5
# ---
# Команда: [('Альфред', 'мечник'), ('Леопольд', 'мечник'), ('Фредерик', 'лекарь')]
# Средняя оценка за качество: 4.5
# Средняя оценка по срокам: 3.5
# Максимальная оценка за вежливость: 5.0
# Время выполнения задачи: 5
# ---
# Команда: [('Альфред', 'мечник'), ('Мартин', 'лучник'), ('Альфред', 'лекарь')]
# Средняя оценка за качество: 4.055555555555555
# Средняя оценка по срокам: 3.777777777777778
# Максимальная оценка за вежливость: 4.0
# Время выполнения задачи: 4
# ---
# Команда: [('Альфред', 'мечник'), ('Мартин', 'лучник'), ('Мартин', 'лекарь')]
# Средняя оценка за качество: 4.055555555555555
# Средняя оценка по срокам: 3.777777777777778
# Максимальная оценка за вежливость: 4.0
# Время выполнения задачи: 4
# ---
# Команда: [('Альфред', 'мечник'), ('Мартин', 'лучник'), ('Соня', 'лекарь')]
# Средняя оценка за качество: 3.888888888888889
# Средняя оценка по срокам: 3.9444444444444446
# Максимальная оценка за вежливость: 4.0
# Время выполнения задачи: 4
# ---
# Команда: [('Альфред', 'мечник'), ('Мартин', 'лучник'), ('Фредерик', 'лекарь')]
# Средняя оценка за качество: 4.055555555555555
# Средняя оценка по срокам: 3.777777777777778
# Максимальная оценка за вежливость: 4.0
# Время выполнения задачи: 4
# ---
# Команда: [('Альфред', 'мечник'), ('Мартин', 'рейнджер'), ('Альфред', 'лекарь')]
# Средняя оценка за качество: 4.0
# Средняя оценка по срокам: 3.9166666666666665
# Максимальная оценка за вежливость: 4.0
# Время выполнения задачи: 4
# ---
# Команда: [('Альфред', 'мечник'), ('Мартин', 'рейнджер'), ('Мартин', 'лекарь')]
# Средняя оценка за качество: 4.0
# Средняя оценка по срокам: 3.9166666666666665
# Максимальная оценка за вежливость: 4.0
# Время выполнения задачи: 4
# ---
# Команда: [('Альфред', 'мечник'), ('Мартин', 'рейнджер'), ('Соня', 'лекарь')]
# Средняя оценка за качество: 3.8333333333333335
# Средняя оценка по срокам: 4.083333333333333
# Максимальная оценка за вежливость: 4.0
# Время выполнения задачи: 4
# ---
# Команда: [('Альфред', 'мечник'), ('Мартин', 'рейнджер'), ('Фредерик', 'лекарь')]
# Средняя оценка за качество: 4.0
# Средняя оценка по срокам: 3.9166666666666665
# Максимальная оценка за вежливость: 4.0
# Время выполнения задачи: 4
# ---
# Команда: [('Альфред', 'мечник'), ('Пастушок', 'мечник'), ('Альфред', 'лекарь')]
# Средняя оценка за качество: 4.166666666666667
# Средняя оценка по срокам: 4.166666666666667
# Максимальная оценка за вежливость: 5.0
# Время выполнения задачи: 4
# ---
# Команда: [('Альфред', 'мечник'), ('Пастушок', 'мечник'), ('Мартин', 'лекарь')]
# Средняя оценка за качество: 4.166666666666667
# Средняя оценка по срокам: 4.166666666666667
# Максимальная оценка за вежливость: 5.0
# Время выполнения задачи: 4
# ---
# Команда: [('Альфред', 'мечник'), ('Пастушок', 'мечник'), ('Соня', 'лекарь')]
# Средняя оценка за качество: 4.0
# Средняя оценка по срокам: 4.333333333333333
# Максимальная оценка за вежливость: 5.0
# Время выполнения задачи: 4
# ---
# Команда: [('Альфред', 'мечник'), ('Пастушок', 'мечник'), ('Фредерик', 'лекарь')]
# Средняя оценка за качество: 4.166666666666667
# ...
# Время выполнения задачи: 4
# ---
# Команда: [('Юлия', 'рейнджер'), ('Альфред', 'рейнджер'), ('Альфред', 'лекарь')]
# Средняя оценка за качество: 4.3999999999999995
# Средняя оценка по срокам: 3.6
# Максимальная оценка за вежливость: 5.0
# Время выполнения задачи: 5
# ---
# Команда: [('Юлия', 'рейнджер'), ('Альфред', 'рейнджер'), ('Мартин', 'лекарь')]
# Средняя оценка за качество: 4.3999999999999995
# Средняя оценка по срокам: 3.6
# Максимальная оценка за вежливость: 5.0
# Время выполнения задачи: 5
# ---
# Команда: [('Юлия', 'рейнджер'), ('Альфред', 'рейнджер'), ('Соня', 'лекарь')]
# Средняя оценка за качество: 4.233333333333333
# Средняя оценка по срокам: 3.766666666666667
# Максимальная оценка за вежливость: 5.0
# Время выполнения задачи: 4
# ---
# Команда: [('Юлия', 'рейнджер'), ('Альфред', 'рейнджер'), ('Фредерик', 'лекарь')]
# Средняя оценка за качество: 4.3999999999999995
# Средняя оценка по срокам: 3.6
# Максимальная оценка за вежливость: 5.0
# Время выполнения задачи: 5
# ---
# Команда: [('Юлия', 'рейнджер'), ('Бендер', 'мечник'), ('Альфред', 'лекарь')]
# Средняя оценка за качество: 4.066666666666666
# Средняя оценка по срокам: 3.6
# Максимальная оценка за вежливость: 4.5
# Время выполнения задачи: 5
# ---
# Команда: [('Юлия', 'рейнджер'), ('Бендер', 'мечник'), ('Мартин', 'лекарь')]
# Средняя оценка за качество: 4.066666666666666
# Средняя оценка по срокам: 3.6
# Максимальная оценка за вежливость: 4.5
# Время выполнения задачи: 5
# ---
# Команда: [('Юлия', 'рейнджер'), ('Бендер', 'мечник'), ('Соня', 'лекарь')]
# Средняя оценка за качество: 3.9
# Средняя оценка по срокам: 3.766666666666667
# Максимальная оценка за вежливость: 4.5
# Время выполнения задачи: 4
# ---
# Команда: [('Юлия', 'рейнджер'), ('Бендер', 'мечник'), ('Фредерик', 'лекарь')]
# Средняя оценка за качество: 4.066666666666666
# Средняя оценка по срокам: 3.6
# Максимальная оценка за вежливость: 4.5
# Время выполнения задачи: 5
# ---
# Команда: [('Юлия', 'рейнджер'), ('Бендер', 'рейнджер'), ('Альфред', 'лекарь')]
# Средняя оценка за качество: 4.3999999999999995
# Средняя оценка по срокам: 3.9333333333333336
# Максимальная оценка за вежливость: 4.5
# Время выполнения задачи: 4
# ---
# Команда: [('Юлия', 'рейнджер'), ('Бендер', 'рейнджер'), ('Мартин', 'лекарь')]
# Средняя оценка за качество: 4.3999999999999995
# Средняя оценка по срокам: 3.9333333333333336
# Максимальная оценка за вежливость: 4.5
# Время выполнения задачи: 4
# ---
# Команда: [('Юлия', 'рейнджер'), ('Бендер', 'рейнджер'), ('Соня', 'лекарь')]
# Средняя оценка за качество: 4.233333333333333
# Средняя оценка по срокам: 4.1000000000000005
# Максимальная оценка за вежливость: 4.5
# Время выполнения задачи: 4
# ---
# Команда: [('Юлия', 'рейнджер'), ('Бендер', 'рейнджер'), ('Фредерик', 'лекарь')]
# Средняя оценка за качество: 4.3999999999999995
# Средняя оценка по срокам: 3.9333333333333336
# Максимальная оценка за вежливость: 4.5
# Время выполнения задачи: 4
# ---
# Команда: [('Юлия', 'рейнджер'), ('Бенедикт', 'мечник'), ('Альфред', 'лекарь')]
# Средняя оценка за качество: 4.066666666666666
# Средняя оценка по срокам: 3.85
# Максимальная оценка за вежливость: 4.5
# Время выполнения задачи: 4
# ---
# Команда: [('Юлия', 'рейнджер'), ('Бенедикт', 'мечник'), ('Мартин', 'лекарь')]
# Средняя оценка за качество: 4.066666666666666
# Средняя оценка по срокам: 3.85
# Максимальная оценка за вежливость: 4.5
# Время выполнения задачи: 4
# ---
# Команда: [('Юлия', 'рейнджер'), ('Бенедикт', 'мечник'), ('Соня', 'лекарь')]
# Средняя оценка за качество: 3.9
# Средняя оценка по срокам: 4.016666666666667
# Максимальная оценка за вежливость: 4.5
# Время выполнения задачи: 4
# ---
# Команда: [('Юлия', 'рейнджер'), ('Бенедикт', 'мечник'), ('Фредерик', 'лекарь')]
# Средняя оценка за качество: 4.066666666666666
# Средняя оценка по срокам: 3.85
# Максимальная оценка за вежливость: 4.5
# Время выполнения задачи: 4
# ---
# Команда: [('Юлия', 'рейнджер'), ('Бенедикт', 'рейнджер'), ('Альфред', 'лекарь')]
# Средняя оценка за качество: 4.066666666666666
# Средняя оценка по срокам: 3.85
# Максимальная оценка за вежливость: 4.5
# Время выполнения задачи: 4
# ---
# Команда: [('Юлия', 'рейнджер'), ('Бенедикт', 'рейнджер'), ('Мартин', 'лекарь')]
# Средняя оценка за качество: 4.066666666666666
# Средняя оценка по срокам: 3.85
# Максимальная оценка за вежливость: 4.5
# Время выполнения задачи: 4
# ---
# Команда: [('Юлия', 'рейнджер'), ('Бенедикт', 'рейнджер'), ('Соня', 'лекарь')]
# Средняя оценка за качество: 3.9
# Средняя оценка по срокам: 4.016666666666667
# Максимальная оценка за вежливость: 4.5
# Время выполнения задачи: 4
# ---
# Команда: [('Юлия', 'рейнджер'), ('Бенедикт', 'рейнджер'), ('Фредерик', 'лекарь')]
# Средняя оценка за качество: 4.066666666666666
# Средняя оценка по срокам: 3.85
# Максимальная оценка за вежливость: 4.5
# Время выполнения задачи: 4
# ---
# Команда: [('Юлия', 'рейнджер'), ('Леопольд', 'мечник'), ('Альфред', 'лекарь')]
# Средняя оценка за качество: 4.3999999999999995
# Средняя оценка по срокам: 3.6
# Максимальная оценка за вежливость: 5.0
# Время выполнения задачи: 5
# ---
# Команда: [('Юлия', 'рейнджер'), ('Леопольд', 'мечник'), ('Мартин', 'лекарь')]
# Средняя оценка за качество: 4.3999999999999995
# Средняя оценка по срокам: 3.6
# Максимальная оценка за вежливость: 5.0
# Время выполнения задачи: 5
# ---
# Команда: [('Юлия', 'рейнджер'), ('Леопольд', 'мечник'), ('Соня', 'лекарь')]
# Средняя оценка за качество: 4.233333333333333
# Средняя оценка по срокам: 3.766666666666667
# Максимальная оценка за вежливость: 5.0
# Время выполнения задачи: 4
# ---
# Команда: [('Юлия', 'рейнджер'), ('Леопольд', 'мечник'), ('Фредерик', 'лекарь')]
# Средняя оценка за качество: 4.3999999999999995
# Средняя оценка по срокам: 3.6
# Максимальная оценка за вежливость: 5.0
# Время выполнения задачи: 5
# ---
# Команда: [('Юлия', 'рейнджер'), ('Мартин', 'лучник'), ('Альфред', 'лекарь')]
# Средняя оценка за качество: 3.9555555555555557
# Средняя оценка по срокам: 3.8777777777777778
# Максимальная оценка за вежливость: 3.6666666666666665
# Время выполнения задачи: 4
# ---
# Команда: [('Юлия', 'рейнджер'), ('Мартин', 'лучник'), ('Мартин', 'лекарь')]
# Средняя оценка за качество: 3.9555555555555557
# Средняя оценка по срокам: 3.8777777777777778
# Максимальная оценка за вежливость: 4.0
# Время выполнения задачи: 4
# ---
# Команда: [('Юлия', 'рейнджер'), ('Мартин', 'лучник'), ('Соня', 'лекарь')]
# Средняя оценка за качество: 3.788888888888889
# Средняя оценка по срокам: 4.044444444444444
# Максимальная оценка за вежливость: 3.6666666666666665
# Время выполнения задачи: 4
# ---
# Команда: [('Юлия', 'рейнджер'), ('Мартин', 'лучник'), ('Фредерик', 'лекарь')]
# Средняя оценка за качество: 3.9555555555555557
# Средняя оценка по срокам: 3.8777777777777778
# Максимальная оценка за вежливость: 3.6666666666666665
# Время выполнения задачи: 4
# ---
# Команда: [('Юлия', 'рейнджер'), ('Мартин', 'рейнджер'), ('Альфред', 'лекарь')]
# Средняя оценка за качество: 3.9
# Средняя оценка по срокам: 4.016666666666667
# Максимальная оценка за вежливость: 3.6
# Время выполнения задачи: 4
# ---
# Команда: [('Юлия', 'рейнджер'), ('Мартин', 'рейнджер'), ('Мартин', 'лекарь')]
# Средняя оценка за качество: 3.9
# Средняя оценка по срокам: 4.016666666666667
# Максимальная оценка за вежливость: 4.0
# Время выполнения задачи: 4
# ---
# Команда: [('Юлия', 'рейнджер'), ('Мартин', 'рейнджер'), ('Соня', 'лекарь')]
# Средняя оценка за качество: 3.733333333333333
# Средняя оценка по срокам: 4.183333333333334
# Максимальная оценка за вежливость: 3.6
# Время выполнения задачи: 4
# ---
# Команда: [('Юлия', 'рейнджер'), ('Мартин', 'рейнджер'), ('Фредерик', 'лекарь')]
# Средняя оценка за качество: 3.9
# Средняя оценка по срокам: 4.016666666666667
# Максимальная оценка за вежливость: 3.6
# Время выполнения задачи: 4
# ---
# Команда: [('Юлия', 'рейнджер'), ('Пастушок', 'мечник'), ('Альфред', 'лекарь')]
# Средняя оценка за качество: 4.066666666666666
# Средняя оценка по срокам: 4.266666666666667
# Максимальная оценка за вежливость: 5.0
# Время выполнения задачи: 4
# ---
# Команда: [('Юлия', 'рейнджер'), ('Пастушок', 'мечник'), ('Мартин', 'лекарь')]
# Средняя оценка за качество: 4.066666666666666
# Средняя оценка по срокам: 4.266666666666667
# Максимальная оценка за вежливость: 5.0
# Время выполнения задачи: 4
# ---
# Команда: [('Юлия', 'рейнджер'), ('Пастушок', 'мечник'), ('Соня', 'лекарь')]
# Средняя оценка за качество: 3.9
# Средняя оценка по срокам: 4.433333333333334
# Максимальная оценка за вежливость: 5.0
# Время выполнения задачи: 4
# ---
# Команда: [('Юлия', 'рейнджер'), ('Пастушок', 'мечник'), ('Фредерик', 'лекарь')]
# Средняя оценка за качество: 4.066666666666666
# Средняя оценка по срокам: 4.266666666666667
# Максимальная оценка за вежливость: 5.0
# Время выполнения задачи: 4
# ---
# Команда: [('Юлия', 'рейнджер'), ('Пастушок', 'рейнджер'), ('Альфред', 'лекарь')]
# Средняя оценка за качество: 4.066666666666666
# Средняя оценка по срокам: 4.266666666666667
# Максимальная оценка за вежливость: 5.0
# Время выполнения задачи: 4
# ---
# Команда: [('Юлия', 'рейнджер'), ('Пастушок', 'рейнджер'), ('Мартин', 'лекарь')]
# Средняя оценка за качество: 4.066666666666666
# Средняя оценка по срокам: 4.266666666666667
# Максимальная оценка за вежливость: 5.0
# Время выполнения задачи: 4
# ---
# Команда: [('Юлия', 'рейнджер'), ('Пастушок', 'рейнджер'), ('Соня', 'лекарь')]
# Средняя оценка за качество: 3.9
# Средняя оценка по срокам: 4.433333333333334
# Максимальная оценка за вежливость: 5.0
# Время выполнения задачи: 4
# ---
# Команда: [('Юлия', 'рейнджер'), ('Пастушок', 'рейнджер'), ('Фредерик', 'лекарь')]
# Средняя оценка за качество: 4.066666666666666
# Средняя оценка по срокам: 4.266666666666667
# Максимальная оценка за вежливость: 5.0
# Время выполнения задачи: 4
# ---
# Команда: [('Юлия', 'рейнджер'), ('Синеглазый', 'мечник'), ('Альфред', 'лекарь')]
# Средняя оценка за качество: 4.066666666666666
# Средняя оценка по срокам: 3.9333333333333336
# Максимальная оценка за вежливость: 3.6
# Время выполнения задачи: 4
# ---
# Команда: [('Юлия', 'рейнджер'), ('Синеглазый', 'мечник'), ('Мартин', 'лекарь')]
# Средняя оценка за качество: 4.066666666666666
# Средняя оценка по срокам: 3.9333333333333336
# Максимальная оценка за вежливость: 4.0
# Время выполнения задачи: 4
# ---
# Команда: [('Юлия', 'рейнджер'), ('Синеглазый', 'мечник'), ('Соня', 'лекарь')]
# Средняя оценка за качество: 3.9
# Средняя оценка по срокам: 4.1000000000000005
# Максимальная оценка за вежливость: 3.6
# Время выполнения задачи: 4
# ---
# Команда: [('Юлия', 'рейнджер'), ('Синеглазый', 'мечник'), ('Фредерик', 'лекарь')]
# Средняя оценка за качество: 4.066666666666666
# Средняя оценка по срокам: 3.9333333333333336
# Максимальная оценка за вежливость: 3.6
# Время выполнения задачи: 4
# ---
# Команда: [('Юлия', 'рейнджер'), ('Синеглазый', 'рейнджер'), ('Альфред', 'лекарь')]
# Средняя оценка за качество: 4.066666666666666
# Средняя оценка по срокам: 3.9333333333333336
# Максимальная оценка за вежливость: 3.6
# Время выполнения задачи: 4
# ---
# Команда: [('Юлия', 'рейнджер'), ('Синеглазый', 'рейнджер'), ('Мартин', 'лекарь')]
# Средняя оценка за качество: 4.066666666666666
# Средняя оценка по срокам: 3.9333333333333336
# Максимальная оценка за вежливость: 4.0
# Время выполнения задачи: 4
# ---
# Команда: [('Юлия', 'рейнджер'), ('Синеглазый', 'рейнджер'), ('Соня', 'лекарь')]
# Средняя оценка за качество: 3.9
# Средняя оценка по срокам: 4.1000000000000005
# Максимальная оценка за вежливость: 3.6
# Время выполнения задачи: 4
# ---
# Команда: [('Юлия', 'рейнджер'), ('Синеглазый', 'рейнджер'), ('Фредерик', 'лекарь')]
# Средняя оценка за качество: 4.066666666666666
# Средняя оценка по срокам: 3.9333333333333336
# Максимальная оценка за вежливость: 3.6
# Время выполнения задачи: 4
# ---
# Команда: [('Юлия', 'рейнджер'), ('Соня', 'боевой маг'), ('Альфред', 'лекарь')]
# Средняя оценка за качество: 4.0
# Средняя оценка по срокам: 3.9333333333333336
# Максимальная оценка за вежливость: 3.6
# Время выполнения задачи: 4
# ---
# Команда: [('Юлия', 'рейнджер'), ('Соня', 'боевой маг'), ('Мартин', 'лекарь')]
# Средняя оценка за качество: 4.0
# Средняя оценка по срокам: 3.9333333333333336
# Максимальная оценка за вежливость: 4.0
# Время выполнения задачи: 4
# ---
# Команда: [('Юлия', 'рейнджер'), ('Соня', 'боевой маг'), ('Соня', 'лекарь')]
# Средняя оценка за качество: 3.8333333333333335
# Средняя оценка по срокам: 4.1000000000000005
# Максимальная оценка за вежливость: 3.6
# Время выполнения задачи: 4
# ---
# Команда: [('Юлия', 'рейнджер'), ('Соня', 'боевой маг'), ('Фредерик', 'лекарь')]
# Средняя оценка за качество: 4.0
# Средняя оценка по срокам: 3.9333333333333336
# Максимальная оценка за вежливость: 3.6
# Время выполнения задачи: 4
# ---
# Команда: [('Юлия', 'рейнджер'), ('Соня', 'рейнджер'), ('Альфред', 'лекарь')]
# Средняя оценка за качество: 4.1499999999999995
# Средняя оценка по срокам: 3.85
# Максимальная оценка за вежливость: 3.75
# Время выполнения задачи: 4
# ---
# Команда: [('Юлия', 'рейнджер'), ('Соня', 'рейнджер'), ('Мартин', 'лекарь')]
# Средняя оценка за качество: 4.1499999999999995
# Средняя оценка по срокам: 3.85
# Максимальная оценка за вежливость: 4.0
# Время выполнения задачи: 4
# ---
# Команда: [('Юлия', 'рейнджер'), ('Соня', 'рейнджер'), ('Соня', 'лекарь')]
# Средняя оценка за качество: 3.983333333333333
# Средняя оценка по срокам: 4.016666666666667
# Максимальная оценка за вежливость: 3.75
# Время выполнения задачи: 4
# ---
# Команда: [('Юлия', 'рейнджер'), ('Соня', 'рейнджер'), ('Фредерик', 'лекарь')]
# Средняя оценка за качество: 4.1499999999999995
# Средняя оценка по срокам: 3.85
# Максимальная оценка за вежливость: 3.75
# Время выполнения задачи: 4
# ---
# Команда: [('Юлия', 'рейнджер'), ('Фредерик', 'лучник'), ('Альфред', 'лекарь')]
# Средняя оценка за качество: 4.066666666666666
# Средняя оценка по срокам: 3.9333333333333336
# Максимальная оценка за вежливость: 4.333333333333333
# Время выполнения задачи: 4
# ---
# Команда: [('Юлия', 'рейнджер'), ('Фредерик', 'лучник'), ('Мартин', 'лекарь')]
# Средняя оценка за качество: 4.066666666666666
# Средняя оценка по срокам: 3.9333333333333336
# Максимальная оценка за вежливость: 4.333333333333333
# Время выполнения задачи: 4
# ---
# Команда: [('Юлия', 'рейнджер'), ('Фредерик', 'лучник'), ('Соня', 'лекарь')]
# Средняя оценка за качество: 3.9
# Средняя оценка по срокам: 4.1000000000000005
# Максимальная оценка за вежливость: 4.333333333333333
# Время выполнения задачи: 4
# ---
# Команда: [('Юлия', 'рейнджер'), ('Фредерик', 'лучник'), ('Фредерик', 'лекарь')]
# Средняя оценка за качество: 4.066666666666666
# Средняя оценка по срокам: 3.9333333333333336
# Максимальная оценка за вежливость: 4.333333333333333
# Время выполнения задачи: 4
# ---
# Команда: [('Юлия', 'рейнджер'), ('Фредерик', 'рейнджер'), ('Альфред', 'лекарь')]
# Средняя оценка за качество: 4.066666666666666
# Средняя оценка по срокам: 3.9333333333333336
# Максимальная оценка за вежливость: 5.0
# Время выполнения задачи: 4
# ---
# Команда: [('Юлия', 'рейнджер'), ('Фредерик', 'рейнджер'), ('Мартин', 'лекарь')]
# Средняя оценка за качество: 4.066666666666666
# Средняя оценка по срокам: 3.9333333333333336
# Максимальная оценка за вежливость: 5.0
# Время выполнения задачи: 4
# ---
# Команда: [('Юлия', 'рейнджер'), ('Фредерик', 'рейнджер'), ('Соня', 'лекарь')]
# Средняя оценка за качество: 3.9
# Средняя оценка по срокам: 4.1000000000000005
# Максимальная оценка за вежливость: 5.0
# Время выполнения задачи: 4
# ---
# Команда: [('Юлия', 'рейнджер'), ('Фредерик', 'рейнджер'), ('Фредерик', 'лекарь')]
# Средняя оценка за качество: 4.066666666666666
# Средняя оценка по срокам: 3.9333333333333336
# Максимальная оценка за вежливость: 5.0
# Время выполнения задачи: 4
# ---
# Команда: [('Юлия', 'рейнджер'), ('Юлия', 'мечник'), ('Альфред', 'лекарь')]
# Средняя оценка за качество: 4.114285714285715
# Средняя оценка по срокам: 3.695238095238095
# Максимальная оценка за вежливость: 3.7142857142857144
# Время выполнения задачи: 5
# ---
# Команда: [('Юлия', 'рейнджер'), ('Юлия', 'мечник'), ('Мартин', 'лекарь')]
# Средняя оценка за качество: 4.114285714285715
# Средняя оценка по срокам: 3.695238095238095
# Максимальная оценка за вежливость: 4.0
# Время выполнения задачи: 5
# ---
# Команда: [('Юлия', 'рейнджер'), ('Юлия', 'мечник'), ('Соня', 'лекарь')]
# Средняя оценка за качество: 3.947619047619048
# Средняя оценка по срокам: 3.861904761904762
# Максимальная оценка за вежливость: 3.7142857142857144
# Время выполнения задачи: 4
# ---
# Команда: [('Юлия', 'рейнджер'), ('Юлия', 'мечник'), ('Фредерик', 'лекарь')]
# Средняя оценка за качество: 4.114285714285715
# Средняя оценка по срокам: 3.695238095238095
# Максимальная оценка за вежливость: 3.7142857142857144
# Время выполнения задачи: 5
# ---

# %% [markdown]
# ### Метод для формирования словаря задач
#
# Был создан метод, который на выходе возвращает словарь следующего формата:
#
# ```python
# {
#     task: {
#         "priority": priorities,
#         "start_quant": start_quant,
#         "amount": amount,
#         "nearest": nearest
#     }
# }
#
# ```
# ----
#
# ### Описание структуры словаря:
#
# * **priority**: Список допустимых команд, отсортированных по убыванию их приоритетов для выполнения задачи.
# * **start_quant**: Квант времени, соответствующий дате поступления задачи.
# * **amount**: Стоимость выполнения задачи.
# * **nearest**: Ближайшая задача, которая связана с текущей задачей.
#
# ---
#
# ### Зачем это нужно?
# Данный метод упрощает управление задачами и позволяет:
#
# * Оптимально распределять задачи между командами с учётом их приоритета.
# * Учитывать временные факторы и взаимосвязи задач.
# * Подготовить данные для дальнейшей интеграции в рекомендательную систему.
#
# Далее будет описано, как эти данные используются для формирования оптимальных рекомендаций и управления задачами

# %%
def priority_wrapper(task, sorted_teams, start_quant, amount, nearest):
    priorities = {}
    for id, team in enumerate(sorted_teams):
        priorities[id] = team
   
    return {task : {
        "priority" : priorities,
        "start_quant" : start_quant,
        "amount": amount,
        "nearest": nearest
        }
    }

# %% [markdown]
# ### Анализ исторических данных и создание векторного представления кластеров
#
# Для работы с историческими данными из обучающей выборки был разработан вспомогательный метод ``vectorize_by_clusters``, который:
#
# 1. Позволяет получить информацию по каждому кластеру, включая:
#    - Список поручений, относящихся к кластеру.
#    - Их векторное представление для дальнейшего анализа.
#
# ---
#
# #### Использование модели трансформера
#
# Для преобразования текстового описания поручений в векторное представление была использована модель **"ruselkomp/deep-pavlov-full"**. Эта модель, обученная на русском языке, выполняет задачи обработки естественного языка и обеспечивает качественное векторизирование текстов.
#
# ---
#
# #### Особенности векторизации
#
# 1. **Исключение из описания:**
#    Перед векторизацией из описания поручений удаляются:
#    - **Совет:** Дополнительные рекомендации, которые не влияют на суть задачи.
#    - **Цель:** Общая информация о задаче, которая уже классифицирована в кластерах.
#
# 2. **Результат:**
#    Каждое поручение преобразуется в числовой вектор, представляющий его основные семантические особенности.
#
# ---
#
# #### Пример работы метода
#
# - **Входное описание поручения:**
#   "В деревне был похищен рюкзак. Необходимо вернуть его хозяину. Советуем искать в лесу."
#
# - **Преобразованное описание:**
#   "В деревне был похищен рюкзак."
#
# - **Векторное представление:**
#   Вектор из чисел, который передаётся в алгоритмы для анализа и кластеризации.
#
# ---
#
# #### Зачем это нужно?
#
# Создание векторного представления задач:
# 1. **Упрощает анализ:** Позволяет сравнивать задачи внутри одного кластера.
# 2. **Поддерживает обучение модели:** Использование векторов упрощает внедрение алгоритмов машинного обучения.
# 3. **Повышает точность классификации:** Векторизация фокусируется на ключевых аспектах описания задачи.
#
# Данный метод создаёт основу для дальнейшего анализа и оптимизации распределения задач.

# %%
model_name = "ruselkomp/deep-pavlov-full"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModel.from_pretrained(model_name)

def encode_text(text):
    inputs = tokenizer(text, return_tensors="pt", truncation=True, padding=True)
    with torch.no_grad():
        outputs = model(**inputs)
    # [CLS] токен как представление предложения
    cls_embedding = outputs.last_hidden_state[:, 0, :]
    return cls_embedding.squeeze().numpy()
# Out:
# Some weights of BertModel were not initialized from the model checkpoint at ruselkomp/deep-pavlov-full and are newly initialized: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
def vectorize_by_clusters(dt_train_cases):
    clusters = {}
    for cluster in df_train_cases["cluster"].unique():
        df_slice = df_train_cases[df_train_cases["cluster"] == cluster].copy()
        vecs_slice = encode_text(df_slice["description"].values.tolist())
        
        clusters[cluster] = {
            "df_slice":
                df_train_cases[df_train_cases["cluster"] == cluster],
            "vecs": vecs_slice
            }
    return clusters

# %%
clusters = vectorize_by_clusters(df_train_cases)
# Out:
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.

# %%
clusters
# Out:
# {'убить-победить-уничтожить зверь': {'df_slice':      Номер поручения      Заказчик Дата поручения Дата выполнения  \
#   0              11000          Анна     1051-08-11      1051-08-21
#   5              11005          Анна     1051-09-07      1051-09-24
#   10             11010          Анна     1051-02-12      1051-02-18
#   14             11014       Татьяна     1052-05-16      1052-05-30
#   24             11024        Эмилио     1051-06-04      1051-07-21
#   50             11050         Чарли     1052-09-01      1052-09-16
#   80             11081       Татьяна     1052-05-29      1052-06-27
#   128            11129          Олег     1051-04-23      1051-05-03
#   135            11137  Бабушка Синь     1051-02-21      1051-03-03
#   156            11159          Егор     1051-12-24      1051-12-31
#   201            11205       Татьяна     1053-07-22      1053-08-13
#   205            11209       Леонтия     1052-04-20      1052-05-23
#   215            11220          Влад     1052-11-25      1052-12-25
#   222            11227       Леонтия     1051-08-18      1051-10-02
#   230            11237        Эмилио     1051-05-23      1051-07-14
#   232            11239       Татьяна     1052-11-14      1052-11-20
#   244            11251          Иван     1051-07-16      1051-09-12
#   246            11253         Чарли     1051-11-13      1052-01-02
#   255            11262       Аделина     1052-03-23      1052-04-06
#   285            11293       Татьяна     1052-09-17      1052-10-09
#   302            11313          Влад     1052-05-10      1052-06-16
#   307            11318         Чарли     1051-01-03      1051-02-12
#   308            11319         Мария     1052-04-17      1052-06-09
#   322            11333       Аделина     1052-02-04      1052-03-28
#   331            11342  Бабушка Синь     1051-01-20      1051-02-18
#   370            11382  Бабушка Синь     1052-02-26      1052-04-02
#   391            11406       Аделина     1051-04-21      1051-06-14
#   476            11495         Чарли     1053-04-06      1053-05-11
#
#        Затрачено дней  Сумма вознаграждения  \
#   0                 4                  6000
#   5                 4                  9000
#   10                4                 22500
#   14                3                 17500
#   24                3                 18500
#   50                7                  8500
#   80                9                 19500
#   128               8                  6500
#   135               9                 16000
#   156               3                  7000
#   201              10                 25000
#   205               2                 21000
#   215               1                 28000
#   222               1                 14500
#   230               2                 23000
#   232               1                  9500
#   244               3                 23500
#   246               1                  9000
#   255              10                 10000
#   285               5                 15000
#   302              10                 12000
#   307               4                 25500
#   308               4                 22000
#   322               8                 17500
#   331               6                  7500
#   370               4                 21500
#   391               3                 21500
#   476               4                 23000
#
#                                              description  \
#   0    В лесу по дороге от пещеры звери нападают на л...
#   5            В лесу недалеко от города заметили зверей
#   10                Недалеко от города встречаются звери
#   14          В лесу по дороге от пещеры заметили зверей
#   24           В лесу недалеко от города заметили зверей
#   50          В лесу по дороге от пещеры заметили зверей
#   80          Недалеко от города звери нападают на людей
#   128    В лесу между городом и деревней заметили зверей
#   135        В лесу недалеко от города встречаются звери
#   156  В лесу между городом и деревней встречаются звери
#   201             В лесу около деревни встречаются звери
#   205                 Недалеко от города заметили зверей
#   215        В лесу недалеко от города встречаются звери
#   222               В лесу около деревни заметили зверей
#   230  В лесу недалеко от города звери нападают на людей
#   232  В лесу по дороге от пещеры звери нападают на л...
#   244             По дороге из деревни встречаются звери
#   246                 Недалеко от города заметили зверей
#   255               Недалеко от города встречаются звери
#   285         Недалеко от города звери нападают на людей
#   302         В лесу по дороге от пещеры заметили зверей
#   307  В лесу недалеко от города звери нападают на людей
#   308               Недалеко от города встречаются звери
#   322       По дороге из деревни звери нападают на людей
#   331       По дороге из деревни звери нападают на людей
#   370             В лесу около деревни встречаются звери
#   391                 Недалеко от города заметили зверей
#   476             В лесу около деревни встречаются звери
#
#                                cluster              time_in  \
#   0    убить-победить-уничтожить зверь  1051-08-11 00:00:00
#   5    убить-победить-уничтожить зверь  1051-09-07 00:00:00
#   10   убить-победить-уничтожить зверь  1051-02-12 00:00:00
#   14   убить-победить-уничтожить зверь  1052-05-16 00:00:00
#   24   убить-победить-уничтожить зверь  1051-06-04 00:00:00
#   50   убить-победить-уничтожить зверь  1052-09-01 00:00:00
#   80   убить-победить-уничтожить зверь  1052-05-29 00:00:00
#   128  убить-победить-уничтожить зверь  1051-04-23 00:00:00
#   135  убить-победить-уничтожить зверь  1051-02-21 00:00:00
#   156  убить-победить-уничтожить зверь  1051-12-24 00:00:00
#   201  убить-победить-уничтожить зверь  1053-07-22 00:00:00
#   205  убить-победить-уничтожить зверь  1052-04-20 00:00:00
#   215  убить-победить-уничтожить зверь  1052-11-25 00:00:00
#   222  убить-победить-уничтожить зверь  1051-08-18 00:00:00
#   230  убить-победить-уничтожить зверь  1051-05-23 00:00:00
#   232  убить-победить-уничтожить зверь  1052-11-14 00:00:00
#   244  убить-победить-уничтожить зверь  1051-07-16 00:00:00
#   246  убить-победить-уничтожить зверь  1051-11-13 00:00:00
#   255  убить-победить-уничтожить зверь  1052-03-23 00:00:00
#   285  убить-победить-уничтожить зверь  1052-09-17 00:00:00
#   302  убить-победить-уничтожить зверь  1052-05-10 00:00:00
#   307  убить-победить-уничтожить зверь  1051-01-03 00:00:00
#   308  убить-победить-уничтожить зверь  1052-04-17 00:00:00
#   322  убить-победить-уничтожить зверь  1052-02-04 00:00:00
#   331  убить-победить-уничтожить зверь  1051-01-20 00:00:00
#   370  убить-победить-уничтожить зверь  1052-02-26 00:00:00
#   391  убить-победить-уничтожить зверь  1051-04-21 00:00:00
#   476  убить-победить-уничтожить зверь  1053-04-06 00:00:00
#
#                time_finish  Дата поручения_t  Дата выполнения_t       Герой  \
#   0    1051-08-21 00:00:00               221                231      Мартин
#   5    1051-09-24 00:00:00               248                265       Агата
#   10   1051-02-18 00:00:00                41                 47     Альфред
#   14   1052-05-30 00:00:00               500                514    Пастушок
#   24   1051-07-21 00:00:00               153                200    Фредерик
#   50   1052-09-16 00:00:00               608                623    Пастушок
#   80   1052-06-27 00:00:00               513                542    Леопольд
#   128  1051-05-03 00:00:00               111                121        Юлия
#   135  1051-03-03 00:00:00                50                 60    Пастушок
#   156  1051-12-31 00:00:00               356                363  Синеглазый
#   201  1053-08-13 00:00:00               932                954  Синеглазый
#   205  1052-05-23 00:00:00               474                507    Фредерик
#   215  1052-12-25 00:00:00               693                723     Альфред
#   222  1051-10-02 00:00:00               228                273      Бендер
#   230  1051-07-14 00:00:00               141                193     Альфред
#   232  1052-11-20 00:00:00               682                688        Юлия
#   244  1051-09-12 00:00:00               195                253    Бенедикт
#   246  1052-01-02 00:00:00               315                365        Юлия
#   255  1052-04-06 00:00:00               446                460       Агата
#   285  1052-10-09 00:00:00               624                646    Фредерик
#   302  1052-06-16 00:00:00               494                531      Мартин
#   307  1051-02-12 00:00:00                 1                 41      Мартин
#   308  1052-06-09 00:00:00               471                524  Синеглазый
#   322  1052-03-28 00:00:00               398                451    Бенедикт
#   331  1051-02-18 00:00:00                18                 47    Пастушок
#   370  1052-04-02 00:00:00               420                456        Юлия
#   391  1051-06-14 00:00:00               109                163     Глюкоза
#   476  1053-05-11 00:00:00               825                860  Синеглазый
#
#                                       Запись в дневнике  Идеальное время  \
#   0    [разжечь костёр, выследить цель, разжечь костёр]                3
#   5                    [разжечь костёр, разжечь костёр]                2
#   10                    [залечить раны, разжечь костёр]                4
#   14                   [разжечь костёр, разжечь костёр]                3
#   24   [разжечь костёр, выследить цель, разжечь костёр]                2
#   50   [разжечь костёр, выследить цель, разжечь костёр]                7
#   80                                   [разжечь костёр]                9
#   128   [разжечь костёр, залечить раны, разжечь костёр]                7
#   135                  [разжечь костёр, разжечь костёр]                6
#   156   [разжечь костёр, залечить раны, разжечь костёр]                3
#   201   [разжечь костёр, залечить раны, разжечь костёр]                8
#   205                   [залечить раны, разжечь костёр]                2
#   215   [разжечь костёр, залечить раны, разжечь костёр]                1
#   222                  [разжечь костёр, разжечь костёр]                1
#   230   [разжечь костёр, залечить раны, разжечь костёр]                2
#   232  [разжечь костёр, выследить цель, разжечь костёр]                1
#   244                   [залечить раны, разжечь костёр]                3
#   246                   [залечить раны, разжечь костёр]                1
#   255                                  [разжечь костёр]                8
#   285                   [залечить раны, разжечь костёр]                3
#   302   [разжечь костёр, залечить раны, разжечь костёр]                8
#   307   [разжечь костёр, залечить раны, разжечь костёр]                3
#   308                   [залечить раны, разжечь костёр]                4
#   322                   [залечить раны, разжечь костёр]                5
#   331                                  [разжечь костёр]                5
#   370   [разжечь костёр, залечить раны, разжечь костёр]                3
#   391                                  [разжечь костёр]                2
#   476   [разжечь костёр, залечить раны, разжечь костёр]                4
#
#                                             диапазон дат
#   0    [231, 230, 229, 228, 227, 226, 225, 224, 223, ...
#   5    [265, 264, 263, 262, 261, 260, 259, 258, 257, ...
#   10   [47, 46, 45, 44, 43, 42, 41, 40, 39, 38, 37, 3...
#   14   [514, 513, 512, 511, 510, 509, 508, 507, 506, ...
#   24   [200, 199, 198, 197, 196, 195, 194, 193, 192, ...
#   50   [623, 622, 621, 620, 619, 618, 617, 616, 615, ...
#   80   [542, 541, 540, 539, 538, 537, 536, 535, 534, ...
#   128  [121, 120, 119, 118, 117, 116, 115, 114, 113, ...
#   135  [60, 59, 58, 57, 56, 55, 54, 53, 52, 51, 50, 4...
#   156  [363, 362, 361, 360, 359, 358, 357, 356, 355, ...
#   201  [954, 953, 952, 951, 950, 949, 948, 947, 946, ...
#   205  [507, 506, 505, 504, 503, 502, 501, 500, 499, ...
#   215  [723, 722, 721, 720, 719, 718, 717, 716, 715, ...
#   222  [273, 272, 271, 270, 269, 268, 267, 266, 265, ...
#   230  [193, 192, 191, 190, 189, 188, 187, 186, 185, ...
#   232  [688, 687, 686, 685, 684, 683, 682, 681, 680, ...
#   244  [253, 252, 251, 250, 249, 248, 247, 246, 245, ...
#   246  [365, 364, 363, 362, 361, 360, 359, 358, 357, ...
#   255  [460, 459, 458, 457, 456, 455, 454, 453, 452, ...
#   285  [646, 645, 644, 643, 642, 641, 640, 639, 638, ...
#   302  [531, 530, 529, 528, 527, 526, 525, 524, 523, ...
#   307  [41, 40, 39, 38, 37, 36, 35, 34, 33, 32, 31, 3...
#   308  [524, 523, 522, 521, 520, 519, 518, 517, 516, ...
#   322  [451, 450, 449, 448, 447, 446, 445, 444, 443, ...
#   331  [47, 46, 45, 44, 43, 42, 41, 40, 39, 38, 37, 3...
#   370  [456, 455, 454, 453, 452, 451, 450, 449, 448, ...
#   391  [163, 162, 161, 160, 159, 158, 157, 156, 155, ...
#   476  [860, 859, 858, 857, 856, 855, 854, 853, 852, ...  ,
#   'vecs': array([[ 0.06143066,  0.20417333, -0.23092124, ..., -0.2699343 ,
#            0.06920066, -0.12166214],
#          [ 0.04598252,  0.20597628, -0.26208526, ..., -0.23231108,
#            0.10037882, -0.05991553],
#          [ 0.05546055,  0.15395233, -0.1707091 , ...,  0.05638163,
#            0.09402565, -0.1284976 ],
#          ...,
#          [ 0.09096168,  0.16628936, -0.17168945, ..., -0.04671387,
#            0.02096385, -0.10470866],
#          [ 0.02881328,  0.19831678, -0.28633666, ..., -0.05570202,
#            0.09398045, -0.14675888],
#          [ 0.09096168,  0.16628936, -0.17168945, ..., -0.04671387,
#            0.02096385, -0.10470866]], dtype=float32)},
#  'убить-победить-уничтожить разбойник': {'df_slice':      Номер поручения      Заказчик Дата поручения Дата выполнения  \
#   1              11001         Мария     1051-07-09      1051-09-02
#   110            11111         Чарли     1053-03-12      1053-04-20
#   126            11127  Бабушка Синь     1053-07-16      1053-07-27
#   138            11140       Аделина     1053-06-09      1053-06-14
#   171            11175          Влад     1053-08-19      1053-09-30
#   172            11176       Леонтия     1052-02-18      1052-04-08
#   184            11188       Аделина     1053-09-19      1053-11-06
#   190            11194       Татьяна     1052-09-07      1052-10-29
#   195            11199          Олег     1051-02-28      1051-03-17
#   206            11210        Эмилио     1052-12-14      1052-12-20
#   224            11229         Роман     1052-03-16      1052-03-31
#   233            11240        Эмилио     1053-05-06      1053-06-23
#   251            11258          Анна     1053-06-04      1053-08-02
#   256            11263        Бьянка     1051-06-11      1051-08-10
#   323            11334        Эмилио     1051-06-14      1051-08-03
#   409            11425         Мария     1051-04-27      1051-05-29
#   440            11458   Максимилиан     1052-12-30      1053-01-02
#   441            11459  Бабушка Синь     1051-04-29      1051-06-27
#   446            11465          Надя     1052-05-22      1052-06-10
#
#        Затрачено дней  Сумма вознаграждения  \
#   1                 2                 20000
#   110               8                 20000
#   126               4                 12000
#   138               4                 25500
#   171               9                  9500
#   172               3                 18000
#   184               9                 13000
#   190               8                  8500
#   195               6                  7000
#   206               3                  5500
#   224               4                 11500
#   233               7                 15000
#   251               9                 18500
#   256               1                  5000
#   323               7                 14000
#   409               1                  7500
#   440               2                 28500
#   441               5                  6500
#   446              10                 28000
#
#                                              description  \
#   1    В лесу по дороге от пещеры были замечены разбо...
#   110  В лесу между городом и деревней были замечены ...
#   126     В лесу недалеко от города заметили разбойников
#   138  В лесу по дороге от пещеры были замечены разбо...
#   171          По дороге из деревни заметили разбойников
#   172    Недалеко от города разбойники нападают на людей
#   184     В лесу недалеко от города заметили разбойников
#   190    В лесу по дороге от пещеры заметили разбойников
#   195          В лесу около деревни заметили разбойников
#   206     В лесу недалеко от города заметили разбойников
#   224    Недалеко от города разбойники нападают на людей
#   233  В лесу между городом и деревней разбойники нап...
#   251  В лесу между городом и деревней заметили разбо...
#   256  В лесу недалеко от города были замечены разбой...
#   323        Недалеко от города были замечены разбойники
#   409      По дороге из деревни были замечены разбойники
#   440  В лесу между городом и деревней заметили разбо...
#   441     В лесу недалеко от города заметили разбойников
#   446    Недалеко от города разбойники нападают на людей
#
#                                    cluster              time_in  \
#   1    убить-победить-уничтожить разбойник  1051-07-09 00:00:00
#   110  убить-победить-уничтожить разбойник  1053-03-12 00:00:00
#   126  убить-победить-уничтожить разбойник  1053-07-16 00:00:00
#   138  убить-победить-уничтожить разбойник  1053-06-09 00:00:00
#   171  убить-победить-уничтожить разбойник  1053-08-19 00:00:00
#   172  убить-победить-уничтожить разбойник  1052-02-18 00:00:00
#   184  убить-победить-уничтожить разбойник  1053-09-19 00:00:00
#   190  убить-победить-уничтожить разбойник  1052-09-07 00:00:00
#   195  убить-победить-уничтожить разбойник  1051-02-28 00:00:00
#   206  убить-победить-уничтожить разбойник  1052-12-14 00:00:00
#   224  убить-победить-уничтожить разбойник  1052-03-16 00:00:00
#   233  убить-победить-уничтожить разбойник  1053-05-06 00:00:00
#   251  убить-победить-уничтожить разбойник  1053-06-04 00:00:00
#   256  убить-победить-уничтожить разбойник  1051-06-11 00:00:00
#   323  убить-победить-уничтожить разбойник  1051-06-14 00:00:00
#   409  убить-победить-уничтожить разбойник  1051-04-27 00:00:00
#   440  убить-победить-уничтожить разбойник  1052-12-30 00:00:00
#   441  убить-победить-уничтожить разбойник  1051-04-29 00:00:00
#   446  убить-победить-уничтожить разбойник  1052-05-22 00:00:00
#
#                time_finish  Дата поручения_t  Дата выполнения_t       Герой  \
#   1    1051-09-02 00:00:00               188                243     Альфред
#   110  1053-04-20 00:00:00               800                839     Альфред
#   126  1053-07-27 00:00:00               926                937    Фредерик
#   138  1053-06-14 00:00:00               889                894        Соня
#   171  1053-09-30 00:00:00               960               1002    Леопольд
#   172  1052-04-08 00:00:00               412                462  Синеглазый
#   184  1053-11-06 00:00:00               991               1039    Леопольд
#   190  1052-10-29 00:00:00               614                666    Бенедикт
#   195  1051-03-17 00:00:00                57                 74    Бенедикт
#   206  1052-12-20 00:00:00               712                718       Агата
#   224  1052-03-31 00:00:00               439                454      Бендер
#   233  1053-06-23 00:00:00               855                903       Агата
#   251  1053-08-02 00:00:00               884                943        Юлия
#   256  1051-08-10 00:00:00               160                220    Леопольд
#   323  1051-08-03 00:00:00               163                213        Юлия
#   409  1051-05-29 00:00:00               115                147    Пастушок
#   440  1053-01-02 00:00:00               728                731     Глюкоза
#   441  1051-06-27 00:00:00               117                176        Юлия
#   446  1052-06-10 00:00:00               506                525    Пастушок
#
#                                       Запись в дневнике  Идеальное время  \
#   1     [разжечь костёр, залечить раны, разжечь костёр]                2
#   110   [разжечь костёр, залечить раны, разжечь костёр]                4
#   126   [разжечь костёр, залечить раны, разжечь костёр]                4
#   138   [разжечь костёр, залечить раны, разжечь костёр]                3
#   171                                  [разжечь костёр]                9
#   172                   [залечить раны, разжечь костёр]                2
#   184  [разжечь костёр, выследить цель, разжечь костёр]                4
#   190   [разжечь костёр, залечить раны, разжечь костёр]                7
#   195   [разжечь костёр, залечить раны, разжечь костёр]                5
#   206                  [разжечь костёр, разжечь костёр]                2
#   224                                  [разжечь костёр]                4
#   233  [разжечь костёр, выследить цель, разжечь костёр]                5
#   251   [разжечь костёр, залечить раны, разжечь костёр]                6
#   256                  [разжечь костёр, разжечь костёр]                1
#   323                   [залечить раны, разжечь костёр]                5
#   409                                  [разжечь костёр]                1
#   440                  [разжечь костёр, разжечь костёр]                2
#   441   [разжечь костёр, залечить раны, разжечь костёр]                4
#   446                                  [разжечь костёр]               10
#
#                                             диапазон дат
#   1    [243, 242, 241, 240, 239, 238, 237, 236, 235, ...
#   110  [839, 838, 837, 836, 835, 834, 833, 832, 831, ...
#   126  [937, 936, 935, 934, 933, 932, 931, 930, 929, ...
#   138  [894, 893, 892, 891, 890, 889, 888, 887, 886, ...
#   171  [1002, 1001, 1000, 999, 998, 997, 996, 995, 99...
#   172  [462, 461, 460, 459, 458, 457, 456, 455, 454, ...
#   184  [1039, 1038, 1037, 1036, 1035, 1034, 1033, 103...
#   190  [666, 665, 664, 663, 662, 661, 660, 659, 658, ...
#   195  [74, 73, 72, 71, 70, 69, 68, 67, 66, 65, 64, 6...
#   206  [718, 717, 716, 715, 714, 713, 712, 711, 710, ...
#   224  [454, 453, 452, 451, 450, 449, 448, 447, 446, ...
#   233  [903, 902, 901, 900, 899, 898, 897, 896, 895, ...
#   251  [943, 942, 941, 940, 939, 938, 937, 936, 935, ...
#   256  [220, 219, 218, 217, 216, 215, 214, 213, 212, ...
#   323  [213, 212, 211, 210, 209, 208, 207, 206, 205, ...
#   409  [147, 146, 145, 144, 143, 142, 141, 140, 139, ...
#   440  [731, 730, 729, 728, 727, 726, 725, 724, 723, ...
#   441  [176, 175, 174, 173, 172, 171, 170, 169, 168, ...
#   446  [525, 524, 523, 522, 521, 520, 519, 518, 517, ...  ,
#   'vecs': array([[ 0.06103481,  0.08082059, -0.21687123, ..., -0.14621627,
#            0.08922688, -0.14992021],
#          [ 0.11331269,  0.10812198, -0.30844676, ..., -0.13175422,
#            0.13922852, -0.17733341],
#          [ 0.1301053 ,  0.13689065, -0.28208643, ..., -0.17047605,
#            0.11657556, -0.09577636],
#          ...,
#          [ 0.1289074 ,  0.13211381, -0.30123806, ..., -0.1660386 ,
#            0.121579  , -0.15356156],
#          [ 0.1301053 ,  0.13689065, -0.28208643, ..., -0.17047605,
#            0.11657556, -0.09577636],
#          [ 0.1400531 ,  0.15393755, -0.38226396, ..., -0.04538599,
#            0.13628834, -0.279888  ]], dtype=float32)},
#  'спасти-освободить монстр': {'df_slice':      Номер поручения Заказчик Дата поручения Дата выполнения  Затрачено дней  \
#   2              11002   Эмилио     1053-10-05      1053-10-20               7
#   18             11018     Надя     1053-03-14      1053-05-13               9
#   20             11020   Бьянка     1051-06-24      1051-07-14               6
#   33             11033     Надя     1052-04-12      1052-06-08               4
#   38             11038     Влад     1052-07-03      1052-08-03               3
#   ..               ...      ...            ...             ...             ...
#   435            11453     Егор     1051-04-28      1051-06-18               7
#   442            11460     Анна     1052-09-05      1052-09-11               3
#   453            11472   Бьянка     1051-03-23      1051-04-21              10
#   455            11474   Эмилио     1053-03-21      1053-04-16               2
#   470            11489     Анна     1053-07-03      1053-08-18               7
#
#        Сумма вознаграждения                                     description  \
#   2                   22500  По дороге из деревни монстры похитили путников
#   18                  19500  По дороге из деревни монстры похитили путников
#   20                  15500    Недалеко от города монстры похитили путников
#   33                  21500              В городе монстры похитили путников
#   38                  19000    Недалеко от города монстры похитили путников
#   ..                    ...                                             ...
#   435                 27000              В городе монстры похитили путников
#   442                 27000              В городе монстры похитили путников
#   453                  9000             В деревне монстры похитили путников
#   455                  6000    Недалеко от города монстры похитили путников
#   470                 15000  По дороге из деревни монстры похитили путников
#
#                         cluster              time_in          time_finish  \
#   2    спасти-освободить монстр  1053-10-05 00:00:00  1053-10-20 00:00:00
#   18   спасти-освободить монстр  1053-03-14 00:00:00  1053-05-13 00:00:00
#   20   спасти-освободить монстр  1051-06-24 00:00:00  1051-07-14 00:00:00
#   33   спасти-освободить монстр  1052-04-12 00:00:00  1052-06-08 00:00:00
#   38   спасти-освободить монстр  1052-07-03 00:00:00  1052-08-03 00:00:00
#   ..                        ...                  ...                  ...
#   435  спасти-освободить монстр  1051-04-28 00:00:00  1051-06-18 00:00:00
#   442  спасти-освободить монстр  1052-09-05 00:00:00  1052-09-11 00:00:00
#   453  спасти-освободить монстр  1051-03-23 00:00:00  1051-04-21 00:00:00
#   455  спасти-освободить монстр  1053-03-21 00:00:00  1053-04-16 00:00:00
#   470  спасти-освободить монстр  1053-07-03 00:00:00  1053-08-18 00:00:00
#
#        Дата поручения_t  Дата выполнения_t       Герой Запись в дневнике  \
#   2                1007               1022      Мартин  [выследить цель]
#   18                802                862    Фредерик  [выследить цель]
#   20                173                193       Агата  [выследить цель]
#   33                466                523  Синеглазый  [выследить цель]
#   38                548                579      Мартин  [выследить цель]
#   ..                ...                ...         ...               ...
#   435               116                167      Бендер  [выследить цель]
#   442               612                618    Пастушок  [выследить цель]
#   453                80                109    Леопольд  [выследить цель]
#   455               809                835        Соня  [выследить цель]
#   470               913                959     Глюкоза  [выследить цель]
#
#        Идеальное время                                       диапазон дат
#   2                  6  [1022, 1021, 1020, 1019, 1018, 1017, 1016, 101...
#   18                 8  [862, 861, 860, 859, 858, 857, 856, 855, 854, ...
#   20                 5  [193, 192, 191, 190, 189, 188, 187, 186, 185, ...
#   33                 3  [523, 522, 521, 520, 519, 518, 517, 516, 515, ...
#   38                 3  [579, 578, 577, 576, 575, 574, 573, 572, 571, ...
#   ..               ...                                                ...
#   435                6  [167, 166, 165, 164, 163, 162, 161, 160, 159, ...
#   442                2  [618, 617, 616, 615, 614, 613, 612, 611, 610, ...
#   453               10  [109, 108, 107, 106, 105, 104, 103, 102, 101, ...
#   455                2  [835, 834, 833, 832, 831, 830, 829, 828, 827, ...
#   470                6  [959, 958, 957, 956, 955, 954, 953, 952, 951, ...
#
#   [62 rows x 16 columns],
#   'vecs': array([[ 0.17999803,  0.03675321, -0.27292687, ...,  0.00877029,
#            0.02204125, -0.30614185],
#          [ 0.17999803,  0.03675321, -0.27292687, ...,  0.00877029,
#            0.02204125, -0.30614185],
#          [ 0.23893704,  0.11030099, -0.36874908, ...,  0.07927215,
#            0.13071129, -0.32830608],
#          ...,
#          [ 0.18089804,  0.1338622 , -0.17231438, ..., -0.04690132,
#           -0.01532943, -0.24205807],
#          [ 0.23893704,  0.11030099, -0.36874908, ...,  0.07927215,
#            0.13071129, -0.32830608],
#          [ 0.17999803,  0.03675321, -0.27292687, ...,  0.00877029,
#            0.02204125, -0.30614185]], dtype=float32)},
#  'убить-победить-уничтожить монстр': {'df_slice':      Номер поручения      Заказчик Дата поручения Дата выполнения  \
#   3              11003        Бьянка     1052-11-24      1052-12-02
#   16             11016          Надя     1051-10-27      1051-12-02
#   21             11021         Чарли     1051-03-07      1051-04-04
#   26             11026        Эмилио     1051-01-10      1051-01-18
#   36             11036          Егор     1051-10-13      1051-10-16
#   41             11041          Анна     1053-04-10      1053-04-18
#   62             11063         Мария     1053-04-28      1053-05-11
#   75             11076         Чарли     1053-09-26      1053-11-16
#   76             11077        Бьянка     1053-10-09      1053-12-06
#   79             11080         Чарли     1051-06-13      1051-07-23
#   82             11083          Надя     1051-05-24      1051-06-14
#   84             11085       Татьяна     1052-09-21      1052-10-04
#   86             11087         Роман     1051-09-11      1051-09-23
#   90             11091       Аделина     1051-02-08      1051-03-26
#   92             11093          Егор     1052-10-28      1052-11-04
#   99             11100          Анна     1051-04-10      1051-05-22
#   108            11109          Анна     1051-11-09      1051-12-29
#   120            11121         Роман     1053-04-25      1053-06-16
#   121            11122  Бабушка Синь     1051-10-16      1051-10-29
#   123            11124         Чарли     1052-03-11      1052-05-07
#   155            11158          Иван     1053-02-09      1053-02-19
#   181            11185         Мария     1051-01-22      1051-01-25
#   188            11192          Влад     1051-12-06      1052-01-22
#   189            11193  Бабушка Синь     1051-01-22      1051-02-17
#   196            11200  Бабушка Синь     1053-02-26      1053-04-27
#   198            11202       Леонтия     1051-09-04      1051-09-08
#   218            11223       Леонтия     1051-10-30      1051-11-02
#   221            11226          Надя     1052-02-02      1052-02-24
#   250            11257        Эмилио     1053-01-25      1053-03-23
#   257            11264         Чарли     1051-03-28      1051-05-10
#   260            11267          Влад     1053-03-09      1053-03-29
#   264            11271          Егор     1053-06-25      1053-08-09
#   273            11280          Надя     1052-10-13      1052-10-26
#   292            11300          Влад     1053-06-28      1053-08-13
#   338            11349       Леонтия     1051-11-30      1051-12-07
#   339            11350          Олег     1051-05-25      1051-05-29
#   355            11366          Надя     1052-12-15      1053-02-09
#   361            11372       Аделина     1052-08-27      1052-10-25
#   363            11374          Надя     1052-08-20      1052-09-09
#   389            11404          Олег     1053-04-15      1053-05-28
#   402            11418        Эмилио     1053-07-21      1053-08-28
#   403            11419       Аделина     1051-04-10      1051-05-22
#   408            11424       Аделина     1051-03-02      1051-03-29
#   414            11431   Максимилиан     1051-07-15      1051-08-21
#   419            11436          Егор     1052-12-19      1052-12-31
#   423            11441          Анна     1053-01-07      1053-02-18
#   430            11448         Мария     1051-08-16      1051-08-30
#   447            11466          Олег     1051-06-03      1051-07-28
#   448            11467        Эмилио     1052-06-17      1052-06-29
#   450            11469        Эмилио     1053-01-01      1053-01-22
#   463            11482          Иван     1051-10-23      1051-11-02
#   471            11490          Анна     1052-04-07      1052-04-24
#   477            11496          Олег     1052-10-03      1052-11-25
#   478            11497       Леонтия     1053-06-13      1053-07-10
#
#        Затрачено дней  Сумма вознаграждения  \
#   3                 5                  5500
#   16                4                 26500
#   21                5                 13000
#   26                1                 15000
#   36                2                 18500
#   41                7                 15500
#   62                9                 24500
#   75                9                 22000
#   76                8                 24500
#   79                6                 25500
#   82                1                 20000
#   84                4                 17000
#   86                9                 12000
#   90                3                 19000
#   92                6                 24500
#   99                5                  7500
#   108               3                  5000
#   120               7                 26500
#   121               1                 19500
#   123               6                 21000
#   155               3                 28000
#   181               1                 23000
#   188               6                  7000
#   189               3                 21500
#   196              10                 17000
#   198               2                  5000
#   218               2                  6500
#   221               5                 16500
#   250               1                 25500
#   257               4                 29500
#   260               1                 25500
#   264               8                 12500
#   273               1                 24500
#   292               1                 11000
#   338               5                 29500
#   339               3                 16000
#   355               9                 13000
#   361               9                 27500
#   363               4                 12500
#   389               3                 29500
#   402               6                 25000
#   403               9                 22000
#   408               5                  9500
#   414               9                 14000
#   419               7                 28000
#   423              10                  7000
#   430               3                 18000
#   447              10                 25500
#   448               7                 18500
#   450               5                 13500
#   463               2                 18000
#   471               1                 26500
#   477               7                  9000
#   478               4                  8000
#
#                                              description  \
#   3                   Недалеко от города видели монстров
#   16                В лесу около деревни видели монстров
#   21        В лесу по дороге от пещеры заметили монстров
#   26     В лесу между городом и деревней видели монстров
#   36     В лесу между городом и деревней видели монстров
#   41   В лесу между городом и деревней монстры напада...
#   62              В лесу около деревни заметили монстров
#   75   В лесу по дороге от пещеры монстры нападают на...
#   76   В лесу по дороге от пещеры монстры нападают на...
#   79          В лесу по дороге от пещеры видели монстров
#   82              По дороге из деревни заметили монстров
#   84      По дороге из деревни монстры нападают на людей
#   86   В лесу недалеко от города монстры нападают на ...
#   90        Недалеко от города монстры нападают на людей
#   92   В лесу между городом и деревней монстры напада...
#   99                Недалеко от города заметили монстров
#   108               Недалеко от города заметили монстров
#   120  В лесу между городом и деревней монстры напада...
#   121             По дороге из деревни заметили монстров
#   123         В лесу по дороге от пещеры видели монстров
#   155               Недалеко от города заметили монстров
#   181  В лесу между городом и деревней монстры напада...
#   188               Недалеко от города заметили монстров
#   189          В лесу недалеко от города видели монстров
#   196    В лесу между городом и деревней видели монстров
#   198       В лесу по дороге от пещеры заметили монстров
#   218         В лесу по дороге от пещеры видели монстров
#   221               В лесу около деревни видели монстров
#   250       В лесу по дороге от пещеры заметили монстров
#   257  В лесу между городом и деревней заметили монстров
#   260     По дороге из деревни монстры нападают на людей
#   264                 Недалеко от города видели монстров
#   273  В лесу по дороге от пещеры монстры нападают на...
#   292    В лесу между городом и деревней видели монстров
#   338               В лесу около деревни видели монстров
#   339       В лесу по дороге от пещеры заметили монстров
#   355          В лесу недалеко от города видели монстров
#   361        В лесу недалеко от города заметили монстров
#   363        В лесу недалеко от города заметили монстров
#   389  В лесу по дороге от пещеры монстры нападают на...
#   402  В лесу между городом и деревней монстры напада...
#   403          В лесу недалеко от города видели монстров
#   408     В лесу около деревни монстры нападают на людей
#   414               В лесу около деревни видели монстров
#   419        В лесу недалеко от города заметили монстров
#   423          В лесу недалеко от города видели монстров
#   430  В лесу недалеко от города монстры нападают на ...
#   447         В лесу по дороге от пещеры видели монстров
#   448     В лесу около деревни монстры нападают на людей
#   450     По дороге из деревни монстры нападают на людей
#   463               В лесу около деревни видели монстров
#   471         В лесу по дороге от пещеры видели монстров
#   477    В лесу между городом и деревней видели монстров
#   478  В лесу по дороге от пещеры монстры нападают на...
#
#                                 cluster              time_in  \
#   3    убить-победить-уничтожить монстр  1052-11-24 00:00:00
#   16   убить-победить-уничтожить монстр  1051-10-27 00:00:00
#   21   убить-победить-уничтожить монстр  1051-03-07 00:00:00
#   26   убить-победить-уничтожить монстр  1051-01-10 00:00:00
#   36   убить-победить-уничтожить монстр  1051-10-13 00:00:00
#   41   убить-победить-уничтожить монстр  1053-04-10 00:00:00
#   62   убить-победить-уничтожить монстр  1053-04-28 00:00:00
#   75   убить-победить-уничтожить монстр  1053-09-26 00:00:00
#   76   убить-победить-уничтожить монстр  1053-10-09 00:00:00
#   79   убить-победить-уничтожить монстр  1051-06-13 00:00:00
#   82   убить-победить-уничтожить монстр  1051-05-24 00:00:00
#   84   убить-победить-уничтожить монстр  1052-09-21 00:00:00
#   86   убить-победить-уничтожить монстр  1051-09-11 00:00:00
#   90   убить-победить-уничтожить монстр  1051-02-08 00:00:00
#   92   убить-победить-уничтожить монстр  1052-10-28 00:00:00
#   99   убить-победить-уничтожить монстр  1051-04-10 00:00:00
#   108  убить-победить-уничтожить монстр  1051-11-09 00:00:00
#   120  убить-победить-уничтожить монстр  1053-04-25 00:00:00
#   121  убить-победить-уничтожить монстр  1051-10-16 00:00:00
#   123  убить-победить-уничтожить монстр  1052-03-11 00:00:00
#   155  убить-победить-уничтожить монстр  1053-02-09 00:00:00
#   181  убить-победить-уничтожить монстр  1051-01-22 00:00:00
#   188  убить-победить-уничтожить монстр  1051-12-06 00:00:00
#   189  убить-победить-уничтожить монстр  1051-01-22 00:00:00
#   196  убить-победить-уничтожить монстр  1053-02-26 00:00:00
#   198  убить-победить-уничтожить монстр  1051-09-04 00:00:00
#   218  убить-победить-уничтожить монстр  1051-10-30 00:00:00
#   221  убить-победить-уничтожить монстр  1052-02-02 00:00:00
#   250  убить-победить-уничтожить монстр  1053-01-25 00:00:00
#   257  убить-победить-уничтожить монстр  1051-03-28 00:00:00
#   260  убить-победить-уничтожить монстр  1053-03-09 00:00:00
#   264  убить-победить-уничтожить монстр  1053-06-25 00:00:00
#   273  убить-победить-уничтожить монстр  1052-10-13 00:00:00
#   292  убить-победить-уничтожить монстр  1053-06-28 00:00:00
#   338  убить-победить-уничтожить монстр  1051-11-30 00:00:00
#   339  убить-победить-уничтожить монстр  1051-05-25 00:00:00
#   355  убить-победить-уничтожить монстр  1052-12-15 00:00:00
#   361  убить-победить-уничтожить монстр  1052-08-27 00:00:00
#   363  убить-победить-уничтожить монстр  1052-08-20 00:00:00
#   389  убить-победить-уничтожить монстр  1053-04-15 00:00:00
#   402  убить-победить-уничтожить монстр  1053-07-21 00:00:00
#   403  убить-победить-уничтожить монстр  1051-04-10 00:00:00
#   408  убить-победить-уничтожить монстр  1051-03-02 00:00:00
#   414  убить-победить-уничтожить монстр  1051-07-15 00:00:00
#   419  убить-победить-уничтожить монстр  1052-12-19 00:00:00
#   423  убить-победить-уничтожить монстр  1053-01-07 00:00:00
#   430  убить-победить-уничтожить монстр  1051-08-16 00:00:00
#   447  убить-победить-уничтожить монстр  1051-06-03 00:00:00
#   448  убить-победить-уничтожить монстр  1052-06-17 00:00:00
#   450  убить-победить-уничтожить монстр  1053-01-01 00:00:00
#   463  убить-победить-уничтожить монстр  1051-10-23 00:00:00
#   471  убить-победить-уничтожить монстр  1052-04-07 00:00:00
#   477  убить-победить-уничтожить монстр  1052-10-03 00:00:00
#   478  убить-победить-уничтожить монстр  1053-06-13 00:00:00
#
#                time_finish  Дата поручения_t  Дата выполнения_t       Герой  \
#   3    1052-12-02 00:00:00               692                700      Бендер
#   16   1051-12-02 00:00:00               298                334      Бендер
#   21   1051-04-04 00:00:00                64                 92    Леопольд
#   26   1051-01-18 00:00:00                 8                 16    Леопольд
#   36   1051-10-16 00:00:00               284                287     Глюкоза
#   41   1053-04-18 00:00:00               829                837     Альфред
#   62   1053-05-11 00:00:00               847                860        Юлия
#   75   1053-11-16 00:00:00               998               1049        Юлия
#   76   1053-12-06 00:00:00              1011               1069  Синеглазый
#   79   1051-07-23 00:00:00               162                202     Глюкоза
#   82   1051-06-14 00:00:00               142                163    Фредерик
#   84   1052-10-04 00:00:00               628                641  Синеглазый
#   86   1051-09-23 00:00:00               252                264       Агата
#   90   1051-03-26 00:00:00                37                 83     Альфред
#   92   1052-11-04 00:00:00               665                672     Глюкоза
#   99   1051-05-22 00:00:00                98                140  Синеглазый
#   108  1051-12-29 00:00:00               311                361    Пастушок
#   120  1053-06-16 00:00:00               844                896  Синеглазый
#   121  1051-10-29 00:00:00               287                300     Глюкоза
#   123  1052-05-07 00:00:00               434                491    Фредерик
#   155  1053-02-19 00:00:00               769                779        Соня
#   181  1051-01-25 00:00:00                20                 23      Бендер
#   188  1052-01-22 00:00:00               338                385     Глюкоза
#   189  1051-02-17 00:00:00                20                 46     Глюкоза
#   196  1053-04-27 00:00:00               786                846     Альфред
#   198  1051-09-08 00:00:00               245                249       Агата
#   218  1051-11-02 00:00:00               301                304    Леопольд
#   221  1052-02-24 00:00:00               396                418    Фредерик
#   250  1053-03-23 00:00:00               754                811     Альфред
#   257  1051-05-10 00:00:00                85                128    Леопольд
#   260  1053-03-29 00:00:00               797                817    Бенедикт
#   264  1053-08-09 00:00:00               905                950    Фредерик
#   273  1052-10-26 00:00:00               650                663  Синеглазый
#   292  1053-08-13 00:00:00               908                954     Глюкоза
#   338  1051-12-07 00:00:00               332                339    Фредерик
#   339  1051-05-29 00:00:00               143                147    Леопольд
#   355  1053-02-09 00:00:00               713                769        Юлия
#   361  1052-10-25 00:00:00               603                662    Бенедикт
#   363  1052-09-09 00:00:00               596                616    Леопольд
#   389  1053-05-28 00:00:00               834                877     Глюкоза
#   402  1053-08-28 00:00:00               931                969     Альфред
#   403  1051-05-22 00:00:00                98                140    Леопольд
#   408  1051-03-29 00:00:00                59                 86    Леопольд
#   414  1051-08-21 00:00:00               194                231        Юлия
#   419  1052-12-31 00:00:00               717                729        Юлия
#   423  1053-02-18 00:00:00               736                778      Бендер
#   430  1051-08-30 00:00:00               226                240    Бенедикт
#   447  1051-07-28 00:00:00               152                207    Леопольд
#   448  1052-06-29 00:00:00               532                544     Альфред
#   450  1053-01-22 00:00:00               730                751    Фредерик
#   463  1051-11-02 00:00:00               294                304    Пастушок
#   471  1052-04-24 00:00:00               461                478        Соня
#   477  1052-11-25 00:00:00               640                693        Юлия
#   478  1053-07-10 00:00:00               893                920    Пастушок
#
#                                       Запись в дневнике  Идеальное время  \
#   3                                    [разжечь костёр]                4
#   16   [разжечь костёр, выследить цель, разжечь костёр]                4
#   21                   [разжечь костёр, разжечь костёр]                5
#   26                   [разжечь костёр, разжечь костёр]                1
#   36                   [разжечь костёр, разжечь костёр]                1
#   41    [разжечь костёр, залечить раны, разжечь костёр]                6
#   62    [разжечь костёр, залечить раны, разжечь костёр]                8
#   75    [разжечь костёр, залечить раны, разжечь костёр]                8
#   76    [разжечь костёр, залечить раны, разжечь костёр]                5
#   79                   [разжечь костёр, разжечь костёр]                5
#   82                    [залечить раны, разжечь костёр]                1
#   84                   [выследить цель, разжечь костёр]                4
# ...
#   23                В деревне у меня потерялся рюкзак  вернуть-найти рюкзак
#   27                    В городе у меня пропал рюкзак  вернуть-найти рюкзак
#   32     Недалеко от города у меня был украден рюкзак  вернуть-найти рюкзак
#   35                   В деревне у меня пропал рюкзак  вернуть-найти рюкзак
#   46                 В городе у меня потерялся рюкзак  вернуть-найти рюкзак
#   48                    В городе у меня пропал рюкзак  вернуть-найти рюкзак
#   113              В городе у меня был украден рюкзак  вернуть-найти рюкзак
#   127    Недалеко от города у меня был украден рюкзак  вернуть-найти рюкзак
#   151                   В городе у меня пропал рюкзак  вернуть-найти рюкзак
#   157                В городе у меня потерялся рюкзак  вернуть-найти рюкзак
#   160    Недалеко от города у меня был украден рюкзак  вернуть-найти рюкзак
#   174             В деревне у меня был украден рюкзак  вернуть-найти рюкзак
#   176                  В деревне у меня пропал рюкзак  вернуть-найти рюкзак
#   183    Недалеко от города у меня был украден рюкзак  вернуть-найти рюкзак
#   187                   В городе у меня пропал рюкзак  вернуть-найти рюкзак
#   217                  В деревне у меня пропал рюкзак  вернуть-найти рюкзак
#   219         Недалеко от города у меня пропал рюкзак  вернуть-найти рюкзак
#   227       По дороге из деревни у меня пропал рюкзак  вернуть-найти рюкзак
#   228                В городе у меня потерялся рюкзак  вернуть-найти рюкзак
#   236               В деревне у меня потерялся рюкзак  вернуть-найти рюкзак
#   238                В городе у меня потерялся рюкзак  вернуть-найти рюкзак
#   259  По дороге из деревни у меня был украден рюкзак  вернуть-найти рюкзак
#   266       По дороге из деревни у меня пропал рюкзак  вернуть-найти рюкзак
#   277             В деревне у меня был украден рюкзак  вернуть-найти рюкзак
#   291      Недалеко от города у меня потерялся рюкзак  вернуть-найти рюкзак
#   299                  В деревне у меня пропал рюкзак  вернуть-найти рюкзак
#   306    Недалеко от города у меня был украден рюкзак  вернуть-найти рюкзак
#   314  По дороге из деревни у меня был украден рюкзак  вернуть-найти рюкзак
#   317    Недалеко от города у меня был украден рюкзак  вернуть-найти рюкзак
#   318    Недалеко от города у меня был украден рюкзак  вернуть-найти рюкзак
#   321              В городе у меня был украден рюкзак  вернуть-найти рюкзак
#   327                   В городе у меня пропал рюкзак  вернуть-найти рюкзак
#   333    Недалеко от города у меня был украден рюкзак  вернуть-найти рюкзак
#   341             В деревне у меня был украден рюкзак  вернуть-найти рюкзак
#   348         Недалеко от города у меня пропал рюкзак  вернуть-найти рюкзак
#   359      Недалеко от города у меня потерялся рюкзак  вернуть-найти рюкзак
#   373             В деревне у меня был украден рюкзак  вернуть-найти рюкзак
#   388             В деревне у меня был украден рюкзак  вернуть-найти рюкзак
#   392                   В городе у меня пропал рюкзак  вернуть-найти рюкзак
#   396         Недалеко от города у меня пропал рюкзак  вернуть-найти рюкзак
#   399    Недалеко от города у меня был украден рюкзак  вернуть-найти рюкзак
#   406         Недалеко от города у меня пропал рюкзак  вернуть-найти рюкзак
#   407  По дороге из деревни у меня был украден рюкзак  вернуть-найти рюкзак
#   416                   В городе у меня пропал рюкзак  вернуть-найти рюкзак
#   437             В деревне у меня был украден рюкзак  вернуть-найти рюкзак
#   439                В городе у меня потерялся рюкзак  вернуть-найти рюкзак
#   443                   В городе у меня пропал рюкзак  вернуть-найти рюкзак
#   466             В деревне у меня был украден рюкзак  вернуть-найти рюкзак
#   467                  В деревне у меня пропал рюкзак  вернуть-найти рюкзак
#   475         Недалеко от города у меня пропал рюкзак  вернуть-найти рюкзак
#
#                    time_in          time_finish  Дата поручения_t  \
#   23   1051-02-16 00:00:00  1051-04-11 00:00:00                45
#   27   1051-07-19 00:00:00  1051-09-08 00:00:00               198
#   32   1052-07-07 00:00:00  1052-08-23 00:00:00               552
#   35   1052-06-26 00:00:00  1052-07-01 00:00:00               541
#   46   1053-03-02 00:00:00  1053-04-01 00:00:00               790
#   48   1053-11-01 00:00:00  1053-12-24 00:00:00              1034
#   113  1053-07-05 00:00:00  1053-07-13 00:00:00               915
#   127  1052-02-15 00:00:00  1052-03-21 00:00:00               409
#   151  1053-09-22 00:00:00  1053-11-12 00:00:00               994
#   157  1052-07-02 00:00:00  1052-07-18 00:00:00               547
#   160  1053-05-04 00:00:00  1053-05-29 00:00:00               853
#   174  1051-04-01 00:00:00  1051-05-08 00:00:00                89
#   176  1051-06-06 00:00:00  1051-07-30 00:00:00               155
#   183  1052-04-24 00:00:00  1052-06-18 00:00:00               478
#   187  1052-07-09 00:00:00  1052-08-04 00:00:00               554
#   217  1052-08-14 00:00:00  1052-10-11 00:00:00               590
#   219  1053-01-20 00:00:00  1053-01-29 00:00:00               749
#   227  1053-03-27 00:00:00  1053-05-01 00:00:00               815
#   228  1051-07-29 00:00:00  1051-09-09 00:00:00               208
#   236  1052-11-22 00:00:00  1053-01-15 00:00:00               690
#   238  1053-07-08 00:00:00  1053-08-05 00:00:00               918
#   259  1051-04-26 00:00:00  1051-06-20 00:00:00               114
#   266  1053-05-02 00:00:00  1053-06-14 00:00:00               851
#   277  1051-05-13 00:00:00  1051-05-18 00:00:00               131
#   291  1053-03-08 00:00:00  1053-04-29 00:00:00               796
#   299  1053-05-09 00:00:00  1053-05-27 00:00:00               858
#   306  1052-12-20 00:00:00  1053-01-14 00:00:00               718
#   314  1052-02-27 00:00:00  1052-03-08 00:00:00               421
#   317  1051-12-15 00:00:00  1052-01-14 00:00:00               347
#   318  1053-06-19 00:00:00  1053-08-04 00:00:00               899
#   321  1051-05-27 00:00:00  1051-06-10 00:00:00               145
#   327  1052-10-16 00:00:00  1052-12-13 00:00:00               653
#   333  1051-08-24 00:00:00  1051-09-13 00:00:00               234
#   341  1053-05-07 00:00:00  1053-06-01 00:00:00               856
#   348  1051-08-07 00:00:00  1051-09-11 00:00:00               217
#   359  1051-12-19 00:00:00  1052-01-08 00:00:00               351
#   373  1053-05-07 00:00:00  1053-07-03 00:00:00               856
#   388  1052-02-28 00:00:00  1052-03-14 00:00:00               422
#   392  1051-12-16 00:00:00  1051-12-31 00:00:00               348
#   396  1051-03-23 00:00:00  1051-05-15 00:00:00                80
#   399  1052-11-15 00:00:00  1052-12-18 00:00:00               683
#   406  1052-07-19 00:00:00  1052-08-11 00:00:00               564
#   407  1051-05-09 00:00:00  1051-05-17 00:00:00               127
#   416  1053-05-03 00:00:00  1053-05-21 00:00:00               852
#   437  1053-04-23 00:00:00  1053-05-27 00:00:00               842
#   439  1053-03-09 00:00:00  1053-04-29 00:00:00               797
#   443  1051-05-17 00:00:00  1051-06-11 00:00:00               135
#   466  1051-08-13 00:00:00  1051-08-29 00:00:00               223
#   467  1052-03-30 00:00:00  1052-04-13 00:00:00               453
#   475  1052-08-05 00:00:00  1052-09-15 00:00:00               581
#
#        Дата выполнения_t       Герой                    Запись в дневнике  \
#   23                  99        Юлия  [найти пропажу, отыскать заказчика]
#   27                 249    Бенедикт  [найти пропажу, отыскать заказчика]
#   32                 599    Пастушок  [найти пропажу, отыскать заказчика]
#   35                 546    Бенедикт  [найти пропажу, отыскать заказчика]
#   46                 820  Синеглазый  [найти пропажу, отыскать заказчика]
#   48                1087        Соня  [найти пропажу, отыскать заказчика]
#   113                923     Альфред  [найти пропажу, отыскать заказчика]
#   127                444    Леопольд  [найти пропажу, отыскать заказчика]
#   151               1045    Леопольд  [найти пропажу, отыскать заказчика]
#   157                563      Мартин  [найти пропажу, отыскать заказчика]
#   160                878        Соня  [найти пропажу, отыскать заказчика]
#   174                126     Глюкоза  [найти пропажу, отыскать заказчика]
#   176                209        Юлия  [найти пропажу, отыскать заказчика]
#   183                533        Юлия  [найти пропажу, отыскать заказчика]
#   187                580    Бенедикт  [найти пропажу, отыскать заказчика]
#   217                648      Мартин  [найти пропажу, отыскать заказчика]
#   219                758    Фредерик  [найти пропажу, отыскать заказчика]
#   227                850    Леопольд  [найти пропажу, отыскать заказчика]
#   228                250  Синеглазый  [найти пропажу, отыскать заказчика]
#   236                744  Синеглазый  [найти пропажу, отыскать заказчика]
#   238                946  Синеглазый  [найти пропажу, отыскать заказчика]
#   259                169      Мартин  [найти пропажу, отыскать заказчика]
#   266                894    Фредерик  [найти пропажу, отыскать заказчика]
#   277                136      Бендер  [найти пропажу, отыскать заказчика]
#   291                848    Леопольд  [найти пропажу, отыскать заказчика]
#   299                876  Синеглазый  [найти пропажу, отыскать заказчика]
#   306                743        Юлия  [найти пропажу, отыскать заказчика]
#   314                431       Агата  [найти пропажу, отыскать заказчика]
#   317                377  Синеглазый  [найти пропажу, отыскать заказчика]
#   318                945    Бенедикт  [найти пропажу, отыскать заказчика]
#   321                159    Пастушок  [найти пропажу, отыскать заказчика]
#   327                711        Юлия  [найти пропажу, отыскать заказчика]
#   333                254      Мартин  [найти пропажу, отыскать заказчика]
#   341                881    Пастушок  [найти пропажу, отыскать заказчика]
#   348                252    Фредерик  [найти пропажу, отыскать заказчика]
#   359                371     Альфред  [найти пропажу, отыскать заказчика]
#   373                913    Леопольд  [найти пропажу, отыскать заказчика]
#   388                437      Бендер  [найти пропажу, отыскать заказчика]
#   392                363    Фредерик  [найти пропажу, отыскать заказчика]
#   396                133      Бендер  [найти пропажу, отыскать заказчика]
#   399                716    Фредерик  [найти пропажу, отыскать заказчика]
#   406                587    Леопольд  [найти пропажу, отыскать заказчика]
#   407                135    Фредерик  [найти пропажу, отыскать заказчика]
#   416                870      Бендер  [найти пропажу, отыскать заказчика]
#   437                876     Глюкоза  [найти пропажу, отыскать заказчика]
#   439                848    Бенедикт  [найти пропажу, отыскать заказчика]
#   443                160        Юлия  [найти пропажу, отыскать заказчика]
#   466                239  Синеглазый  [найти пропажу, отыскать заказчика]
#   467                467      Бендер  [найти пропажу, отыскать заказчика]
#   475                622       Агата  [найти пропажу, отыскать заказчика]
#
#        Идеальное время                                       диапазон дат
#   23                 8  [99, 98, 97, 96, 95, 94, 93, 92, 91, 90, 89, 8...
#   27                 8  [249, 248, 247, 246, 245, 244, 243, 242, 241, ...
#   32                 5  [599, 598, 597, 596, 595, 594, 593, 592, 591, ...
#   35                 2  [546, 545, 544, 543, 542, 541, 540, 539, 538, ...
#   46                 2  [820, 819, 818, 817, 816, 815, 814, 813, 812, ...
#   48                 8  [1087, 1086, 1085, 1084, 1083, 1082, 1081, 108...
#   113                5  [923, 922, 921, 920, 919, 918, 917, 916, 915, ...
#   127                7  [444, 443, 442, 441, 440, 439, 438, 437, 436, ...
#   151                6  [1045, 1044, 1043, 1042, 1041, 1040, 1039, 103...
#   157                3  [563, 562, 561, 560, 559, 558, 557, 556, 555, ...
#   160                5  [878, 877, 876, 875, 874, 873, 872, 871, 870, ...
#   174                3  [126, 125, 124, 123, 122, 121, 120, 119, 118, ...
#   176                8  [209, 208, 207, 206, 205, 204, 203, 202, 201, ...
#   183                6  [533, 532, 531, 530, 529, 528, 527, 526, 525, ...
#   187                2  [580, 579, 578, 577, 576, 575, 574, 573, 572, ...
#   217                8  [648, 647, 646, 645, 644, 643, 642, 641, 640, ...
#   219                4  [758, 757, 756, 755, 754, 753, 752, 751, 750, ...
#   227                6  [850, 849, 848, 847, 846, 845, 844, 843, 842, ...
#   228                4  [250, 249, 248, 247, 246, 245, 244, 243, 242, ...
#   236                5  [744, 743, 742, 741, 740, 739, 738, 737, 736, ...
#   238                2  [946, 945, 944, 943, 942, 941, 940, 939, 938, ...
#   259                6  [169, 168, 167, 166, 165, 164, 163, 162, 161, ...
#   266                6  [894, 893, 892, 891, 890, 889, 888, 887, 886, ...
#   277                2  [136, 135, 134, 133, 132, 131, 130, 129, 128, ...
#   291                3  [848, 847, 846, 845, 844, 843, 842, 841, 840, ...
#   299                6  [876, 875, 874, 873, 872, 871, 870, 869, 868, ...
#   306                7  [743, 742, 741, 740, 739, 738, 737, 736, 735, ...
#   314                2  [431, 430, 429, 428, 427, 426, 425, 424, 423, ...
#   317                2  [377, 376, 375, 374, 373, 372, 371, 370, 369, ...
#   318                1  [945, 944, 943, 942, 941, 940, 939, 938, 937, ...
#   321                7  [159, 158, 157, 156, 155, 154, 153, 152, 151, ...
#   327                6  [711, 710, 709, 708, 707, 706, 705, 704, 703, ...
#   333                5  [254, 253, 252, 251, 250, 249, 248, 247, 246, ...
#   341                7  [881, 880, 879, 878, 877, 876, 875, 874, 873, ...
#   348                6  [252, 251, 250, 249, 248, 247, 246, 245, 244, ...
#   359                5  [371, 370, 369, 368, 367, 366, 365, 364, 363, ...
#   373                4  [913, 912, 911, 910, 909, 908, 907, 906, 905, ...
#   388                8  [437, 436, 435, 434, 433, 432, 431, 430, 429, ...
#   392                5  [363, 362, 361, 360, 359, 358, 357, 356, 355, ...
#   396                4  [133, 132, 131, 130, 129, 128, 127, 126, 125, ...
#   399                4  [716, 715, 714, 713, 712, 711, 710, 709, 708, ...
#   406                5  [587, 586, 585, 584, 583, 582, 581, 580, 579, ...
#   407                2  [135, 134, 133, 132, 131, 130, 129, 128, 127, ...
#   416                4  [870, 869, 868, 867, 866, 865, 864, 863, 862, ...
#   437                2  [876, 875, 874, 873, 872, 871, 870, 869, 868, ...
#   439                3  [848, 847, 846, 845, 844, 843, 842, 841, 840, ...
#   443                2  [160, 159, 158, 157, 156, 155, 154, 153, 152, ...
#   466                2  [239, 238, 237, 236, 235, 234, 233, 232, 231, ...
#   467                4  [467, 466, 465, 464, 463, 462, 461, 460, 459, ...
#   475                6  [622, 621, 620, 619, 618, 617, 616, 615, 614, ...  ,
#   'vecs': array([[ 0.0772648 ,  0.02343634, -0.1617963 , ..., -0.21616481,
#            0.00919232, -0.03852651],
#          [ 0.11303122,  0.04159737, -0.16567731, ..., -0.13722299,
#            0.0535849 , -0.02657236],
#          [ 0.12813081, -0.02518999, -0.26687765, ..., -0.1205087 ,
#            0.09449665, -0.08133309],
#          ...,
#          [ 0.09411749,  0.00529443, -0.18281287, ..., -0.19565566,
#            0.00440636, -0.04219428],
#          [ 0.07290576,  0.02722931, -0.12987384, ..., -0.14848813,
#           -0.0105155 , -0.03674772],
#          [ 0.15584922, -0.00685567, -0.23507458, ..., -0.06093681,
#            0.06777669, -0.08402423]], dtype=float32)}}

# %% [markdown]
# # 3. Модель

# %% [markdown]
# ### Определение ближайших выполненных поручений перед запуском модели
#
# Перед запуском модели для планирования невыполненных поручений был реализован подход, который позволяет использовать информацию из исторических данных выполненных задач.
#
# ---
#
# #### Алгоритм определения ближайшего выполненного поручения
#
# 1. **Определение кластера для невыполненного поручения**
#    Для каждого невыполненного поручения определяется его **кластер цель-объект**, чтобы ограничить поиск задач только задачами из того же кластера.
#
# 2. **Поиск ближайшего выполненного поручения**
#    Используется векторное представление поручений. Для входного невыполненного поручения рассчитывается **косинусное расстояние** до всех выполненных поручений внутри этого же кластера.
#    - Находится ближайшая задача, которая уже была успешно выполнена.
#
# 3. **Получение данных о выполненной задаче**
#    Для ближайшего выполненного поручения извлекается:
#    - **Идеальное время выполнения задачи.**
#    - **Список задач, необходимых для выполнения.**
#
# ---
#
# #### Допущение
#
# Предполагается, что все задачи внутри одного кластера схожи локально. Это позволяет использовать данные о ближайших выполненных задачах как ориентир для оценки времени выполнения и необходимых действий для текущего невыполненного поручения.
#
# ---
#
# #### Построение команд для невыполненной задачи
#
# 1. **Формирование допустимых команд**
#    На основе списка задач ближайшего выполненного поручения рассчитываются допустимые команды (с помощью ``TaskManager``), которые могут выполнить аналогичные действия.
#
# 2. **Оценка команд**
#    Для каждой команды рассчитываются:
#    - Средние показатели по качеству, срокам и вежливости.
#    - Ожидаемое время выполнения задачи.
#
# ---
#
# #### Приоритизация допустимых команд
#
# На основе полученных данных для каждой невыполненной задачи формируется список **приоритетных допустимых команд**, которые:
# 1. Имеют наивысшую **средневзвешенную оценку**:
#
#    * **Оценка команды = 0.5 * Качество + 0.4 * Сроки + 0.1 * Вежливость**
#
# 2. Учитывают доступность героев в заданном временном интервале.
#
# ---
#
# ### Итог
#
# Этот подход позволяет:
# - Использовать данные выполненных задач для предсказания времени и стратегии выполнения новых поручений.
# - Формировать приоритетные команды, которые оптимальны с точки зрения эффективности и доступности.
# - Подготовить базу для реализации рекомендательной системы с учётом успешного опыта выполнения схожих задач.

# %% [markdown]
# ### Формирование тестовой выборки

# %%
df_test_cases = df_cases[df_cases["Выполнено"]=="нет"]
df_test_cases.head()
# Out:
#      Номер поручения Заказчик Дата поручения Выполнено Дата выполнения  \
# 56             11056    Мария     1053-09-06       нет             NaN
# 134            11134     Иван     1053-09-04       нет             NaN
# 143            11143     Егор     1053-10-18       нет             NaN
# 161            11161   Эмилио     1053-10-03       нет             NaN
# 218            11218     Олег     1053-10-01       нет             NaN
#
#      Затрачено дней  Сумма вознаграждения  \
# 56              NaN                 23500
# 134             NaN                 27500
# 143             NaN                 10500
# 161             NaN                  7500
# 218             NaN                 16000
#
#                                               Описание  \
# 56   По дороге из деревни у меня пропала драгоценно...
# 134  В пещере появвилось огромное каменное чудовище...
# 143  В пещере завёлся дракон. Нужно его убить. Это ...
# 161  В городе у меня потерялся рюкзак. Нужно найти ...
# 218  Недалеко от города монстры похитили путников. ...
#
#                                            description  \
# 56   По дороге из деревни у меня пропала драгоценность
# 134     В пещере появвилось огромное каменное чудовище
# 143                            В пещере завёлся дракон
# 161                   В городе у меня потерялся рюкзак
# 218       Недалеко от города монстры похитили путников
#
#                                                 advice  \
# 56
# 134
# 143  Это может потребовать времени и усилий, так ка...
# 161
# 218  Осмотрите все возможные укрытия, чтобы найти п...
#
#                                 purpose purpose_prep  \
# 56   Нужно вернуть её как можно скорее.      вернуть
# 134               Нужно уничтожить его.   уничтожить
# 143                     Нужно его убить        убить
# 161   Нужно найти его как можно скорее.        найти
# 218                     Нужно спасти их       спасти
#
#                                  description_prep             common_purpose  \
# 56          дорога деревня пропасть драгоценность              вернуть-найти
# 134  пещера появвилось огромный каменный чудовище  убить-победить-уничтожить
# 143                       пещера завестись дракон  убить-победить-уничтожить
# 161                       город потеряться рюкзак              вернуть-найти
# 218                  город монстр похитить путник          спасти-освободить
#
#              description_object  \
# 56                драгоценность
# 134  огромный каменный чудовище
# 143                      дракон
# 161                      рюкзак
# 218                      монстр
#
#                                                cluster              time_in  \
# 56                         вернуть-найти драгоценность  1053-09-06 00:00:00
# 134  убить-победить-уничтожить огромный каменный чу...  1053-09-04 00:00:00
# 143                   убить-победить-уничтожить дракон  1053-10-18 00:00:00
# 161                               вернуть-найти рюкзак  1053-10-03 00:00:00
# 218                           спасти-освободить монстр  1053-10-01 00:00:00
#
#     time_finish  Дата поручения_t  Дата выполнения_t
# 56          NaN               978                 -1
# 134         NaN               976                 -1
# 143         NaN              1020                 -1
# 161         NaN              1005                 -1
# 218         NaN              1003                 -1

# %%
#Нахождение ближайшего выполненного соседа и создание на основе его данных всевозмодных команд
wrappers = []
tasks_teams = {}
for task_name, clust, case_, start_quant in df_test_cases[["Номер поручения", "cluster","description", "Дата поручения_t"]].values:
    df_slice, vecs = clusters[clust].values()
    input_vector = encode_text([case_])
    similarities = cosine_similarity([input_vector], vecs).flatten()
    most_similar_idx = similarities.argmax()
    most_similar_record = df_slice.iloc[most_similar_idx]  
    
    heroes_table = hero_profiles[hero_profiles["cluster"]==clust].T.to_dict().values()
    most_similar_record[["Сумма вознаграждения"]]

    nearest_task, t0, amount, tasks = most_similar_record[["Номер поручения", "Идеальное время", "Сумма вознаграждения", "Запись в дневнике"]].values


    manager = TaskManager(heroes_table, heroes_availibility)
    task_mapping = manager.find_heroes_for_task(tasks)
    teams = manager.generate_teams(task_mapping, start_quant, t0)
    sorted_teams = sorted(teams, key=lambda team: team['weighted_score'], reverse=True)

    wrappers.append(priority_wrapper(task_name, sorted_teams, start_quant, amount, nearest_task))


for d in wrappers:
    tasks_teams.update(d)

# %% [markdown]
# ### Пример полученной конструкции

# %%
tasks_teams[11056]
# Out:
# {'priority': {0: {'team': [('Синеглазый', 'следопыт'), ('Соня', 'следопыт')],
#    'avg_quality': 4.416666666666666,
#    'avg_deadline': 4.0,
#    'max_politeness': 3.75,
#    'task_time': 8,
#    'weighted_score': 4.183333333333334,
#    'common_availability': {1,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   1: {'team': [('Соня', 'следопыт'), ('Синеглазый', 'следопыт')],
#    'avg_quality': 4.416666666666666,
#    'avg_deadline': 4.0,
#    'max_politeness': 3.75,
#    'task_time': 8,
#    'weighted_score': 4.183333333333334,
#    'common_availability': {1,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   2: {'team': [('Мартин', 'следопыт'), ('Синеглазый', 'следопыт')],
#    'avg_quality': 4.125,
#    'avg_deadline': 4.0,
#    'max_politeness': 4.25,
#    'task_time': 8,
#    'weighted_score': 4.0875,
#    'common_availability': {1,
#     1070,
#     1071,
#     1072,
#     1073,
#     1074,
#     1075,
#     1076,
#     1077,
#     1078,
#     1079,
#     1080,
#     1081,
#     1082,
#     1083,
#     1084,
#     1085,
#     1086,
#     1087,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   3: {'team': [('Синеглазый', 'следопыт'), ('Мартин', 'следопыт')],
#    'avg_quality': 4.125,
#    'avg_deadline': 4.0,
#    'max_politeness': 4.25,
#    'task_time': 8,
#    'weighted_score': 4.0875,
#    'common_availability': {1,
#     1070,
#     1071,
#     1072,
#     1073,
#     1074,
#     1075,
#     1076,
#     1077,
#     1078,
#     1079,
#     1080,
#     1081,
#     1082,
#     1083,
#     1084,
#     1085,
#     1086,
#     1087,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   4: {'team': [('Бендер', 'следопыт'), ('Синеглазый', 'следопыт')],
#    'avg_quality': 3.95,
#    'avg_deadline': 4.2,
#    'max_politeness': 4.0,
#    'task_time': 8,
#    'weighted_score': 4.055000000000001,
#    'common_availability': {1,
#     1070,
#     1071,
#     1072,
#     1073,
#     1074,
#     1075,
#     1076,
#     1077,
#     1078,
#     1079,
#     1080,
#     1081,
#     1082,
#     1083,
#     1084,
#     1085,
#     1086,
#     1087,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   5: {'team': [('Синеглазый', 'следопыт'), ('Бендер', 'следопыт')],
#    'avg_quality': 3.95,
#    'avg_deadline': 4.2,
#    'max_politeness': 4.0,
#    'task_time': 8,
#    'weighted_score': 4.055000000000001,
#    'common_availability': {1,
#     1070,
#     1071,
#     1072,
#     1073,
#     1074,
#     1075,
#     1076,
#     1077,
#     1078,
#     1079,
#     1080,
#     1081,
#     1082,
#     1083,
#     1084,
#     1085,
#     1086,
#     1087,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   6: {'team': [('Агата', 'следопыт'), ('Синеглазый', 'следопыт')],
#    'avg_quality': 4.0,
#    'avg_deadline': 4.0,
#    'max_politeness': 4.5,
#    'task_time': 8,
#    'weighted_score': 4.05,
#    'common_availability': {1,
#     1070,
#     1071,
#     1072,
#     1073,
#     1074,
#     1075,
#     1076,
#     1077,
#     1078,
#     1079,
#     1080,
#     1081,
#     1082,
#     1083,
#     1084,
#     1085,
#     1086,
#     1087,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   7: {'team': [('Пастушок', 'следопыт'), ('Синеглазый', 'следопыт')],
#    'avg_quality': 4.321428571428571,
#    'avg_deadline': 3.7857142857142856,
#    'max_politeness': 3.75,
#    'task_time': 8,
#    'weighted_score': 4.05,
#    'common_availability': {1,
#     1083,
#     1084,
#     1085,
#     1086,
#     1087,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   8: {'team': [('Синеглазый', 'следопыт'), ('Агата', 'следопыт')],
#    'avg_quality': 4.0,
#    'avg_deadline': 4.0,
#    'max_politeness': 4.5,
#    'task_time': 8,
#    'weighted_score': 4.05,
#    'common_availability': {1,
#     1070,
#     1071,
#     1072,
#     1073,
#     1074,
#     1075,
#     1076,
#     1077,
#     1078,
#     1079,
#     1080,
#     1081,
#     1082,
#     1083,
#     1084,
#     1085,
#     1086,
#     1087,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   9: {'team': [('Синеглазый', 'следопыт'), ('Пастушок', 'следопыт')],
#    'avg_quality': 4.321428571428571,
#    'avg_deadline': 3.7857142857142856,
#    'max_politeness': 3.75,
#    'task_time': 8,
#    'weighted_score': 4.05,
#    'common_availability': {1,
#     1083,
#     1084,
#     1085,
#     1086,
#     1087,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   10: {'team': [('Мартин', 'следопыт'), ('Соня', 'следопыт')],
#    'avg_quality': 4.041666666666666,
#    'avg_deadline': 4.0,
#    'max_politeness': 4.25,
#    'task_time': 8,
#    'weighted_score': 4.045833333333333,
#    'common_availability': {1,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   11: {'team': [('Соня', 'следопыт'), ('Мартин', 'следопыт')],
#    'avg_quality': 4.041666666666666,
#    'avg_deadline': 4.0,
#    'max_politeness': 4.25,
#    'task_time': 8,
#    'weighted_score': 4.045833333333333,
#    'common_availability': {1,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   12: {'team': [('Синеглазый', 'следопыт'), ('Фредерик', 'следопыт')],
#    'avg_quality': 4.178571428571429,
#    'avg_deadline': 3.8571428571428577,
#    'max_politeness': 3.857142857142857,
#    'task_time': 8,
#    'weighted_score': 4.017857142857143,
#    'common_availability': {1,
#     1079,
#     1080,
#     1081,
#     1082,
#     1083,
#     1084,
#     1085,
#     1086,
#     1087,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   13: {'team': [('Фредерик', 'следопыт'), ('Синеглазый', 'следопыт')],
#    'avg_quality': 4.178571428571429,
#    'avg_deadline': 3.857142857142857,
#    'max_politeness': 3.857142857142857,
#    'task_time': 8,
#    'weighted_score': 4.017857142857143,
#    'common_availability': {1,
#     1079,
#     1080,
#     1081,
#     1082,
#     1083,
#     1084,
#     1085,
#     1086,
#     1087,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   14: {'team': [('Бендер', 'следопыт'), ('Соня', 'следопыт')],
#    'avg_quality': 3.8666666666666663,
#    'avg_deadline': 4.2,
#    'max_politeness': 4.0,
#    'task_time': 8,
#    'weighted_score': 4.013333333333334,
#    'common_availability': {1,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   15: {'team': [('Соня', 'следопыт'), ('Бендер', 'следопыт')],
#    'avg_quality': 3.8666666666666667,
#    'avg_deadline': 4.2,
#    'max_politeness': 4.0,
#    'task_time': 8,
#    'weighted_score': 4.013333333333334,
#    'common_availability': {1,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   16: {'team': [('Соня', 'следопыт'), ('Агата', 'следопыт')],
#    'avg_quality': 3.9166666666666665,
#    'avg_deadline': 4.0,
#    'max_politeness': 4.5,
#    'task_time': 8,
#    'weighted_score': 4.008333333333334,
#    'common_availability': {1,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   17: {'team': [('Агата', 'следопыт'), ('Соня', 'следопыт')],
#    'avg_quality': 3.916666666666666,
#    'avg_deadline': 4.0,
#    'max_politeness': 4.5,
#    'task_time': 8,
#    'weighted_score': 4.008333333333333,
#    'common_availability': {1,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   18: {'team': [('Пастушок', 'следопыт'), ('Соня', 'следопыт')],
#    'avg_quality': 4.238095238095238,
#    'avg_deadline': 3.7857142857142856,
#    'max_politeness': 3.7142857142857144,
#    'task_time': 8,
#    'weighted_score': 4.004761904761905,
#    'common_availability': {1,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   19: {'team': [('Соня', 'следопыт'), ('Пастушок', 'следопыт')],
#    'avg_quality': 4.238095238095238,
#    'avg_deadline': 3.7857142857142856,
#    'max_politeness': 3.7142857142857144,
#    'task_time': 8,
#    'weighted_score': 4.004761904761905,
#    'common_availability': {1,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   20: {'team': [('Соня', 'следопыт'), ('Фредерик', 'следопыт')],
#    'avg_quality': 4.095238095238095,
#    'avg_deadline': 3.8571428571428577,
#    'max_politeness': 3.857142857142857,
#    'task_time': 8,
#    'weighted_score': 3.9761904761904763,
#    'common_availability': {1,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   21: {'team': [('Фредерик', 'следопыт'), ('Соня', 'следопыт')],
#    'avg_quality': 4.095238095238095,
#    'avg_deadline': 3.857142857142857,
#    'max_politeness': 3.857142857142857,
#    'task_time': 8,
#    'weighted_score': 3.976190476190476,
#    'common_availability': {1,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   22: {'team': [('Бенедикт', 'следопыт'), ('Синеглазый', 'следопыт')],
#    'avg_quality': 4.15,
#    'avg_deadline': 3.8,
#    'max_politeness': 3.75,
#    'task_time': 8,
#    'weighted_score': 3.97,
#    'common_availability': {1,
#     1070,
#     1071,
#     1072,
#     1073,
#     1074,
#     1075,
#     1076,
#     1077,
#     1078,
#     1079,
#     1080,
#     1081,
#     1082,
#     1083,
#     1084,
#     1085,
#     1086,
#     1087,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   23: {'team': [('Синеглазый', 'следопыт'), ('Бенедикт', 'следопыт')],
#    'avg_quality': 4.15,
#    'avg_deadline': 3.8,
#    'max_politeness': 3.75,
#    'task_time': 8,
#    'weighted_score': 3.97,
#    'common_availability': {1,
#     1070,
#     1071,
#     1072,
#     1073,
#     1074,
#     1075,
#     1076,
#     1077,
#     1078,
#     1079,
#     1080,
#     1081,
#     1082,
#     1083,
#     1084,
#     1085,
#     1086,
#     1087,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   24: {'team': [('Синеглазый', 'следопыт'), ('Юлия', 'следопыт')],
#    'avg_quality': 4.5,
#    'avg_deadline': 3.25,
#    'max_politeness': 4.0,
#    'task_time': 10,
#    'weighted_score': 3.9499999999999997,
#    'common_availability': {1,
#     1070,
#     1071,
#     1072,
#     1073,
#     1074,
#     1075,
#     1076,
#     1077,
#     1078,
#     1079,
#     1080,
#     1081,
#     1082,
#     1083,
#     1084,
#     1085,
#     1086,
#     1087,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   25: {'team': [('Юлия', 'следопыт'), ('Синеглазый', 'следопыт')],
#    'avg_quality': 4.5,
#    'avg_deadline': 3.25,
#    'max_politeness': 4.0,
#    'task_time': 10,
#    'weighted_score': 3.9499999999999997,
#    'common_availability': {1,
#     1070,
#     1071,
#     1072,
#     1073,
#     1074,
#     1075,
#     1076,
#     1077,
#     1078,
#     1079,
#     1080,
#     1081,
#     1082,
#     1083,
#     1084,
#     1085,
#     1086,
#     1087,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   26: {'team': [('Бенедикт', 'следопыт'), ('Соня', 'следопыт')],
#    'avg_quality': 4.066666666666666,
#    'avg_deadline': 3.8,
#    'max_politeness': 3.6666666666666665,
#    'task_time': 8,
#    'weighted_score': 3.92,
#    'common_availability': {1,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   27: {'team': [('Соня', 'следопыт'), ('Бенедикт', 'следопыт')],
#    'avg_quality': 4.066666666666666,
#    'avg_deadline': 3.8,
#    'max_politeness': 3.6666666666666665,
#    'task_time': 8,
#    'weighted_score': 3.92,
#    'common_availability': {1,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   28: {'team': [('Мартин', 'следопыт'), ('Пастушок', 'следопыт')],
#    'avg_quality': 3.946428571428571,
#    'avg_deadline': 3.7857142857142856,
#    'max_politeness': 4.25,
#    'task_time': 8,
#    'weighted_score': 3.9124999999999996,
#    'common_availability': {1,
#     1083,
#     1084,
#     1085,
#     1086,
#     1087,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   29: {'team': [('Пастушок', 'следопыт'), ('Мартин', 'следопыт')],
#    'avg_quality': 3.9464285714285716,
#    'avg_deadline': 3.7857142857142856,
#    'max_politeness': 4.25,
#    'task_time': 8,
#    'weighted_score': 3.9124999999999996,
#    'common_availability': {1,
#     1083,
#     1084,
#     1085,
#     1086,
#     1087,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   30: {'team': [('Соня', 'следопыт'), ('Юлия', 'следопыт')],
#    'avg_quality': 4.416666666666666,
#    'avg_deadline': 3.25,
#    'max_politeness': 4.0,
#    'task_time': 10,
#    'weighted_score': 3.9083333333333328,
#    'common_availability': {1,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   31: {'team': [('Юлия', 'следопыт'), ('Соня', 'следопыт')],
#    'avg_quality': 4.416666666666666,
#    'avg_deadline': 3.25,
#    'max_politeness': 4.0,
#    'task_time': 10,
#    'weighted_score': 3.9083333333333328,
#    'common_availability': {1,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   32: {'team': [('Бендер', 'следопыт'), ('Мартин', 'следопыт')],
#    'avg_quality': 3.575,
#    'avg_deadline': 4.2,
#    'max_politeness': 4.25,
#    'task_time': 8,
#    'weighted_score': 3.8925,
#    'common_availability': {1,
#     1036,
#     1037,
#     1038,
#     1039,
#     1040,
#     1041,
#     1042,
#     1043,
#     1044,
#     1045,
#     1046,
#     1047,
#     1048,
#     1049,
#     1050,
#     1051,
#     1052,
#     1053,
#     1054,
#     1055,
#     1056,
#     1057,
#     1058,
#     1059,
#     1060,
#     1061,
#     1062,
#     1063,
#     1064,
#     1065,
#     1066,
#     1067,
#     1068,
#     1069,
#     1070,
#     1071,
#     1072,
#     1073,
#     1074,
#     1075,
#     1076,
#     1077,
#     1078,
#     1079,
#     1080,
#     1081,
#     1082,
#     1083,
#     1084,
#     1085,
#     1086,
#     1087,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   33: {'team': [('Мартин', 'следопыт'), ('Бендер', 'следопыт')],
#    'avg_quality': 3.575,
#    'avg_deadline': 4.2,
#    'max_politeness': 4.25,
#    'task_time': 8,
#    'weighted_score': 3.8925,
#    'common_availability': {1,
#     1036,
#     1037,
#     1038,
#     1039,
#     1040,
#     1041,
#     1042,
#     1043,
#     1044,
#     1045,
#     1046,
#     1047,
#     1048,
#     1049,
#     1050,
#     1051,
#     1052,
#     1053,
#     1054,
#     1055,
#     1056,
#     1057,
#     1058,
#     1059,
#     1060,
#     1061,
#     1062,
#     1063,
#     1064,
#     1065,
#     1066,
#     1067,
#     1068,
#     1069,
#     1070,
#     1071,
#     1072,
#     1073,
#     1074,
#     1075,
#     1076,
#     1077,
#     1078,
#     1079,
#     1080,
#     1081,
#     1082,
#     1083,
#     1084,
#     1085,
#     1086,
#     1087,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   34: {'team': [('Леопольд', 'следопыт'), ('Синеглазый', 'следопыт')],
#    'avg_quality': 4.083333333333333,
#    'avg_deadline': 3.666666666666667,
#    'max_politeness': 3.8333333333333335,
#    'task_time': 9,
#    'weighted_score': 3.8916666666666666,
#    'common_availability': {1,
#     1070,
#     1071,
#     1072,
#     1073,
#     1074,
#     1075,
#     1076,
#     1077,
#     1078,
#     1079,
#     1080,
#     1081,
#     1082,
#     1083,
#     1084,
#     1085,
#     1086,
#     1087,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   35: {'team': [('Синеглазый', 'следопыт'), ('Леопольд', 'следопыт')],
#    'avg_quality': 4.083333333333333,
#    'avg_deadline': 3.666666666666667,
#    'max_politeness': 3.8333333333333335,
#    'task_time': 9,
#    'weighted_score': 3.8916666666666666,
#    'common_availability': {1,
#     1070,
#     1071,
#     1072,
#     1073,
#     1074,
#     1075,
#     1076,
#     1077,
#     1078,
#     1079,
#     1080,
#     1081,
#     1082,
#     1083,
#     1084,
#     1085,
#     1086,
#     1087,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   36: {'team': [('Пастушок', 'следопыт'), ('Бендер', 'следопыт')],
#    'avg_quality': 3.771428571428572,
#    'avg_deadline': 3.985714285714286,
#    'max_politeness': 4.0,
#    'task_time': 8,
#    'weighted_score': 3.8800000000000003,
#    'common_availability': {1,
#     1083,
#     1084,
#     1085,
#     1086,
#     1087,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   37: {'team': [('Бендер', 'следопыт'), ('Пастушок', 'следопыт')],
#    'avg_quality': 3.7714285714285714,
#    'avg_deadline': 3.9857142857142858,
#    'max_politeness': 4.0,
#    'task_time': 8,
#    'weighted_score': 3.88,
#    'common_availability': {1,
#     1083,
#     1084,
#     1085,
#     1086,
#     1087,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   38: {'team': [('Агата', 'следопыт'), ('Пастушок', 'следопыт')],
#    'avg_quality': 3.821428571428571,
#    'avg_deadline': 3.7857142857142856,
#    'max_politeness': 4.5,
#    'task_time': 8,
#    'weighted_score': 3.875,
#    'common_availability': {1,
#     1083,
#     1084,
#     1085,
#     1086,
#     1087,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   39: {'team': [('Пастушок', 'следопыт'), ('Агата', 'следопыт')],
#    'avg_quality': 3.8214285714285716,
#    'avg_deadline': 3.7857142857142856,
#    'max_politeness': 4.5,
#    'task_time': 8,
#    'weighted_score': 3.875,
#    'common_availability': {1,
#     1083,
#     1084,
#     1085,
#     1086,
#     1087,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   40: {'team': [('Мартин', 'следопыт'), ('Фредерик', 'следопыт')],
#    'avg_quality': 3.803571428571429,
#    'avg_deadline': 3.8571428571428577,
#    'max_politeness': 4.25,
#    'task_time': 8,
#    'weighted_score': 3.869642857142858,
#    'common_availability': {1,
#     1079,
#     1080,
#     1081,
#     1082,
#     1083,
#     1084,
#     1085,
#     1086,
#     1087,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   41: {'team': [('Фредерик', 'следопыт'), ('Мартин', 'следопыт')],
#    'avg_quality': 3.803571428571429,
#    'avg_deadline': 3.857142857142857,
#    'max_politeness': 4.25,
#    'task_time': 8,
#    'weighted_score': 3.869642857142857,
#    'common_availability': {1,
#     1079,
#     1080,
#     1081,
#     1082,
#     1083,
#     1084,
#     1085,
#     1086,
#     1087,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   42: {'team': [('Агата', 'следопыт'), ('Мартин', 'следопыт')],
#    'avg_quality': 3.625,
#    'avg_deadline': 4.0,
#    'max_politeness': 4.5,
#    'task_time': 8,
#    'weighted_score': 3.8625000000000003,
#    'common_availability': {1,
#     1055,
#     1056,
#     1057,
#     1058,
#     1059,
#     1060,
#     1061,
#     1062,
#     1063,
#     1064,
#     1065,
#     1066,
#     1067,
#     1068,
#     1069,
#     1070,
#     1071,
#     1072,
#     1073,
#     1074,
#     1075,
#     1076,
#     1077,
#     1078,
#     1079,
#     1080,
#     1081,
#     1082,
#     1083,
#     1084,
#     1085,
#     1086,
#     1087,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   43: {'team': [('Мартин', 'следопыт'), ('Агата', 'следопыт')],
#    'avg_quality': 3.625,
#    'avg_deadline': 4.0,
#    'max_politeness': 4.5,
#    'task_time': 8,
#    'weighted_score': 3.8625000000000003,
#    'common_availability': {1,
#     1055,
#     1056,
#     1057,
#     1058,
#     1059,
#     1060,
#     1061,
#     1062,
#     1063,
#     1064,
#     1065,
#     1066,
#     1067,
#     1068,
#     1069,
#     1070,
#     1071,
#     1072,
#     1073,
#     1074,
#     1075,
#     1076,
#     1077,
#     1078,
#     1079,
#     1080,
#     1081,
#     1082,
#     1083,
#     1084,
#     1085,
#     1086,
#     1087,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   44: {'team': [('Агата', 'следопыт'), ('Бендер', 'следопыт')],
#    'avg_quality': 3.45,
#    'avg_deadline': 4.2,
#    'max_politeness': 4.5,
#    'task_time': 8,
#    'weighted_score': 3.8550000000000004,
#    'common_availability': {1,
#     1055,
#     1056,
#     1057,
#     1058,
#     1059,
#     1060,
#     1061,
#     1062,
#     1063,
#     1064,
#     1065,
#     1066,
#     1067,
#     1068,
#     1069,
#     1070,
#     1071,
#     1072,
#     1073,
#     1074,
#     1075,
#     1076,
#     1077,
#     1078,
#     1079,
#     1080,
#     1081,
#     1082,
#     1083,
#     1084,
#     1085,
#     1086,
#     1087,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   45: {'team': [('Бендер', 'следопыт'), ('Агата', 'следопыт')],
#    'avg_quality': 3.45,
#    'avg_deadline': 4.2,
#    'max_politeness': 4.5,
#    'task_time': 8,
#    'weighted_score': 3.8550000000000004,
#    'common_availability': {1,
#     1055,
#     1056,
#     1057,
#     1058,
#     1059,
#     1060,
#     1061,
#     1062,
#     1063,
#     1064,
#     1065,
#     1066,
#     1067,
#     1068,
#     1069,
#     1070,
#     1071,
#     1072,
#     1073,
#     1074,
#     1075,
#     1076,
#     1077,
#     1078,
#     1079,
#     1080,
#     1081,
#     1082,
#     1083,
#     1084,
#     1085,
#     1086,
#     1087,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   46: {'team': [('Леопольд', 'следопыт'), ('Соня', 'следопыт')],
#    'avg_quality': 4.0,
#    'avg_deadline': 3.666666666666667,
#    'max_politeness': 3.8333333333333335,
#    'task_time': 9,
#    'weighted_score': 3.85,
#    'common_availability': {1,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   47: {'team': [('Соня', 'следопыт'), ('Леопольд', 'следопыт')],
#    'avg_quality': 3.9999999999999996,
#    'avg_deadline': 3.666666666666667,
#    'max_politeness': 3.8333333333333335,
#    'task_time': 9,
#    'weighted_score': 3.85,
#    'common_availability': {1,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   48: {'team': [('Пастушок', 'следопыт'), ('Фредерик', 'следопыт')],
#    'avg_quality': 4.0,
#    'avg_deadline': 3.6428571428571432,
#    'max_politeness': 3.857142857142857,
#    'task_time': 9,
#    'weighted_score': 3.842857142857143,
#    'common_availability': {1,
#     1083,
#     1084,
#     1085,
#     1086,
#     1087,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   49: {'team': [('Фредерик', 'следопыт'), ('Пастушок', 'следопыт')],
#    'avg_quality': 4.0,
#    'avg_deadline': 3.642857142857143,
#    'max_politeness': 3.857142857142857,
#    'task_time': 9,
#    'weighted_score': 3.842857142857143,
#    'common_availability': {1,
#     1083,
#     1084,
#     1085,
#     1086,
#     1087,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   50: {'team': [('Бендер', 'следопыт'), ('Фредерик', 'следопыт')],
#    'avg_quality': 3.6285714285714286,
#    'avg_deadline': 4.057142857142858,
#    'max_politeness': 4.0,
#    'task_time': 8,
#    'weighted_score': 3.8371428571428576,
#    'common_availability': {1,
#     1079,
#     1080,
#     1081,
#     1082,
#     1083,
#     1084,
#     1085,
#     1086,
#     1087,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   51: {'team': [('Фредерик', 'следопыт'), ('Бендер', 'следопыт')],
#    'avg_quality': 3.6285714285714286,
#    'avg_deadline': 4.057142857142857,
#    'max_politeness': 4.0,
#    'task_time': 8,
#    'weighted_score': 3.8371428571428567,
#    'common_availability': {1,
#     1079,
#     1080,
#     1081,
#     1082,
#     1083,
#     1084,
#     1085,
#     1086,
#     1087,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   52: {'team': [('Мартин', 'следопыт'), ('Бенедикт', 'следопыт')],
#    'avg_quality': 3.7750000000000004,
#    'avg_deadline': 3.8,
#    'max_politeness': 4.25,
#    'task_time': 8,
#    'weighted_score': 3.8325000000000005,
#    'common_availability': {1,
#     1023,
#     1024,
#     1025,
#     1026,
#     1027,
#     1028,
#     1029,
#     1030,
#     1031,
#     1032,
#     1033,
#     1034,
#     1035,
#     1036,
#     1037,
#     1038,
#     1039,
#     1040,
#     1041,
#     1042,
#     1043,
#     1044,
#     1045,
#     1046,
#     1047,
#     1048,
#     1049,
#     1050,
#     1051,
#     1052,
#     1053,
#     1054,
#     1055,
#     1056,
#     1057,
#     1058,
#     1059,
#     1060,
#     1061,
#     1062,
#     1063,
#     1064,
#     1065,
#     1066,
#     1067,
#     1068,
#     1069,
#     1070,
#     1071,
#     1072,
#     1073,
#     1074,
#     1075,
#     1076,
#     1077,
#     1078,
#     1079,
#     1080,
#     1081,
#     1082,
#     1083,
#     1084,
#     1085,
#     1086,
#     1087,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   53: {'team': [('Бенедикт', 'следопыт'), ('Мартин', 'следопыт')],
#    'avg_quality': 3.775,
#    'avg_deadline': 3.8,
#    'max_politeness': 4.25,
#    'task_time': 8,
#    'weighted_score': 3.8324999999999996,
#    'common_availability': {1,
#     1023,
#     1024,
#     1025,
#     1026,
#     1027,
#     1028,
#     1029,
#     1030,
#     1031,
#     1032,
#     1033,
#     1034,
#     1035,
#     1036,
#     1037,
#     1038,
#     1039,
#     1040,
#     1041,
#     1042,
#     1043,
#     1044,
#     1045,
#     1046,
#     1047,
#     1048,
#     1049,
#     1050,
#     1051,
#     1052,
#     1053,
#     1054,
#     1055,
#     1056,
#     1057,
#     1058,
#     1059,
#     1060,
#     1061,
#     1062,
#     1063,
#     1064,
#     1065,
#     1066,
#     1067,
#     1068,
#     1069,
#     1070,
#     1071,
#     1072,
#     1073,
#     1074,
#     1075,
#     1076,
#     1077,
#     1078,
#     1079,
#     1080,
#     1081,
#     1082,
#     1083,
#     1084,
#     1085,
#     1086,
#     1087,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   54: {'team': [('Агата', 'следопыт'), ('Фредерик', 'следопыт')],
#    'avg_quality': 3.678571428571429,
#    'avg_deadline': 3.8571428571428577,
#    'max_politeness': 4.5,
#    'task_time': 8,
#    'weighted_score': 3.8321428571428577,
#    'common_availability': {1,
#     1079,
#     1080,
#     1081,
#     1082,
#     1083,
#     1084,
#     1085,
#     1086,
#     1087,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   55: {'team': [('Фредерик', 'следопыт'), ('Агата', 'следопыт')],
#    'avg_quality': 3.678571428571429,
#    'avg_deadline': 3.857142857142857,
#    'max_politeness': 4.5,
#    'task_time': 8,
#    'weighted_score': 3.8321428571428573,
#    'common_availability': {1,
#     1079,
#     1080,
#     1081,
#     1082,
#     1083,
#     1084,
#     1085,
#     1086,
#     1087,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   56: {'team': [('Альфред', 'следопыт'), ('Синеглазый', 'следопыт')],
#    'avg_quality': 3.916666666666667,
#    'avg_deadline': 3.666666666666667,
#    'max_politeness': 4.0,
#    'task_time': 9,
#    'weighted_score': 3.825,
#    'common_availability': {1,
#     1070,
#     1071,
#     1072,
#     1073,
#     1074,
#     1075,
#     1076,
#     1077,
#     1078,
#     1079,
#     1080,
#     1081,
#     1082,
#     1083,
#     1084,
#     1085,
#     1086,
#     1087,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   57: {'team': [('Синеглазый', 'следопыт'), ('Альфред', 'следопыт')],
#    'avg_quality': 3.916666666666667,
#    'avg_deadline': 3.666666666666667,
#    'max_politeness': 4.0,
#    'task_time': 9,
#    'weighted_score': 3.825,
#    'common_availability': {1,
#     1070,
#     1071,
#     1072,
#     1073,
#     1074,
#     1075,
#     1076,
#     1077,
#     1078,
#     1079,
#     1080,
#     1081,
#     1082,
#     1083,
#     1084,
#     1085,
#     1086,
#     1087,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   58: {'team': [('Бенедикт', 'следопыт'), ('Бендер', 'следопыт')],
#    'avg_quality': 3.6,
#    'avg_deadline': 4.0,
#    'max_politeness': 4.0,
#    'task_time': 8,
#    'weighted_score': 3.8000000000000003,
#    'common_availability': {1,
#     1036,
#     1037,
#     1038,
#     1039,
#     1040,
#     1041,
#     1042,
#     1043,
#     1044,
#     1045,
#     1046,
#     1047,
#     1048,
#     1049,
#     1050,
#     1051,
#     1052,
#     1053,
#     1054,
#     1055,
#     1056,
#     1057,
#     1058,
#     1059,
#     1060,
#     1061,
#     1062,
#     1063,
#     1064,
#     1065,
#     1066,
#     1067,
#     1068,
#     1069,
#     1070,
#     1071,
#     1072,
#     1073,
#     1074,
#     1075,
#     1076,
#     1077,
#     1078,
#     1079,
#     1080,
#     1081,
#     1082,
#     1083,
#     1084,
#     1085,
#     1086,
#     1087,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   59: {'team': [('Бендер', 'следопыт'), ('Бенедикт', 'следопыт')],
#    'avg_quality': 3.5999999999999996,
#    'avg_deadline': 4.0,
#    'max_politeness': 4.0,
#    'task_time': 8,
#    'weighted_score': 3.8,
#    'common_availability': {1,
#     1036,
#     1037,
#     1038,
#     1039,
#     1040,
#     1041,
#     1042,
#     1043,
#     1044,
#     1045,
#     1046,
#     1047,
#     1048,
#     1049,
#     1050,
#     1051,
#     1052,
#     1053,
#     1054,
#     1055,
#     1056,
#     1057,
#     1058,
#     1059,
#     1060,
#     1061,
#     1062,
#     1063,
#     1064,
#     1065,
#     1066,
#     1067,
#     1068,
#     1069,
#     1070,
#     1071,
#     1072,
#     1073,
#     1074,
#     1075,
#     1076,
#     1077,
#     1078,
#     1079,
#     1080,
#     1081,
#     1082,
#     1083,
#     1084,
#     1085,
#     1086,
#     1087,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   60: {'team': [('Агата', 'следопыт'), ('Бенедикт', 'следопыт')],
#    'avg_quality': 3.6500000000000004,
#    'avg_deadline': 3.8,
#    'max_politeness': 4.5,
#    'task_time': 8,
#    'weighted_score': 3.7950000000000004,
#    'common_availability': {1,
#     1055,
#     1056,
#     1057,
#     1058,
#     1059,
#     1060,
#     1061,
#     1062,
#     1063,
#     1064,
#     1065,
#     1066,
#     1067,
#     1068,
#     1069,
#     1070,
#     1071,
#     1072,
#     1073,
#     1074,
#     1075,
#     1076,
#     1077,
#     1078,
#     1079,
#     1080,
#     1081,
#     1082,
#     1083,
#     1084,
#     1085,
#     1086,
#     1087,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   61: {'team': [('Бенедикт', 'следопыт'), ('Агата', 'следопыт')],
#    'avg_quality': 3.65,
#    'avg_deadline': 3.8,
#    'max_politeness': 4.5,
#    'task_time': 8,
#    'weighted_score': 3.795,
#    'common_availability': {1,
#     1055,
#     1056,
#     1057,
#     1058,
#     1059,
#     1060,
#     1061,
#     1062,
#     1063,
#     1064,
#     1065,
#     1066,
#     1067,
#     1068,
#     1069,
#     1070,
#     1071,
#     1072,
#     1073,
#     1074,
#     1075,
#     1076,
#     1077,
#     1078,
#     1079,
#     1080,
#     1081,
#     1082,
#     1083,
#     1084,
#     1085,
#     1086,
#     1087,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   62: {'team': [('Бенедикт', 'следопыт'), ('Пастушок', 'следопыт')],
#    'avg_quality': 3.9714285714285715,
#    'avg_deadline': 3.585714285714286,
#    'max_politeness': 3.7142857142857144,
#    'task_time': 9,
#    'weighted_score': 3.7914285714285714,
#    'common_availability': {1,
#     1083,
#     1084,
#     1085,
#     1086,
#     1087,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   63: {'team': [('Пастушок', 'следопыт'), ('Бенедикт', 'следопыт')],
#    'avg_quality': 3.9714285714285715,
#    'avg_deadline': 3.585714285714286,
#    'max_politeness': 3.7142857142857144,
#    'task_time': 9,
#    'weighted_score': 3.7914285714285714,
#    'common_availability': {1,
#     1083,
#     1084,
#     1085,
#     1086,
#     1087,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   64: {'team': [('Мартин', 'следопыт'), ('Юлия', 'следопыт')],
#    'avg_quality': 4.125,
#    'avg_deadline': 3.25,
#    'max_politeness': 4.25,
#    'task_time': 10,
#    'weighted_score': 3.7874999999999996,
#    'common_availability': {1,
#     1050,
#     1051,
#     1052,
#     1053,
#     1054,
#     1055,
#     1056,
#     1057,
#     1058,
#     1059,
#     1060,
#     1061,
#     1062,
#     1063,
#     1064,
#     1065,
#     1066,
#     1067,
#     1068,
#     1069,
#     1070,
#     1071,
#     1072,
#     1073,
#     1074,
#     1075,
#     1076,
#     1077,
#     1078,
#     1079,
#     1080,
#     1081,
#     1082,
#     1083,
#     1084,
#     1085,
#     1086,
#     1087,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   65: {'team': [('Юлия', 'следопыт'), ('Мартин', 'следопыт')],
#    'avg_quality': 4.125,
#    'avg_deadline': 3.25,
#    'max_politeness': 4.25,
#    'task_time': 10,
#    'weighted_score': 3.7874999999999996,
#    'common_availability': {1,
#     1050,
#     1051,
#     1052,
#     1053,
#     1054,
#     1055,
#     1056,
#     1057,
#     1058,
#     1059,
#     1060,
#     1061,
#     1062,
#     1063,
#     1064,
#     1065,
#     1066,
#     1067,
#     1068,
#     1069,
#     1070,
#     1071,
#     1072,
#     1073,
#     1074,
#     1075,
#     1076,
#     1077,
#     1078,
#     1079,
#     1080,
#     1081,
#     1082,
#     1083,
#     1084,
#     1085,
#     1086,
#     1087,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   66: {'team': [('Соня', 'следопыт'), ('Альфред', 'следопыт')],
#    'avg_quality': 3.8333333333333335,
#    'avg_deadline': 3.666666666666667,
#    'max_politeness': 4.0,
#    'task_time': 9,
#    'weighted_score': 3.7833333333333337,
#    'common_availability': {1,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   67: {'team': [('Альфред', 'следопыт'), ('Соня', 'следопыт')],
#    'avg_quality': 3.833333333333333,
#    'avg_deadline': 3.666666666666667,
#    'max_politeness': 4.0,
#    'task_time': 9,
#    'weighted_score': 3.783333333333333,
#    'common_availability': {1,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   68: {'team': [('Пастушок', 'следопыт'), ('Юлия', 'следопыт')],
#    'avg_quality': 4.321428571428571,
#    'avg_deadline': 3.0357142857142856,
#    'max_politeness': 4.0,
#    'task_time': 10,
#    'weighted_score': 3.775,
#    'common_availability': {1,
#     1083,
#     1084,
#     1085,
#     1086,
#     1087,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   69: {'team': [('Юлия', 'следопыт'), ('Пастушок', 'следопыт')],
#    'avg_quality': 4.321428571428571,
#    'avg_deadline': 3.0357142857142856,
#    'max_politeness': 4.0,
#    'task_time': 10,
#    'weighted_score': 3.775,
#    'common_availability': {1,
#     1083,
#     1084,
#     1085,
#     1086,
#     1087,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   70: {'team': [('Бенедикт', 'следопыт'), ('Фредерик', 'следопыт')],
#    'avg_quality': 3.8285714285714287,
#    'avg_deadline': 3.6571428571428575,
#    'max_politeness': 3.857142857142857,
#    'task_time': 9,
#    'weighted_score': 3.762857142857143,
#    'common_availability': {1,
#     1079,
#     1080,
#     1081,
#     1082,
#     1083,
#     1084,
#     1085,
#     1086,
#     1087,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   71: {'team': [('Фредерик', 'следопыт'), ('Бенедикт', 'следопыт')],
#    'avg_quality': 3.8285714285714283,
#    'avg_deadline': 3.657142857142857,
#    'max_politeness': 3.857142857142857,
#    'task_time': 9,
#    'weighted_score': 3.762857142857143,
#    'common_availability': {1,
#     1079,
#     1080,
#     1081,
#     1082,
#     1083,
#     1084,
#     1085,
#     1086,
#     1087,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   72: {'team': [('Бендер', 'следопыт'), ('Юлия', 'следопыт')],
#    'avg_quality': 3.95,
#    'avg_deadline': 3.45,
#    'max_politeness': 4.0,
#    'task_time': 9,
#    'weighted_score': 3.7550000000000003,
#    'common_availability': {1,
#     1050,
#     1051,
#     1052,
#     1053,
#     1054,
#     1055,
#     1056,
#     1057,
#     1058,
#     1059,
#     1060,
#     1061,
#     1062,
#     1063,
#     1064,
#     1065,
#     1066,
#     1067,
#     1068,
#     1069,
#     1070,
#     1071,
#     1072,
#     1073,
#     1074,
#     1075,
#     1076,
#     1077,
#     1078,
#     1079,
#     1080,
#     1081,
#     1082,
#     1083,
#     1084,
#     1085,
#     1086,
#     1087,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   73: {'team': [('Юлия', 'следопыт'), ('Бендер', 'следопыт')],
#    'avg_quality': 3.95,
#    'avg_deadline': 3.45,
#    'max_politeness': 4.0,
#    'task_time': 9,
#    'weighted_score': 3.7550000000000003,
#    'common_availability': {1,
#     1050,
#     1051,
#     1052,
#     1053,
#     1054,
#     1055,
#     1056,
#     1057,
#     1058,
#     1059,
#     1060,
#     1061,
#     1062,
#     1063,
#     1064,
#     1065,
#     1066,
#     1067,
#     1068,
#     1069,
#     1070,
#     1071,
#     1072,
#     1073,
#     1074,
#     1075,
#     1076,
#     1077,
#     1078,
#     1079,
#     1080,
#     1081,
#     1082,
#     1083,
#     1084,
#     1085,
#     1086,
#     1087,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   74: {'team': [('Агата', 'следопыт'), ('Юлия', 'следопыт')],
#    'avg_quality': 4.0,
#    'avg_deadline': 3.25,
#    'max_politeness': 4.5,
#    'task_time': 10,
#    'weighted_score': 3.75,
#    'common_availability': {1,
#     1055,
#     1056,
#     1057,
#     1058,
#     1059,
#     1060,
#     1061,
#     1062,
#     1063,
#     1064,
#     1065,
#     1066,
#     1067,
#     1068,
#     1069,
#     1070,
#     1071,
#     1072,
#     1073,
#     1074,
#     1075,
#     1076,
#     1077,
#     1078,
#     1079,
#     1080,
#     1081,
#     1082,
#     1083,
#     1084,
#     1085,
#     1086,
#     1087,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   75: {'team': [('Юлия', 'следопыт'), ('Агата', 'следопыт')],
#    'avg_quality': 4.0,
#    'avg_deadline': 3.25,
#    'max_politeness': 4.5,
#    'task_time': 10,
#    'weighted_score': 3.75,
#    'common_availability': {1,
#     1055,
#     1056,
#     1057,
#     1058,
#     1059,
#     1060,
#     1061,
#     1062,
#     1063,
#     1064,
#     1065,
#     1066,
#     1067,
#     1068,
#     1069,
#     1070,
#     1071,
#     1072,
#     1073,
#     1074,
#     1075,
#     1076,
#     1077,
#     1078,
#     1079,
#     1080,
#     1081,
#     1082,
#     1083,
#     1084,
#     1085,
#     1086,
#     1087,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   76: {'team': [('Леопольд', 'следопыт'), ('Мартин', 'следопыт')],
#    'avg_quality': 3.708333333333333,
#    'avg_deadline': 3.666666666666667,
#    'max_politeness': 4.25,
#    'task_time': 9,
#    'weighted_score': 3.7458333333333336,
#    'common_availability': {1,
#     1046,
#     1047,
#     1048,
#     1049,
#     1050,
#     1051,
#     1052,
#     1053,
#     1054,
#     1055,
#     1056,
#     1057,
#     1058,
#     1059,
#     1060,
#     1061,
#     1062,
#     1063,
#     1064,
#     1065,
#     1066,
#     1067,
#     1068,
#     1069,
#     1070,
#     1071,
#     1072,
#     1073,
#     1074,
#     1075,
#     1076,
#     1077,
#     1078,
#     1079,
#     1080,
#     1081,
#     1082,
#     1083,
#     1084,
#     1085,
#     1086,
#     1087,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   77: {'team': [('Мартин', 'следопыт'), ('Леопольд', 'следопыт')],
#    'avg_quality': 3.708333333333333,
#    'avg_deadline': 3.666666666666667,
#    'max_politeness': 4.25,
#    'task_time': 9,
#    'weighted_score': 3.7458333333333336,
#    'common_availability': {1,
#     1046,
#     1047,
#     1048,
#     1049,
#     1050,
#     1051,
#     1052,
#     1053,
#     1054,
#     1055,
#     1056,
#     1057,
#     1058,
#     1059,
#     1060,
#     1061,
#     1062,
#     1063,
#     1064,
#     1065,
#     1066,
#     1067,
#     1068,
#     1069,
#     1070,
#     1071,
#     1072,
#     1073,
#     1074,
#     1075,
#     1076,
#     1077,
#     1078,
#     1079,
#     1080,
#     1081,
#     1082,
#     1083,
#     1084,
#     1085,
#     1086,
#     1087,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   78: {'team': [('Фредерик', 'следопыт'), ('Юлия', 'следопыт')],
#    'avg_quality': 4.178571428571429,
#    'avg_deadline': 3.107142857142857,
#    'max_politeness': 4.0,
#    'task_time': 10,
#    'weighted_score': 3.732142857142857,
#    'common_availability': {1,
#     1079,
#     1080,
#     1081,
#     1082,
#     1083,
#     1084,
#     1085,
#     1086,
#     1087,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   79: {'team': [('Юлия', 'следопыт'), ('Фредерик', 'следопыт')],
#    'avg_quality': 4.178571428571429,
#    'avg_deadline': 3.1071428571428577,
#    'max_politeness': 4.0,
#    'task_time': 10,
#    'weighted_score': 3.732142857142857,
#    'common_availability': {1,
#     1079,
#     1080,
#     1081,
#     1082,
#     1083,
#     1084,
#     1085,
#     1086,
#     1087,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   80: {'team': [('Леопольд', 'следопыт'), ('Пастушок', 'следопыт')],
#    'avg_quality': 3.904761904761905,
#    'avg_deadline': 3.4523809523809526,
#    'max_politeness': 3.8333333333333335,
#    'task_time': 9,
#    'weighted_score': 3.7166666666666672,
#    'common_availability': {1,
#     1083,
#     1084,
#     1085,
#     1086,
# ...
#     1087,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   90: {'team': [('Альфред', 'следопыт'), ('Мартин', 'следопыт')],
#    'avg_quality': 3.541666666666667,
#    'avg_deadline': 3.666666666666667,
#    'max_politeness': 4.25,
#    'task_time': 9,
#    'weighted_score': 3.6625000000000005,
#    'common_availability': {1,
#     1044,
#     1045,
#     1046,
#     1047,
#     1048,
#     1049,
#     1050,
#     1051,
#     1052,
#     1053,
#     1054,
#     1055,
#     1056,
#     1057,
#     1058,
#     1059,
#     1060,
#     1061,
#     1062,
#     1063,
#     1064,
#     1065,
#     1066,
#     1067,
#     1068,
#     1069,
#     1070,
#     1071,
#     1072,
#     1073,
#     1074,
#     1075,
#     1076,
#     1077,
#     1078,
#     1079,
#     1080,
#     1081,
#     1082,
#     1083,
#     1084,
#     1085,
#     1086,
#     1087,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   91: {'team': [('Мартин', 'следопыт'), ('Альфред', 'следопыт')],
#    'avg_quality': 3.541666666666667,
#    'avg_deadline': 3.666666666666667,
#    'max_politeness': 4.25,
#    'task_time': 9,
#    'weighted_score': 3.6625000000000005,
#    'common_availability': {1,
#     1044,
#     1045,
#     1046,
#     1047,
#     1048,
#     1049,
#     1050,
#     1051,
#     1052,
#     1053,
#     1054,
#     1055,
#     1056,
#     1057,
#     1058,
#     1059,
#     1060,
#     1061,
#     1062,
#     1063,
#     1064,
#     1065,
#     1066,
#     1067,
#     1068,
#     1069,
#     1070,
#     1071,
#     1072,
#     1073,
#     1074,
#     1075,
#     1076,
#     1077,
#     1078,
#     1079,
#     1080,
#     1081,
#     1082,
#     1083,
#     1084,
#     1085,
#     1086,
#     1087,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   92: {'team': [('Пастушок', 'следопыт'), ('Альфред', 'следопыт')],
#    'avg_quality': 3.7380952380952386,
#    'avg_deadline': 3.4523809523809526,
#    'max_politeness': 4.0,
#    'task_time': 9,
#    'weighted_score': 3.6500000000000004,
#    'common_availability': {1,
#     1083,
#     1084,
#     1085,
#     1086,
#     1087,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   93: {'team': [('Альфред', 'следопыт'), ('Пастушок', 'следопыт')],
#    'avg_quality': 3.738095238095238,
#    'avg_deadline': 3.4523809523809526,
#    'max_politeness': 4.0,
#    'task_time': 9,
#    'weighted_score': 3.65,
#    'common_availability': {1,
#     1083,
#     1084,
#     1085,
#     1086,
#     1087,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   94: {'team': [('Леопольд', 'следопыт'), ('Бенедикт', 'следопыт')],
#    'avg_quality': 3.7333333333333334,
#    'avg_deadline': 3.466666666666667,
#    'max_politeness': 3.8333333333333335,
#    'task_time': 9,
#    'weighted_score': 3.6366666666666667,
#    'common_availability': {1,
#     1046,
#     1047,
#     1048,
#     1049,
#     1050,
#     1051,
#     1052,
#     1053,
#     1054,
#     1055,
#     1056,
#     1057,
#     1058,
#     1059,
#     1060,
#     1061,
#     1062,
#     1063,
#     1064,
#     1065,
#     1066,
#     1067,
#     1068,
#     1069,
#     1070,
#     1071,
#     1072,
#     1073,
#     1074,
#     1075,
#     1076,
#     1077,
#     1078,
#     1079,
#     1080,
#     1081,
#     1082,
#     1083,
#     1084,
#     1085,
#     1086,
#     1087,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   95: {'team': [('Бенедикт', 'следопыт'), ('Леопольд', 'следопыт')],
#    'avg_quality': 3.733333333333333,
#    'avg_deadline': 3.466666666666667,
#    'max_politeness': 3.8333333333333335,
#    'task_time': 9,
#    'weighted_score': 3.6366666666666663,
#    'common_availability': {1,
#     1046,
#     1047,
#     1048,
#     1049,
#     1050,
#     1051,
#     1052,
#     1053,
#     1054,
#     1055,
#     1056,
#     1057,
#     1058,
#     1059,
#     1060,
#     1061,
#     1062,
#     1063,
#     1064,
#     1065,
#     1066,
#     1067,
#     1068,
#     1069,
#     1070,
#     1071,
#     1072,
#     1073,
#     1074,
#     1075,
#     1076,
#     1077,
#     1078,
#     1079,
#     1080,
#     1081,
#     1082,
#     1083,
#     1084,
#     1085,
#     1086,
#     1087,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   96: {'team': [('Альфред', 'следопыт'), ('Бендер', 'следопыт')],
#    'avg_quality': 3.3666666666666667,
#    'avg_deadline': 3.8666666666666667,
#    'max_politeness': 4.0,
#    'task_time': 8,
#    'weighted_score': 3.6300000000000003,
#    'common_availability': {1,
#     1044,
#     1045,
#     1046,
#     1047,
#     1048,
#     1049,
#     1050,
#     1051,
#     1052,
#     1053,
#     1054,
#     1055,
#     1056,
#     1057,
#     1058,
#     1059,
#     1060,
#     1061,
#     1062,
#     1063,
#     1064,
#     1065,
#     1066,
#     1067,
#     1068,
#     1069,
#     1070,
#     1071,
#     1072,
#     1073,
#     1074,
#     1075,
#     1076,
#     1077,
#     1078,
#     1079,
#     1080,
#     1081,
#     1082,
#     1083,
#     1084,
#     1085,
#     1086,
#     1087,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   97: {'team': [('Бендер', 'следопыт'), ('Альфред', 'следопыт')],
#    'avg_quality': 3.3666666666666667,
#    'avg_deadline': 3.866666666666667,
#    'max_politeness': 4.0,
#    'task_time': 8,
#    'weighted_score': 3.6300000000000003,
#    'common_availability': {1,
#     1044,
#     1045,
#     1046,
#     1047,
#     1048,
#     1049,
#     1050,
#     1051,
#     1052,
#     1053,
#     1054,
#     1055,
#     1056,
#     1057,
#     1058,
#     1059,
#     1060,
#     1061,
#     1062,
#     1063,
#     1064,
#     1065,
#     1066,
#     1067,
#     1068,
#     1069,
#     1070,
#     1071,
#     1072,
#     1073,
#     1074,
#     1075,
#     1076,
#     1077,
#     1078,
#     1079,
#     1080,
#     1081,
#     1082,
#     1083,
#     1084,
#     1085,
#     1086,
#     1087,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   98: {'team': [('Агата', 'следопыт'), ('Альфред', 'следопыт')],
#    'avg_quality': 3.416666666666667,
#    'avg_deadline': 3.666666666666667,
#    'max_politeness': 4.5,
#    'task_time': 9,
#    'weighted_score': 3.6250000000000004,
#    'common_availability': {1,
#     1055,
#     1056,
#     1057,
#     1058,
#     1059,
#     1060,
#     1061,
#     1062,
#     1063,
#     1064,
#     1065,
#     1066,
#     1067,
#     1068,
#     1069,
#     1070,
#     1071,
#     1072,
#     1073,
#     1074,
#     1075,
#     1076,
#     1077,
#     1078,
#     1079,
#     1080,
#     1081,
#     1082,
#     1083,
#     1084,
#     1085,
#     1086,
#     1087,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   99: {'team': [('Альфред', 'следопыт'), ('Агата', 'следопыт')],
#    'avg_quality': 3.416666666666667,
#    'avg_deadline': 3.666666666666667,
#    'max_politeness': 4.5,
#    'task_time': 9,
#    'weighted_score': 3.6250000000000004,
#    'common_availability': {1,
#     1055,
#     1056,
#     1057,
#     1058,
#     1059,
#     1060,
#     1061,
#     1062,
#     1063,
#     1064,
#     1065,
#     1066,
#     1067,
#     1068,
#     1069,
#     1070,
#     1071,
#     1072,
#     1073,
#     1074,
#     1075,
#     1076,
#     1077,
#     1078,
#     1079,
#     1080,
#     1081,
#     1082,
#     1083,
#     1084,
#     1085,
#     1086,
#     1087,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   100: {'team': [('Леопольд', 'следопыт'), ('Юлия', 'следопыт')],
#    'avg_quality': 4.083333333333333,
#    'avg_deadline': 2.916666666666667,
#    'max_politeness': 4.0,
#    'task_time': 11,
#    'weighted_score': 3.608333333333333,
#    'common_availability': {1,
#     1050,
#     1051,
#     1052,
#     1053,
#     1054,
#     1055,
#     1056,
#     1057,
#     1058,
#     1059,
#     1060,
#     1061,
#     1062,
#     1063,
#     1064,
#     1065,
#     1066,
#     1067,
#     1068,
#     1069,
#     1070,
#     1071,
#     1072,
#     1073,
#     1074,
#     1075,
#     1076,
#     1077,
#     1078,
#     1079,
#     1080,
#     1081,
#     1082,
#     1083,
#     1084,
#     1085,
#     1086,
#     1087,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   101: {'team': [('Юлия', 'следопыт'), ('Леопольд', 'следопыт')],
#    'avg_quality': 4.083333333333333,
#    'avg_deadline': 2.916666666666667,
#    'max_politeness': 4.0,
#    'task_time': 11,
#    'weighted_score': 3.608333333333333,
#    'common_availability': {1,
#     1050,
#     1051,
#     1052,
#     1053,
#     1054,
#     1055,
#     1056,
#     1057,
#     1058,
#     1059,
#     1060,
#     1061,
#     1062,
#     1063,
#     1064,
#     1065,
#     1066,
#     1067,
#     1068,
#     1069,
#     1070,
#     1071,
#     1072,
#     1073,
#     1074,
#     1075,
#     1076,
#     1077,
#     1078,
#     1079,
#     1080,
#     1081,
#     1082,
#     1083,
#     1084,
#     1085,
#     1086,
#     1087,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   102: {'team': [('Альфред', 'следопыт'), ('Фредерик', 'следопыт')],
#    'avg_quality': 3.5952380952380953,
#    'avg_deadline': 3.5238095238095237,
#    'max_politeness': 4.0,
#    'task_time': 9,
#    'weighted_score': 3.607142857142857,
#    'common_availability': {1,
#     1079,
#     1080,
#     1081,
#     1082,
#     1083,
#     1084,
#     1085,
#     1086,
#     1087,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   103: {'team': [('Фредерик', 'следопыт'), ('Альфред', 'следопыт')],
#    'avg_quality': 3.5952380952380953,
#    'avg_deadline': 3.523809523809524,
#    'max_politeness': 4.0,
#    'task_time': 9,
#    'weighted_score': 3.607142857142857,
#    'common_availability': {1,
#     1079,
#     1080,
#     1081,
#     1082,
#     1083,
#     1084,
#     1085,
#     1086,
#     1087,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   104: {'team': [('Альфред', 'следопыт'), ('Бенедикт', 'следопыт')],
#    'avg_quality': 3.5666666666666664,
#    'avg_deadline': 3.466666666666667,
#    'max_politeness': 4.0,
#    'task_time': 9,
#    'weighted_score': 3.57,
#    'common_availability': {1,
#     1044,
#     1045,
#     1046,
#     1047,
#     1048,
#     1049,
#     1050,
#     1051,
#     1052,
#     1053,
#     1054,
#     1055,
#     1056,
#     1057,
#     1058,
#     1059,
#     1060,
#     1061,
#     1062,
#     1063,
#     1064,
#     1065,
#     1066,
#     1067,
#     1068,
#     1069,
#     1070,
#     1071,
#     1072,
#     1073,
#     1074,
#     1075,
#     1076,
#     1077,
#     1078,
#     1079,
#     1080,
#     1081,
#     1082,
#     1083,
#     1084,
#     1085,
#     1086,
#     1087,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   105: {'team': [('Бенедикт', 'следопыт'), ('Альфред', 'следопыт')],
#    'avg_quality': 3.566666666666667,
#    'avg_deadline': 3.466666666666667,
#    'max_politeness': 4.0,
#    'task_time': 9,
#    'weighted_score': 3.57,
#    'common_availability': {1,
#     1044,
#     1045,
#     1046,
#     1047,
#     1048,
#     1049,
#     1050,
#     1051,
#     1052,
#     1053,
#     1054,
#     1055,
#     1056,
#     1057,
#     1058,
#     1059,
#     1060,
#     1061,
#     1062,
#     1063,
#     1064,
#     1065,
#     1066,
#     1067,
#     1068,
#     1069,
#     1070,
#     1071,
#     1072,
#     1073,
#     1074,
#     1075,
#     1076,
#     1077,
#     1078,
#     1079,
#     1080,
#     1081,
#     1082,
#     1083,
#     1084,
#     1085,
#     1086,
#     1087,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   106: {'team': [('Альфред', 'следопыт'), ('Юлия', 'следопыт')],
#    'avg_quality': 3.916666666666667,
#    'avg_deadline': 2.916666666666667,
#    'max_politeness': 4.0,
#    'task_time': 11,
#    'weighted_score': 3.525,
#    'common_availability': {1,
#     1050,
#     1051,
#     1052,
#     1053,
#     1054,
#     1055,
#     1056,
#     1057,
#     1058,
#     1059,
#     1060,
#     1061,
#     1062,
#     1063,
#     1064,
#     1065,
#     1066,
#     1067,
#     1068,
#     1069,
#     1070,
#     1071,
#     1072,
#     1073,
#     1074,
#     1075,
#     1076,
#     1077,
#     1078,
#     1079,
#     1080,
#     1081,
#     1082,
#     1083,
#     1084,
#     1085,
#     1086,
#     1087,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   107: {'team': [('Юлия', 'следопыт'), ('Альфред', 'следопыт')],
#    'avg_quality': 3.916666666666667,
#    'avg_deadline': 2.916666666666667,
#    'max_politeness': 4.0,
#    'task_time': 11,
#    'weighted_score': 3.525,
#    'common_availability': {1,
#     1050,
#     1051,
#     1052,
#     1053,
#     1054,
#     1055,
#     1056,
#     1057,
#     1058,
#     1059,
#     1060,
#     1061,
#     1062,
#     1063,
#     1064,
#     1065,
#     1066,
#     1067,
#     1068,
#     1069,
#     1070,
#     1071,
#     1072,
#     1073,
#     1074,
#     1075,
#     1076,
#     1077,
#     1078,
#     1079,
#     1080,
#     1081,
#     1082,
#     1083,
#     1084,
#     1085,
#     1086,
#     1087,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   108: {'team': [('Альфред', 'следопыт'), ('Леопольд', 'следопыт')],
#    'avg_quality': 3.5,
#    'avg_deadline': 3.3333333333333335,
#    'max_politeness': 4.0,
#    'task_time': 9,
#    'weighted_score': 3.4833333333333334,
#    'common_availability': {1,
#     1046,
#     1047,
#     1048,
#     1049,
#     1050,
#     1051,
#     1052,
#     1053,
#     1054,
#     1055,
#     1056,
#     1057,
#     1058,
#     1059,
#     1060,
#     1061,
#     1062,
#     1063,
#     1064,
#     1065,
#     1066,
#     1067,
#     1068,
#     1069,
#     1070,
#     1071,
#     1072,
#     1073,
#     1074,
#     1075,
#     1076,
#     1077,
#     1078,
#     1079,
#     1080,
#     1081,
#     1082,
#     1083,
#     1084,
#     1085,
#     1086,
#     1087,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}},
#   109: {'team': [('Леопольд', 'следопыт'), ('Альфред', 'следопыт')],
#    'avg_quality': 3.5,
#    'avg_deadline': 3.3333333333333335,
#    'max_politeness': 4.0,
#    'task_time': 9,
#    'weighted_score': 3.4833333333333334,
#    'common_availability': {1,
#     1046,
#     1047,
#     1048,
#     1049,
#     1050,
#     1051,
#     1052,
#     1053,
#     1054,
#     1055,
#     1056,
#     1057,
#     1058,
#     1059,
#     1060,
#     1061,
#     1062,
#     1063,
#     1064,
#     1065,
#     1066,
#     1067,
#     1068,
#     1069,
#     1070,
#     1071,
#     1072,
#     1073,
#     1074,
#     1075,
#     1076,
#     1077,
#     1078,
#     1079,
#     1080,
#     1081,
#     1082,
#     1083,
#     1084,
#     1085,
#     1086,
#     1087,
#     1088,
#     1089,
#     1090,
#     1091,
#     1092,
#     1093,
#     1094,
#     1095,
#     1096,
#     1097,
#     1098,
#     1099,
#     1100,
#     1101,
#     1102,
#     1103,
#     1104,
#     1105,
#     1106}}},
#  'start_quant': 978,
#  'amount': 23500,
#  'nearest': 11095}

# %% [markdown]
# ### Обратный расчет приоритетов команд по задачам
#
# После того как для каждой задачи были рассчитаны допустимые команды и их приоритеты, выполнена обратная задача:
#
# **Определение приоритетов задач для каждой команды.**
#
# ---
#
# #### Цель обратного расчета
#
# Для каждой команды необходимо:
# 1. Рассчитать список задач, которые эта команда может выполнить.
# 2. Определить приоритетность задач, основанную на **стоимости поручения**:
#    - **Более дорогие задачи получают более высокий приоритет.**
#    - Это позволяет оптимально распределить ресурсы команды на более ценные задачи.
#
# ---
#
# #### Логика расчета
#
# 1. **Список доступных задач**
#    Для каждой команды формируется список задач, которые она может выполнить, с учётом:
#    - Доступности команды в заданном временном интервале.
#    - Возможности выполнения всех подзадач поручения.
#
# 2. **Сортировка по стоимости**
#    Задачи в списке команды сортируются по **убыванию стоимости**:
#    - Более дорогие задачи имеют больший приоритет для выполнения.
#
#
# ---
#
# Допущение:
# - Стоимость задачи не учитывает её сложность и идеальное время выполнения.
#
# ---
#
# 3. **Результат:**
#    Для каждой команды создаётся список задач с приоритетами.
#
# ---
#
# #### Зачем это нужно?
#
# 1. **Оптимизация распределения ресурсов**
#    Позволяет направить команды на выполнение наиболее ценных задач, увеличивая общую эффективность системы.
#
# 2. **Балансирование нагрузки**
#    Учитывает доступность команд и позволяет равномерно распределить задачи между ними.
#
# 3. **Подготовка к построению финального расписания**
#    Этот этап закладывает основу для эффективного выполнения задач с учётом приоритетов как задач, так и команд.
#
# ---
#
# ### Итог
#
# Расчёт приоритетов задач для каждой команды завершает процесс подготовки данных для построения рекомендательной системы. Теперь команды могут быть распределены на задачи с учётом их стоимости и временной доступности, что обеспечивает максимальную эффективность выполнения поручений.

# %%
team_priorities = {}
for task_id, task_data in tasks_teams.items():
    amount = task_data["amount"]
    for team_info in task_data["priority"].values():
        team = tuple(team_info["team"])
        if team not in team_priorities:
            team_priorities[team] = [(task_id, amount)]
        else:
            team_priorities[team].append((task_id, amount))

team_priorities_sorted = {}
for key, value in team_priorities.items():
    team_priorities_sorted[key] = dict([[id, values] for id, values in enumerate(sorted(value, reverse=True, key=lambda x: x[-1]))])

# %% [markdown]
# # Постановка задачи: Модель двухсторонних рынков с временными отрезками в виде задачи целочисленного программирования
#
# **Аркаша**, зная классические методы построения рекомендательных систем, решил поэкспериментировать и искать оптимальные команды для выполнения задач, используя подходы из теории двухсторонних рынков. Он сформулировал задачу **распределения задач между командами** как модель двухстороннего рынка с временными отрезками, где важно учитывать доступность команд в гильдии, чтобы успешно выполнить все поручения.
#
# ## Что такое задача двухсторонних рынков?
#
# Двухсторонний рынок — это модель, где два множества агентов (например, работники и работодатели) взаимодействуют, чтобы сформировать "сочетания", удовлетворяющие их предпочтениям. Классическим примером является задача распределения интернов по больницам, где:
# - Больницы имеют ограниченное количество мест и список предпочтений интернов.
# - Интерны предпочитают работать в определённых больницах.
#
# В рамках таких задач часто вводится понятие **блокирующей пары**:
# - **Блокирующая пара** — это пара (агент из первого множества, агент из второго множества), которая предпочитает друг друга своим текущим партнёрам, нарушая стабильность системы.
#
# Аркаша адаптировал эту идею для распределения задач между командами, где:
# 1. Задачи ("работодатели") имеют приоритеты среди команд.
# 2. Команды ("работники") имеют приоритеты среди задач.
# 3. Важно учитывать не только стабильность, но и временные ограничения.
#
# ---
#
# ## Основные множества
#
# ### 1. Задачи (tasks)
# Это множество задач, каждая из которых имеет следующие параметры:
# - `start_quant`: минимальный квант времени, когда задача может быть начата.
# - `amount`: вознаграждение за успешное выполнение задачи.
# - `priority`: словарь, где каждому приоритету (ключу) соответствует описание, включающее:
#   - Название команды (`team`) — список пар кортежей вида `[(Член команды, Роль)]`.
#   - Время выполнения задачи данной командой (`task_time`).
#   - Доступные кванты времени для всей команды (`common_availability`).
#
# ### 2. Команды (teams)
# Это множество команд, где каждая команда представлена как:
# - Список пар кортежей вида `[(Член команды, Роль)]`.
# - Каждая команда имеет список задач с приоритетами, которые она может выполнять.
#
# ---
#
# ## Переменные
#
# ### 1. Бинарная переменная $X_{\text{team, task, t}}$
# - $X_{\text{team, task, t}} = 1$ , если команда `team` начинает выполнение задачи `task` в квант времени \( t \).
# - Эта переменная нужна для:
#   - Связи задачи с командой и временем её выполнения.
#   - Учёта доступности команд в гильдии в конкретные временные интервалы.
#
# ### 2. Бинарная переменная $w_{\text{task}}$
# - $w_{\text{task}} = 1$, если задача `task` выполнена.
# - Эта переменная нужна для:
#   - Отслеживания, была ли задача выполнена.
#   - Подсчёта выполненных задач в целевой функции.
#
# ### 3. Бинарная переменная $B_{\text{team, task}}$
# - $B_{\text{team, task}} = 1$, если команда `team` и задача `task` образуют блокирующую пару.
# - Эта переменная нужна для:
#   - Учёта стабильности решения.
#   - Сокращения числа блокирующих пар.
#
# ### 4. Вещественная неотрицательная переменная $\text{MaxTime}$
# - Это максимальное время выполнения задач.
# - Нужна для:
#   - Минимизации общего времени завершения всех задач.
#
# ---
#
# ## Ограничения
#
# ### 1. Связь выполнения задач с командами и временем
# $$
# w_{\text{task}} = \sum_{\text{team}, t} X_{\text{team, task, t}}
# $$
# - Это ограничение устанавливает, что задача считается выполненной, если она была начата хотя бы одной командой в определённый момент времени.
# - **Зачем нужно:** чтобы задача могла считаться выполненной только при наличии команды, которая действительно начала её выполнение.
#
# ---
#
# ### 2. Ограничение времени
# Если $X_{\text{team, task, t}} = 1$, то все команды, в которых есть участники команды `team`, становятся недоступны на время выполнения задачи `task` (в интервале $[t, t + \text{task\_time}]$).
# $$
# \sum_{\text{team1, task1, t1}} X_{\text{team1, task1, t1}} \leq M \cdot (1 - X_{\text{team, task, t}})
# $$
# - **Зачем нужно:** чтобы гарантировать, что одна и та же команда или её члены не могут одновременно выполнять разные задачи.
#
# ---
#
# ### 3. Ограничение слабой стабильности
# $$
# q_h X_{\text{team, task, t}} + q_h \sum_{j \succ \text{team}} X_{j, \text{task}, t} + \sum_{i \succ \text{task}} X_{\text{team}, i, t} \geq q_h - M \cdot B_{\text{team, task}}
# $$
# - **Зачем нужно:** чтобы уменьшить количество блокирующих пар, при которых команды и задачи предпочитают друг друга больше, чем текущим партнёрам.
# - $q_{\text{h}}$ - количество команд, которая может принять задача. Будем считать $q_{\text{h}}=1$
# - ${\text{M}}$ - большое число, которое отключает ограничение, при разных значения бинарных переменных
# ---
#
# ### 4. Максимальное время выполнения
# $$
# \text{MaxTime} \geq t + \text{task\_time} \cdot X_{\text{team, task, t}}
# $$
# - **Зачем нужно:** чтобы минимизировать время завершения самой поздней задачи.
#
# ---
#
# ### 5. Минимизация отклонения от предпочтительного времени начала задачи
# $$
# \sum_{\text{team, task, t}} \left(t - \text{start\_quant}_{\text{task}}\right) \cdot X_{\text{team, task, t}}
# $$
# - **Зачем нужно:** чтобы задачи выполнялись ближе к предпочтительному времени их начала.
#
# ---
#
# ## Целевая функция
#
# Итоговая целевая функция объединяет несколько компонентов:
# $$
# \text{Objective} = -\text{TotalReward} + \text{MaxTime} + \alpha_1 \cdot \sum (1 - w_{\text{task}}) + \alpha_2 \cdot \sum B_{\text{team, task}} + \beta \cdot \sum_{\text{team, task, t}} \left(t - \text{start\_quant}_{\text{task}}\right) $$
#
# Где:
# - $ \text{TotalReward} $: сумма вознаграждений за выполненные задачи.
# - $ \text{MaxTime} $: максимальное время выполнения задач.
# - $ \alpha_1 $: штраф за невыполнение задач.
# - $ \alpha_2 $: штраф за блокирующие пары.
# - $ \beta $: штраф за отклонение времени выполнения от $ \text{start\_quant} $.
#
#
# ---
#
# ## Задача
#
# Аркаша построил модель двухстороннего рынка с временными отрезками, чтобы распределять задачи между командами так, чтобы:
# 1. Максимизировать сумму вознаграждений за задачи.
# 2. Минимизировать максимальное время выполнения задач.
# 3. Уменьшить количество невыполненных задач.
# 4. Уменьшить количество блокирующих пар.
# 5. Учитывать предпочтительное время выполнения задач.

# %%
class TaskAssignmentProblem:
    def __init__(self, tasks, teams, planning_horizon, alpha_1=0, alpha_2=0, beta=1000):
        """
        Инициализация задачи распределения задач между командами.

        :param tasks: Словарь с данными задач.
        :param teams: Словарь с данными команд.
        :param planning_horizon: Горизонт планирования (список квантов времени).
        :param alpha_1: Весовой коэффициент для штрафа за невыполненные задачи.
        :param alpha_2: Весовой коэффициент для штрафа за блокирующие пары.
        :param beta: Весовой коэффициент для штрафа за отклонение времени выполнения.
        """
        self.tasks = tasks
        self.teams = teams
        self.T = planning_horizon
        self.alpha_1 = alpha_1
        self.alpha_2 = alpha_2
        self.alpha_3 = beta

        # Создание модели
        self.model = LpProblem(name="TaskAssignmentProblem", sense=LpMinimize)

        # Переменные
        self.X = {}
        self.w = {}
        self.B = {}
        self.max_time = None

        # Вызов методов
        self._create_variables()
        self._add_constraints()
        self._set_objective()

    def _create_variables(self):
        """Создание переменных модели."""
        for task_id, task_data in self.tasks.items():
            start_quant = task_data["start_quant"]
            for team in [tuple(priority["team"]) for priority in task_data["priority"].values()]:
                for t in range(start_quant, max(self.T) + 1):
                    self.X[team, task_id, t] = LpVariable(f"X_{team}_{task_id}_{t}", cat="Binary")

        for task_id in self.tasks.keys():
            self.w[task_id] = LpVariable(f"w_{task_id}", cat="Binary")

        for task_id, task_data in self.tasks.items():
            for team in [tuple(priority["team"]) for priority in task_data["priority"].values()]:
                self.B[team, task_id] = LpVariable(f"B_{team}_{task_id}", cat="Binary")

        self.max_time = LpVariable("MaxTime", lowBound=0, cat="Continuous")

    def _add_constraints(self):
        """Добавление ограничений в модель."""
        for task_id, task_data in self.tasks.items():
            start_quant = task_data["start_quant"]
            self.model += (
                self.w[task_id]
                == lpSum(
                    self.X[team, task_id, t]
                    for team in [tuple(priority["team"]) for priority in task_data["priority"].values()]
                    for t in range(start_quant, max(self.T) + 1)
                ),
                f"TaskCompletion_{task_id}",
            )

        for task_id, task_data in self.tasks.items():
            start_quant = task_data["start_quant"]
            for team in [tuple(priority["team"]) for priority in task_data["priority"].values()]:
                task_time = next(
                    priority["task_time"]
                    for priority in task_data["priority"].values()
                    if tuple(priority["team"]) == team
                )
                for t in range(start_quant, max(self.T) + 1 - task_time):
                    self.model += (
                        self.max_time
                        >= t + task_time * self.X[team, task_id, t],
                        f"MaxTime_{team}_{task_id}_{t}",
                    )

        M = 1000000
        for task_id, task_data in self.tasks.items():
            for team in [tuple(priority["team"]) for priority in task_data["priority"].values()]:
                start_quant = task_data["start_quant"]
                task_time = next(
                    priority["task_time"]
                    for priority in task_data["priority"].values()
                    if tuple(priority["team"]) == team
                )

                self.model += (
                    lpSum(
                        self.X[team, task_id, t]
                        for t in range(start_quant, max(self.T) + 1 - task_time)
                    )
                    >= 1 - M * self.B[team, task_id],
                    f"WeakStability_{team}_{task_id}",
                )

    def _set_objective(self):
        """Задание целевой функции."""
        total_reward = lpSum(
            self.w[task_id] * self.tasks[task_id]["amount"]
            for task_id in self.tasks.keys()
        )
        uncompleted_tasks_penalty = lpSum(1 - self.w[task_id] for task_id in self.tasks.keys())
        blocking_pairs_penalty = lpSum(
            self.B[team, task_id]
            for task_id in self.tasks.keys()
            for team in [tuple(priority["team"]) for priority in self.tasks[task_id]["priority"].values()]
        )
        deviation_penalty = lpSum(
            (t - self.tasks[task_id]["start_quant"]) * self.X[team, task_id, t]
            for task_id in self.tasks.keys()
            for team in [tuple(priority["team"]) for priority in self.tasks[task_id]["priority"].values()]
            for t in range(self.tasks[task_id]["start_quant"], max(self.T) + 1)
        )

        self.model += (
            -total_reward
            + self.alpha_3 * self.max_time
            + self.alpha_1 * uncompleted_tasks_penalty
            + self.alpha_2 * blocking_pairs_penalty
            + self.alpha_3 * deviation_penalty,
            "ObjectiveFunction",
        )

    def solve(self):
        """Решение задачи."""
        self.model.solve()
        return {
            "status": self.model.status,
            "objective": self.model.objective.value(),
            "variables": {v.name: v.value() for v in self.model.variables()},
        }

# %%
problem = TaskAssignmentProblem(tasks=tasks_teams, teams=team_priorities_sorted, planning_horizon=t, alpha_1=1, alpha_2=1, beta=1)

# %%
result = problem.solve()

# %%
def parse_variable_name(variable_name):
    """
    Разбирает имя переменной X_(team)_task_t и извлекает команду, задачу и время.
    
    :param variable_name: Название переменной (строка).
    :return: tuple (team, task, start_time).
    """
    match = re.match(r"X_\((.+)\)_(\d+)_(\d+)", variable_name)
    if not match:
        return

    team_str, task, start_time = match.groups()
    team_str = team_str.replace("_", " ")

    try:
        team = eval(team_str)
    except SyntaxError as e:
        return
    return team, int(task), int(start_time)

# %%
def calculate_total_reward(tasks, w):
    """
    Вычисляет значение TotalReward из решения модели PuLP.

    :param tasks: Словарь задач, содержащий информацию о вознаграждении ('amount').
    :param w: Словарь переменных w_task из решения модели (0 или 1).
    :return: Значение TotalReward.
    """
    total_reward = 0
    for task_id, task_data in tasks.items():
        if w[f"w_{task_id}"] == 1:  # Если задача выполнена
            total_reward += task_data["amount"]
    return total_reward

# %% [markdown]
# Достанем результаты модели:

# %%
variables = result.get("variables", {})
w_values = {name: value for name, value in variables.items() if name.startswith("w_")}
x_values = {name: value for name, value in variables.items() if name.startswith("X_")}
maxTime =  {name: value for name, value in variables.items() if name.startswith("MaxTime")}

# %% [markdown]
# ### Выполнены все задачи

# %%
sum(x_values.values()) == len(tasks_teams)
# Out:
# True

# %% [markdown]
# ### Суммарная выручка

# %%
total_reward = calculate_total_reward(tasks_teams, w_values)
total_reward
# Out:
# 343500

# %%
#Подсчет основных характеристик назначенных команд на поручения
tasks_completed = []
for x, value in x_values.items():
    if value > 0:
        team, task_id, start_time = parse_variable_name(x)
        for pripority, team_info in tasks_teams[task_id]["priority"].items():
            if team_info["team"] == list(team):
                tasks_completed.append(
                    {
                        "Номер поручения": task_id,
                        "Команда": team,
                        "Затрачено дней": team_info["task_time"],
                        "Время начала выполнения": start_time,
                        "Время завершения": team_info["task_time"] + start_time,
                        "Оценка за качество": team_info["avg_quality"],
                        "Оценка по срокам": team_info["avg_deadline"],
                        "Оценка за вежливость": team_info["max_politeness"],
                        "Приоритет команды": pripority,

                    }
                )

# %% [markdown]
# ### Создание финальной таблицы распределения команд по поручениям

# %%
result_df_from_model = pd.DataFrame(tasks_completed)
result_df_from_model.head()
# Out:
#    Номер поручения                                     Команда  \
# 0            11143      ((Альфред, лекарь), (Альфред, мечник))
# 1            11234        ((Бендер, мечник), (Мартин, лучник))
# 2            11396      ((Бендер, рейнджер), (Юлия, рейнджер))
# 3            11402  ((Бендер, следопыт), (Фредерик, следопыт))
# 4            11232                     ((Бенедикт, следопыт),)
#
#    Затрачено дней  Время начала выполнения  Время завершения  \
# 0               6                     1020              1026
# 1              14                     1026              1040
# 2               3                     1033              1036
# 3               3                     1045              1048
# 4               5                     1024              1029
#
#    Оценка за качество  Оценка по срокам  Оценка за вежливость  \
# 0            3.833333          3.666667              3.500000
# 1            3.833333          3.416667              4.500000
# 2            4.166667          3.833333              4.333333
# 3            3.628571          4.057143              4.000000
# 4            3.600000          4.200000              4.200000
#
#    Приоритет команды
# 0                 51
# 1                418
# 2                 81
# 3                 50
# 4                  4

# %%
result_df_from_model["Дата начала выполнения"] = result_df_from_model["Время начала выполнения"].map(t_date_dict)
result_df_from_model["Дата завершения"] = result_df_from_model["Время завершения"].map(t_date_dict)

# %%
result_df = pd.merge(
    result_df_from_model,
    df_test_cases[["Номер поручения", "Дата поручения", "Дата поручения_t", "Описание", "cluster"]],
    on="Номер поручения",
)

# %% [markdown]
# ### Запись распределения Аркашей героев по невыполненным задачам в result_task_assignment.csv

# %%
result_df
# Out:
#     Номер поручения                                       Команда  \
# 0             11143        ((Альфред, лекарь), (Альфред, мечник))
# 1             11234          ((Бендер, мечник), (Мартин, лучник))
# 2             11396        ((Бендер, рейнджер), (Юлия, рейнджер))
# 3             11402    ((Бендер, следопыт), (Фредерик, следопыт))
# 4             11232                       ((Бенедикт, следопыт),)
# 5             11306                       ((Бенедикт, следопыт),)
# 6             11462                       ((Бенедикт, следопыт),)
# 7             11417  ((Леопольд, следопыт), (Пастушок, следопыт))
# 8             11387      ((Леопольд, следопыт), (Юлия, следопыт))
# 9             11218                         ((Мартин, следопыт),)
# 10            11428    ((Пастушок, мечник), (Бенедикт, рейнджер))
# 11            11161  ((Пастушок, следопыт), (Фредерик, следопыт))
# 12            11438  ((Синеглазый, следопыт), (Бендер, следопыт))
# 13            11311    ((Синеглазый, следопыт), (Соня, следопыт))
# 14            11285   ((Фредерик, следопыт), (Альфред, следопыт))
# 15            11134             ((Юлия, лекарь), (Агата, лучник))
# 16            11381        ((Юлия, лекарь), (Синеглазый, мечник))
# 17            11310                           ((Юлия, следопыт),)
# 18            11056      ((Юлия, следопыт), (Леопольд, следопыт))
#
#     Затрачено дней  Время начала выполнения  Время завершения  \
# 0                6                     1020              1026
# 1               14                     1026              1040
# 2                3                     1033              1036
# 3                3                     1045              1048
# 4                5                     1024              1029
# 5                5                     1048              1053
# 6                4                     1055              1059
# 7               12                      994              1006
# 8                6                     1015              1021
# 9                4                     1003              1007
# 10               7                     1037              1044
# 11               3                     1005              1008
# 12               2                     1052              1054
# 13               7                      992               999
# 14               3                     1002              1005
# 15               9                      976               985
# 16               9                      992              1001
# 17               5                      996              1001
# 18              11                      978               989
#
#     Оценка за качество  Оценка по срокам  Оценка за вежливость  \
# 0             3.833333          3.666667              3.500000
# 1             3.833333          3.416667              4.500000
# 2             4.166667          3.833333              4.333333
# 3             3.628571          4.057143              4.000000
# 4             3.600000          4.200000              4.200000
# 5             3.600000          4.200000              4.200000
# 6             3.600000          4.200000              4.200000
# 7             3.904762          3.452381              3.833333
# 8             4.083333          2.916667              4.000000
# 9             4.000000          4.000000              4.500000
# 10            3.500000          4.000000              3.750000
# 11            4.166667          4.000000              4.333333
# 12            3.950000          4.200000              4.000000
# 13            4.416667          4.000000              3.750000
# 14            3.750000          3.750000              4.000000
# 15            4.000000          4.166667              4.333333
# 16            4.000000          4.083333              4.166667
# 17            3.666667          3.666667              3.833333
# 18            4.083333          2.916667              4.000000
#
#     Приоритет команды Дата начала выполнения      Дата завершения  \
# 0                  51    1053-10-18 00:00:00  1053-10-24 00:00:00
# 1                 418    1053-10-24 00:00:00  1053-11-07 00:00:00
# 2                  81    1053-10-31 00:00:00  1053-11-03 00:00:00
# 3                  50    1053-11-12 00:00:00  1053-11-15 00:00:00
# 4                   4    1053-10-22 00:00:00  1053-10-27 00:00:00
# 5                   4    1053-11-15 00:00:00  1053-11-20 00:00:00
# 6                   4    1053-11-22 00:00:00  1053-11-26 00:00:00
# 7                  80    1053-09-22 00:00:00  1053-10-04 00:00:00
# 8                 100    1053-10-13 00:00:00  1053-10-19 00:00:00
# 9                   1    1053-10-01 00:00:00  1053-10-05 00:00:00
# 10                165    1053-11-04 00:00:00  1053-11-11 00:00:00
# 11                  8    1053-10-03 00:00:00  1053-10-06 00:00:00
# 12                  5    1053-11-19 00:00:00  1053-11-21 00:00:00
# 13                  0    1053-09-20 00:00:00  1053-09-27 00:00:00
# 14                 59    1053-09-30 00:00:00  1053-10-03 00:00:00
# 15                  2    1053-09-04 00:00:00  1053-09-13 00:00:00
# 16                  6    1053-09-20 00:00:00  1053-09-29 00:00:00
# 17                  7    1053-09-24 00:00:00  1053-09-29 00:00:00
# 18                101    1053-09-06 00:00:00  1053-09-17 00:00:00
#
#    Дата поручения  Дата поручения_t  \
# 0      1053-10-18              1020
# 1      1053-10-24              1026
# 2      1053-10-31              1033
# 3      1053-11-12              1045
# 4      1053-10-22              1024
# 5      1053-11-15              1048
# 6      1053-11-22              1055
# 7      1053-09-22               994
# 8      1053-10-13              1015
# 9      1053-10-01              1003
# 10     1053-11-04              1037
# 11     1053-10-03              1005
# 12     1053-11-19              1052
# 13     1053-09-20               992
# 14     1053-09-30              1002
# 15     1053-09-04               976
# 16     1053-09-20               992
# 17     1053-09-24               996
# 18     1053-09-06               978
#
#                                              Описание  \
# 0   В пещере завёлся дракон. Нужно его убить. Это ...
# 1   В лесу по дороге от пещеры заметили разбойнико...
# 2   В лесу недалеко от города заметили зверей. Нуж...
# 3   По дороге из деревни у меня потерялась драгоце...
# 4   В деревне монстры похитили путников. Нужно спа...
# 5   В деревне монстры похитили путников. Нужно спа...
# 6   В городе монстры похитили путников. Нужно осво...
# 7   Недалеко от города у меня была украдена драгоц...
# 8   Недалеко от города у меня пропала драгоценност...
# 9   Недалеко от города монстры похитили путников. ...
# 10  В лесу около деревни звери нападают на людей. ...
# 11  В городе у меня потерялся рюкзак. Нужно найти ...
# 12  В городе у меня пропала драгоценность. Нужно в...
# 13  По дороге из деревни у меня была украдена драг...
# 14  В городе у меня потерялся рюкзак. Нужно найти ...
# 15  В пещере появвилось огромное каменное чудовище...
# 16  В пещере появвилось огромное каменное чудовище...
# 17  По дороге из деревни монстры похитили путников...
# 18  По дороге из деревни у меня пропала драгоценно...
#
#                                               cluster
# 0                    убить-победить-уничтожить дракон
# 1                         прогнать-проучить разбойник
# 2                     убить-победить-уничтожить зверь
# 3                         вернуть-найти драгоценность
# 4                            спасти-освободить монстр
# 5                            спасти-освободить монстр
# 6                            спасти-освободить монстр
# 7                         вернуть-найти драгоценность
# 8                         вернуть-найти драгоценность
# 9                            спасти-освободить монстр
# 10                            прогнать-проучить зверь
# 11                               вернуть-найти рюкзак
# 12                        вернуть-найти драгоценность
# 13                        вернуть-найти драгоценность
# 14                               вернуть-найти рюкзак
# 15  убить-победить-уничтожить огромный каменный чу...
# 16  убить-победить-уничтожить огромный каменный чу...
# 17                           спасти-освободить монстр
# 18                        вернуть-найти драгоценность

# %%
result_df.to_csv("result_task_assignment.csv")

# %% [markdown]
# ### Аркаша успешно составил и распределил команды так, что все невыполненные задачи были выполнены

# %% [markdown]
# #### Среднее время ожидания начала выполнения задачи в днях представлено ниже:
# #### Можно видеть, что модель стремилась минимизировать время ожидания, поэтому были подобраны такие команды, которые готовы были взяться за задачи сразу же, как они поступили

# %%
np.mean(result_df["Время начала выполнения"] -result_df["Дата поручения_t"])
# Out:
# 0.0

# %% [markdown]
# #### Суммарное время выполнения (в днях):

# %%
np.mean(result_df["Затрачено дней"])
# Out:
# 6.2105263157894735

# %% [markdown]
# ## Проверка случайного распределения задач
#
# Для проверки алгоритма случайного распределения задач мы реализуем следующий подход:
#
# ### Основные предположения:
# 1. **Набор команд и их приоритеты**:
#    - Используем `team_priorities_sorted` — множество, где каждая команда ассоциирована с приоритетами на выполнение задач.
#    - Если у команды есть приоритет на задачу, то она может её выполнять.
#
# 2. **Индексация задач**:
#    - Все задачи, на которые необходимо назначить команды, индексированы от $0$ до $n$, где $n$ — общее количество задач, которые остались невыполненными.
#
# ### Процесс распределения:
# 1. **Случайный выбор команд**:
#    - Из множества команд ``team_priorities_sorted`` выбираем случайный набор команд. Это позволяет учитывать различные сочетания назначений.
#
# 2. **Назначение задач**:
#    - Для каждой задачи $i$ проверяем, доступна ли случайно выбранная команда $\text{team}_i$ (под индексом $i$) для выполнения задачи $ i $ в соответствии с приоритетами.
#    - Если команда может выполнить задачу, то она назначается на неё.
#
# ### Упрощения и ограничения:
# 1. **Игнорирование доступности команд**:
#    - Фактор доступности команд (например, ограниченность ресурсов или уже назначенные задачи) не учитывается.
#    - Это объясняется тем, что текущее распределение изначально не покрывает все задачи, а цель проверки — оценить случайное распределение.
#
# 2. **Игнорирование временного фактора**:
#    - Временные ограничения (например, доступные кванты времени для выполнения задач) также не учитываются.
#    - Учет временного фактора требует отдельной постановки задачи, время на которую не хватило в рамках поставленного дедлайна.
#
# ### Замечание:
# Случайное распределение предназначено для грубой оценки и проверки корректности базового подхода к назначению задач. Оно не стремится к оптимальности и не учитывает ключевые ограничения, такие как доступность.
#
# Реализация полного алгоритма с учетом временных ограничений требует дополнительного времени на разработку, которое в условиях контеста отсутствует.

# %%
#Случайные выбор n команд
def get_teams_distribution(feasible_teams, num_teams, random_seed=42):
    random.seed(random_seed)
    return dict(random.sample(list(feasible_teams.items()), num_teams))

# %%
#Невыполненные задачи
required_tasks_ids = df_test_cases["Номер поручения"].values
required_tasks_ids
# Out:
# array([11056, 11134, 11143, 11161, 11218, 11232, 11234, 11285, 11306,
#        11310, 11311, 11381, 11387, 11396, 11402, 11417, 11428, 11438,
#        11462], dtype=int64)

# %%
#Проверка, подходит команда к  поручению
def check_team_competence(team, task_id, tasks):
    task = tasks[task_id]["priority"]
    for team_info in task.values():
        if team_info["team"] == list(team):
            return {
                "Номер поручения": task_id,
                "Команда": team,
                "Оценка за качество": team_info["avg_quality"],
                "Оценка по срокам": team_info["avg_deadline"],
                "Оценка за вежливость": team_info["max_politeness"],
                "Затрачено дней": team_info["task_time"],
                "Награда": tasks[task_id]["amount"]  
            }
    return -1

# %%
#Отбор случайных команд из списка, которые смогли бы выполнить задачу без учета времени
def get_random_team_completed_tasks(teams, required_tasks_ids, tasks_info):
    result = []
    for id_, team in enumerate(teams):
        task_id = required_tasks_ids[id_]
        competence = check_team_competence(team, task_id, tasks_info)
        if competence != -1:
            result.append(competence)
    return pd.DataFrame(result)

# %% [markdown]
# ## Как можно видеть, случайное распределение команд не позволяет выполнить все еще невыполненные поручения гильдии даже с учетом отсутсвия фактора времени

# %%
random_teams_42 = get_teams_distribution(team_priorities_sorted, len(required_tasks_ids), 42)
df_res_teams_42 = get_random_team_completed_tasks(random_teams_42, required_tasks_ids, tasks_teams)
df_res_teams_42
# Out:
#    Номер поручения                               Команда  Оценка за качество  \
# 0            11387  ((Соня, следопыт), (Юлия, следопыт))            4.416667
# 1            11428   ((Юлия, мечник), (Альфред, мечник))            3.333333
#
#    Оценка по срокам  Оценка за вежливость  Затрачено дней  Награда
# 0          3.250000              4.000000               5    29000
# 1          3.833333              4.333333               7    15000

# %%
df_res_teams_42["Награда"].sum()
# Out:
# 44000

# %%
random_teams_24 = get_teams_distribution(team_priorities_sorted, len(required_tasks_ids), 24)
df_res_teams_24 = get_random_team_completed_tasks(random_teams_24, required_tasks_ids, tasks_teams)
df_res_teams_24
# Out:
#    Номер поручения                                         Команда  \
# 0            11285     ((Альфред, следопыт), (Пастушок, следопыт))
# 1            11311  ((Фредерик, следопыт), (Синеглазый, следопыт))
# 2            11402      ((Мартин, следопыт), (Пастушок, следопыт))
#
#    Оценка за качество  Оценка по срокам  Оценка за вежливость  Затрачено дней  \
# 0            3.916667          3.750000              4.333333               3
# 1            4.178571          3.857143              3.857143               7
# 2            3.946429          3.785714              4.250000               3
#
#    Награда
# 0    16000
# 1    22000
# 2    15000

# %%
df_res_teams_24["Награда"].sum()
# Out:
# 53000

# %%
random_teams_35 = get_teams_distribution(team_priorities_sorted, len(required_tasks_ids), 35)
df_res_teams_35 = get_random_team_completed_tasks(random_teams_35, required_tasks_ids, tasks_teams)
df_res_teams_35
# Out:
#    Номер поручения                                         Команда  \
# 0            11143            ((Мартин, лекарь), (Бендер, мечник))
# 1            11234  ((Бенедикт, рейнджер), (Синеглазый, рейнджер))
# 2            11402        ((Альфред, следопыт), (Агата, следопыт))
#
#    Оценка за качество  Оценка по срокам  Оценка за вежливость  Затрачено дней  \
# 0            4.321429          4.125000              4.142857               5
# 1            4.000000          3.875000              4.500000              12
# 2            3.416667          3.666667              4.500000               3
#
#    Награда
# 0    11000
# 1    26000
# 2    15000

# %%
df_res_teams_24["Награда"].sum()
# Out:
# 53000

# %% [markdown]
# # Мотивация и особенности модели
#
# Модель была разработана с целью минимизации времени ожидания клиентов. Это ключевой фактор для повышения лояльности заказчиков: чем быстрее гильдия выполняет заказы, тем выше вероятность того, что клиенты вернутся снова. Именно поэтому  модели выбирала такие команды, чье максимальное число героев в командах было ограничено двумя. Этот выбор объясняется тем, что именно команды из двух героев позволили учесть графики всех участников, синхронизировать их доступность и начинать выполнение заданий как можно раньше.
#
# ## Условия и допущения
#
# 1. **Ограничения на качество работы героев**:
#    - Каждый герой может быть выбран для выполнения задачи только в том случае, если его средняя оценка за качество работы превышает 3.
#    - Также учитывается пунктуальность: герой допускается к работе, если его средние оценки за выполнение в срок превышают 2.
#    - Эти ограничения позволяют поддерживать высокий уровень качества выполнения заданий.
#
# 2. **Гибкость параметров приоритетов**:
#    - Пользователь модели может настроить параметры $ \alpha_1$, $\alpha_2$,$\beta$, чтобы управлять акцентами при оптимизации:
#      - $\alpha_1 $: важность количества выполнения заданий.
#      - $\alpha_2$: важность соблюдения приоритетов задач.
#      - $ \beta$: важность отклонения от начала выполнения задачи с момента ее поступления.
#    - Это даёт возможность адаптировать модель под различные сценарии — от строгого соблюдения сроков до выполнения большего числа заказов.
#
# ## Итоги работы модели
#
# Данный подход оказался наиболее эффективным. Он обеспечил:
# - Учет графиков каждого героя, что позволило начинать задачи в максимально ранние сроки.
# - Соответствие высокого уровня качества, заданного через средние оценки.
# - Возможность пользователям модели выбирать, что для них важнее: минимизация времени, соблюдение приоритетов или увеличение числа выполненных задач.
#
# Такая гибкость делает модель подходящей как для малых гильдий с небольшим числом заказов, так и для крупных организаций, где важно учитывать множество различных факторов при планировании работы.

# %% [markdown]
# # Результаты работы
#
# В результате выполнения работы были достигнуты следующие этапы и результаты:
#
# 1. **Анализ описаний поручений:**
#    - Описания поручений были разделены на **описание**, **цель**, и **совет**.
#    - Это позволило структурировать данные и выделить ключевую информацию.
#
# 2. **Определение объектов задания:**
#    - С помощью моделей трансформеров из текстового описания был извлечён **объект задания**.
#    - Это улучшило понимание контекста задачи и её связи с целью.
#
# 3. **Кластеризация задач:**
#    - Построены **кластеры цель-объект**, что позволило определить основные типы задач в гильдии.
#    - Это упростило группировку и анализ поручений.
#
# 4. **Анализ ценообразования:**
#    - Было проанализировано ценообразование с точки зрения заказчиков.
#    - Принято решение **не учитывать фактор заказчика** при формировании рекомендаций, так как он не влияет на эффективность выполнения задач.
#
# 5. **Анализ дневников героев:**
#    - Изучены дневники героев, их выполненные задачи и оценки.
#    - Оценки героев были агрегированы по каждому показателю (качество, сроки, вежливость) внутри их ролей и кластеров.
#
# 6. **Фильтрация героев:**
#    - Герои были признаны **недопустимыми** для выполнения задач в определённых ролях и кластерах, если:
#      - Средняя оценка за качество < 3.
#      - Средняя оценка за сроки ≤ 2.
#
# 7. **Интервалы доступности:**
#    - Для каждого героя определены **интервалы доступности** между поручениями.
#
# ---
#
# ### Построение рекомендательной системы
#
# 1. **Определение ближайших соседей задач:**
#    - Для каждой невыполненной задачи найден её **ближайший выполненный сосед** с точки зрения векторного описания (модель трансформера) и общего кластера.
#
# 2. **Использование информации о соседях:**
#    - Из ближайших выполненных задач извлечены:
#      - **Идеальное время выполнения**, рассчитанное по формуле.
#      - **Список действий**, необходимых для выполнения задачи.
#
# 3. **Формирование команд:**
#    - На основе кластера и доступных героев были построены команды, которые:
#      - Закрывают все подзадачи для выполнения поручения.
#      - Имеют свободное временное окно в момент появления задачи.
#
# 4. **Оценка команд:**
#    - Рассчитаны средние оценки команды за:
#      - **Качество.**
#      - **Сроки.**
#      - **Максимальная вежливость** (представляет всю команду).
#    - Средняя оценка команды рассчитывалась как:
#      $
#      \text{Оценка команды} = 0.5 \times \text{Качество} + 0.4 \times \text{Сроки} + 0.1 \times \text{Вежливость}
#      $
#
# 5. **Приоритеты команд:**
#    - Задачи отсортированы по приоритетам, основываясь на оценке команды.
#    - Для всех команд определены приоритеты по стоимости задач (команды стремились к выполнению самых дорогих поручений).
#
# ---
#
# ### Оптимизация с помощью целочисленного программирования
#
# 1. На основе множества задач и команд сформулирована задача **целочисленного программирования**, учитывающая:
#    - Принципы двухсторонних рынков.
#    - Временной фактор выполнения поручений.
#
# 2. **Расширяемость модели:**
#    - Подход позволяет варьировать гиперпараметры в зависимости от приоритетов пользователя (например, важность времени, приоритетности, % невыполненных задач).
#
# 3. **Результаты модели:**
#    - Модель способна:
#      - Назначать команды на задачи с учётом времени и эффективности.
#      - Избегать временных пересечений и противоречий.
#      - Обеспечивать максимальную ценность выполнения задач для гильдии.
#
# ---
#
# ### Итог
#
# Разработанный подход даёт гибкость и точность в распределении задач. Он позволяет учитывать множество факторов, таких как время, качество, стоимость и доступность героев, обеспечивая оптимальное выполнение поручений.

# %% [markdown]
# # Допущения, сделанные при разработке модели
#
# 1. **Сложность задач**
#    - Сложность задач явно не определялась. Главными критериями для оптимизации были:
#      - **Стоимость задачи.**
#      - **Доступность героев.**
#    - Это могло упростить некоторые аспекты планирования.
#
# 2. **Ограничение выполнения задач героями**
#    - Герой считается способным выполнять задачу в заданном кластере и роли, если:
#      - Его средняя оценка за сроки > 2.
#      - Его средняя оценка за качество > 3.
#    - Это ограничение основано на усреднённых данных и не учитывает индивидуальные случаи.
#
# 3. **Интерпретация оценки по срокам**
#    - Оценка по срокам интерпретировалась как **время выполнения задачи в днях**.
#    - Это упрощение могло игнорировать более тонкие аспекты временного фактора.
#
# 4. **Идеальное время выполнения**
#    - Идеальное время выполнения задачи рассчитывалось по заданной формуле, а не предсказывалось на основе более сложных моделей.
#    - Это могло снизить точность оценки времени для задач, сильно отличающихся от типичных.
#
# 5. **Слабая интерпретация вежливости**
#    - Оценка по вежливости учитывалась как максимальное значение в команде, что может быть недостаточно точным.
#    - Более детальный подход мог бы улучшить понимание влияния вежливости на результаты.
#
# 6. **Отсутствие анализа оценок с точки зрения заказчика**
#    - Оценки задач не подвергались более глубокому анализу с точки зрения:
#      - **Требований заказчиков.**
#      - **Причин их удовлетворённости или неудовлетворённости.**
#
# 7. **Частичное игнорирование времени выполнения подзадач**
#    - Время, затраченное героями на выполнение конкретных подзадач, не учитывалось.
#    - Учитывание этих данных могло бы улучшить точность оценки сложности и эффективности выполнения задач.
#
# ---
#
# ### Итог
#
# Допущения позволили упростить разработку модели и сосредоточиться на ключевых аспектах. Однако дальнейшее расширение этих ограничений могло бы сделать модель более точной и адаптированной к реальным условиям. Это остаётся перспективой для будущей работы.
